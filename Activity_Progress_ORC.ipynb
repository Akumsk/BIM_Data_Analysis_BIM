# %%
#Загрузка библиотек
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import datetime

ORC_activity_progress_may = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_25.05_24.06.csv')
ORC_activity_progress_may = ORC_activity_progress_may.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_may.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


ORC_activity_progress_jul = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_25.06_26.07.csv')
ORC_activity_progress_jul = ORC_activity_progress_jul.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_jul.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_aug = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_27.07._26.08.csv')
ORC_activity_progress_aug = ORC_activity_progress_aug.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_aug.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_spt1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_27.08_11.09.csv')
ORC_activity_progress_spt1 = ORC_activity_progress_spt1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_spt1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_spt2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_14.09_30.09.csv')
ORC_activity_progress_spt2 = ORC_activity_progress_spt2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_spt2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_oct = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_01.10_15.10.csv')
ORC_activity_progress_oct = ORC_activity_progress_oct.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_oct.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_oct2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_16.10_22.10.csv')
ORC_activity_progress_oct2 = ORC_activity_progress_oct2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_oct2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_oct3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_23.10_29.10.csv')
ORC_activity_progress_oct3 = ORC_activity_progress_oct3.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_oct3.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)
ORC_activity_progress_nov1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_30.10_04_11.csv')
ORC_activity_progress_nov1 = ORC_activity_progress_nov1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_nov1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_nov2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_05.11_12.11.csv')
ORC_activity_progress_nov2 = ORC_activity_progress_nov2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_nov2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_nov3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_13.11_18.11.csv')
ORC_activity_progress_nov3 = ORC_activity_progress_nov3.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_nov3.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_dec1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_19.11_20.12.csv')
ORC_activity_progress_dec1 = ORC_activity_progress_dec1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_dec1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_dec2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_21.12_31.12.csv')
ORC_activity_progress_dec2 = ORC_activity_progress_dec2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_dec2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_jan1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_2021.01.16.csv')
ORC_activity_progress_jan1 = ORC_activity_progress_jan1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_jan1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_jan2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_2021.01.31.csv')
ORC_activity_progress_jan2 = ORC_activity_progress_jan2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_jan2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_feb1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_2021.02.07.csv')
ORC_activity_progress_feb1 = ORC_activity_progress_feb1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_feb1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_feb2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_2021.02.09.csv')
ORC_activity_progress_feb2 = ORC_activity_progress_feb2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_feb2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_feb3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_feb3.csv')
ORC_activity_progress_feb3 = ORC_activity_progress_feb3.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_feb3.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_feb4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_feb4.csv')
ORC_activity_progress_feb4 = ORC_activity_progress_feb4.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_feb4.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_feb5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_feb5.csv')
ORC_activity_progress_feb5 = ORC_activity_progress_feb5.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_feb5.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar1.csv')
ORC_activity_progress_mar1 = ORC_activity_progress_mar1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar2.csv')
ORC_activity_progress_mar2 = ORC_activity_progress_mar2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar3.csv')
ORC_activity_progress_mar3 = ORC_activity_progress_mar3.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar3.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar4.csv')
ORC_activity_progress_mar4 = ORC_activity_progress_mar4.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar4.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar5.csv')
ORC_activity_progress_mar5 = ORC_activity_progress_mar5.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar5.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar6 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar6.csv')
ORC_activity_progress_mar6 = ORC_activity_progress_mar6.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar6.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_mar7 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_mar7.csv')
ORC_activity_progress_mar7 = ORC_activity_progress_mar7.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_mar7.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_apr1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_apr1.csv')
ORC_activity_progress_apr1 = ORC_activity_progress_apr1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_apr1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


ORC_activity_progress_apr2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_apr2.csv')
ORC_activity_progress_apr2 = ORC_activity_progress_apr2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_apr2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


ORC_activity_progress_apr3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_apr3.csv')
ORC_activity_progress_apr3 = ORC_activity_progress_apr3.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_apr3.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_apr4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_apr4.csv')
ORC_activity_progress_apr4 = ORC_activity_progress_apr4.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_apr4.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_may1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_may1.csv')
ORC_activity_progress_may1 = ORC_activity_progress_may1.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_may1.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_may2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_may2.csv')
ORC_activity_progress_may2 = ORC_activity_progress_may2.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_may2.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_may22 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_may22.csv')
ORC_activity_progress_may22 = ORC_activity_progress_may22.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_may22.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_may30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_may30.csv')
ORC_activity_progress_may30 = ORC_activity_progress_may30.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_may30.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_june5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_june5.csv')
ORC_activity_progress_june5 = ORC_activity_progress_june5.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_june5.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_june12 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_june12.csv')
ORC_activity_progress_june12 = ORC_activity_progress_june12.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_june12.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_june19 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_june19.csv')
ORC_activity_progress_june19 = ORC_activity_progress_june19.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_june19.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_june28 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_june28.csv')
ORC_activity_progress_june28 = ORC_activity_progress_june28.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_june28.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_jul17 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_jul17.csv')
ORC_activity_progress_jul17 = ORC_activity_progress_jul17.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_jul17.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_jul31 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_jul31.csv')
ORC_activity_progress_jul31 = ORC_activity_progress_jul31.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_jul31.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_avg13 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_avg13.csv')
ORC_activity_progress_avg13 = ORC_activity_progress_avg13.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_avg13.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_avg31 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_avg31.csv')
ORC_activity_progress_avg31 = ORC_activity_progress_avg31.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_avg31.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_sent18 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_sent18.csv')
ORC_activity_progress_sent18 = ORC_activity_progress_sent18.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_sent18.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

ORC_activity_progress_sent30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03 - ПД\20_BIM\997_Отчёты\Activity/ORC_activity_sent30.csv')
ORC_activity_progress_sent30 = ORC_activity_progress_sent30.drop([0,1,2,3,4,5],axis=0)
ORC_activity_progress_sent30.rename(columns = {"Project name: ORC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


ORC_activity_progress = pd.concat([
                        ORC_activity_progress_sent30,    
                        ORC_activity_progress_sent18,    
                        ORC_activity_progress_avg31,    
                        ORC_activity_progress_avg13,    
                        ORC_activity_progress_jul31,    
                        ORC_activity_progress_jul17,    
                        ORC_activity_progress_june28,    
                        ORC_activity_progress_june19,    
                        ORC_activity_progress_june12,    
                        ORC_activity_progress_june5,    
                        ORC_activity_progress_may30,    
                        ORC_activity_progress_may22,    
                        ORC_activity_progress_may2,     
                        ORC_activity_progress_may1,     
                        ORC_activity_progress_apr4,     
                        ORC_activity_progress_apr3,       
                        ORC_activity_progress_apr2,    
                        ORC_activity_progress_apr1,    
                        ORC_activity_progress_mar7,
                        ORC_activity_progress_mar6, 
                        ORC_activity_progress_mar5,      
                        ORC_activity_progress_mar4,  
                        ORC_activity_progress_mar3,    
                        ORC_activity_progress_mar2,    
                        ORC_activity_progress_mar1,
                        ORC_activity_progress_feb5,
                        ORC_activity_progress_feb4,
                        ORC_activity_progress_feb3,                        
                        ORC_activity_progress_feb2,
                        ORC_activity_progress_feb1,
                        ORC_activity_progress_jan2,
                        ORC_activity_progress_jan1,
                        ORC_activity_progress_dec2,
                        ORC_activity_progress_dec1, 
                        ORC_activity_progress_nov3, 
                        ORC_activity_progress_nov2,
                        ORC_activity_progress_nov1,
                        ORC_activity_progress_oct3,
                        ORC_activity_progress_oct2,
                        ORC_activity_progress_oct,
                        ORC_activity_progress_spt2,
                        ORC_activity_progress_spt1,
                        ORC_activity_progress_aug,    
                        ORC_activity_progress_jul 
                       ], join = "outer",ignore_index=True)

# %%
#Заплатка
#names_list = ORC_activity_progress_4q.description.to_list()
#names_list[0].split(' ')
#ln = len(names_list)
#ln

#for i in range(ln):
#    names_list[i] = names_list[i].split(' ')
#    del names_list[i][2:]
#    names_list[i] = ' '.join(names_list[i])
#names_list

#for i in range(ln):
#    ORC_activity_progress_4q.iloc[i,2] = names_list[i]

# %%
#Заплатка
names_list = ORC_activity_progress.description.to_list()
names_list[0].split(' ')
ln = len(names_list)
ln

for i in range(ln):
    names_list[i] = names_list[i].split(' ')
    del names_list[i][2:]
    names_list[i] = ' '.join(names_list[i])
names_list

for i in range(ln):
    ORC_activity_progress.iloc[i,2] = names_list[i]

# %%
#Определение колонки с датой
ORC_activity_progress['date'] = pd.to_datetime(ORC_activity_progress['date']).dt.date
ORC_activity_progress['date'] = pd.to_datetime(ORC_activity_progress['date'])
ORC_activity_progress['week'] = pd.to_datetime(ORC_activity_progress['date']).dt.week
ORC_activity_progress.week[220489] = '1'
ORC_activity_progress.week[220490] = '1'        
ORC_activity_progress['year'] = pd.to_datetime(ORC_activity_progress['date']).dt.year

#Преобразование номера недели в дату

ORC_activity_progress = ORC_activity_progress.assign(date_week = '')

ORC_activity_progress['year'] = ORC_activity_progress['year'].astype(str)
ORC_activity_progress['year'] = ORC_activity_progress['year'] + '-W'+ ORC_activity_progress['week'].astype("str")

for i in range(ORC_activity_progress['year'].size):
    ORC_activity_progress['date_week'].iloc[i] = datetime.datetime.strptime(ORC_activity_progress['year'].iloc[i] + '-1', '%G-W%V-%u')

ORC_activity_progress['date_week'] = pd.to_datetime(ORC_activity_progress['date_week'], format='%Y%m%d', errors='ignore')
#ORC_activity_progress = ORC_activity_progress.drop(['year'], axis = 1)
ORC_activity_progress['year'] = pd.to_datetime(ORC_activity_progress['date']).dt.year
# Out:
# <ipython-input-6-23abd8ed63bb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress.week[220489] = '1'
# <ipython-input-6-23abd8ed63bb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress.week[220490] = '1'
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#ORC_activity_progress.query("'2021-02-16' <= date < '2021-02-25'")

# %%
ORC_activity_progress.query("week == '53'")
# Out:
#              date                                        description  \
# 220489 2021-01-02  Екатерина Караваева viewed ORC_П_27_ИОС7.2.12....
# 220490 2021-01-02  Екатерина Караваева viewed ORC_П_27_ИОС7.2.12....
# 220491 2020-12-31  Дженков Максим archived a markup from Unknown ...
# 220492 2020-12-31  Дженков Максим edited a markup on Unknown docu...
# 220493 2020-12-31      Дженков Максим viewed ORC-П-3-ИОС7.3.5.1.pdf.
# ...           ...                                                ...
# 227232 2020-12-28           Anna Shafranova viewed Transmittal #371.
# 227233 2020-12-28  Anna Shafranova downloaded all files from Tran...
# 227234 2020-12-28           Anna Shafranova viewed Transmittal #370.
# 227235 2020-12-28  Anna Shafranova downloaded all files from Tran...
# 227236 2020-12-28           Anna Shafranova viewed Transmittal #369.
#
#                        name        action_type1                action_type2  \
# ...

# %%
ORC_activity_progress.dtypes
# Out:
# date            datetime64[ns]
# description             object
# name                    object
# action_type1            object
# action_type2            object
# document                object
# folder1                 object
# folder2                 object
# week                     int64
# year                     int64
# date_week       datetime64[ns]
# dtype: object

# %%
def rule(x):
    if (x == 'Dmitrii Reshetnyakov' 
        or x == 'Ekaterina Efimova' 
        or x == 'Victor Zelenin' 
        or x == 'Екатерина Караева' 
        or x == 'Sergey Sheptukhin'
        or x == 'Виктор Богомолов'
        or x == 'Вячеслав Кочнов'
        or x == 'Владислав Максимов'
        or x == 'Антон Серков'
        or x == 'New Member'
        or x == 'Alexey Minyaitsev'
        or x == 'Екатерина Караваева'
        or x == 'Evgeny Ivanchenko'
        or x == 'Unknow user'
        or x == 'Николай Алексеевич'
        or x == 'Svetlana Dubovitskaya'
        or x == 'Дмитрий Данильченко'
        or x == 'Viktoriya Fomicheva'
        or x == 'Garik Mgdsyan'
        or x == 'Mikhail Toporov'
        or x == 'Roman Shatilov'
        or x == 'Ekaterina Korneeva'
        or x == 'Tatyana Mochalovskaya'
        or x == 'Айбим BIM360'
        or x == 'Евгений Манейкин'
        or x == 'Игорь Лакиза'
        or x == 'Ирина Короткова'
        or x == 'Карина Семашко'
        or x == 'Наталья Токарева'
        or x == 'Татьяна Милосердова'
        or x == 'Александр Мантуров'
        or x == 'Богдан Демьяненко'
        or x == 'Дмитрий Белевич'
        or x == 'Елена Терентьева'
        or x == 'Петр Бергер'
        or x == 'Ирина Валькова'
        or x == 'Юлия Капран'
        or x == 'Виктория Куксина'
        or x == 'Test User'
        
       ):
        return 'Spectrum'
    
    elif (x == 'Andrey Kumskov' 
        or x == 'Юлия Морозова' 
        or x == 'Алексей Голиков' 
        or x == 'Владимир Гаськов' 
        or x == 'Шундиков Артем' 
        or x == 'Москвин Илья'
        or x == 'Митрофанов Дмитрий'
        or x == 'Александр Звонов'
        or x == 'Сергей Абрамов'
        or x == 'Мария Реутова'
        or x == 'Евгений Стуров'          
        or x == 'Денис Баранов'         
        or x == 'Анна Аронова'
        or x == 'Филатов Андрей'        
        or x == 'Dmitry Medvedev'
        or x == 'Елена Комарова'
        or x == 'Anna Shafranova'
        or x == 'Денис Миронов'
        or x == 'Илья Жубриков'
        or x == 'Георгий Телепнев'
        or x == 'Дженков Максим'
        or x == 'Сергей Шамолин'
        or x == 'Review #17'
        or x == 'Review #18'
        or x == 'Review #20'
        or x == 'Review #24'
        or x == 'Review #25'
        or x == 'Review #26'
        or x == 'Review #27'
        or x == 'Review #39'
        or x == 'Review #41'
        or x == 'Review #42'
        or x == 'Unknown user'
        or x == 'Anton Kasparian'
        or x == 'Алексей Музаффаров'
        or x == 'Людмила Ставиицкая'
        or x == 'Вадим Шеховцов'
        or x == 'Дамир Фатехов'
        or x ==  'yaroslav yaroslav'
        or x ==  'Sergey Tsarev'
        or x ==  'Alexander Gureev'          
        or x ==  'Павел Ирышков'           
        or x ==  'Roman pozdnyakov'          
        or x ==  'Елена Колесникова'           
         ):
        return 'VTBR'
    
    elif (x == 'Elena Antonova' 
          or x == 'Elena Antonova'):
        return 'Spectrum'
    else:
        return 'undefined'
ORC_activity_progress['team'] = ORC_activity_progress.apply(lambda x: rule(x['name']), axis=1)

#
def rule(y):
    if (y == 'Download source file/Export sheet' 
        or y == 'Export item' 
        or y == 'Print document' 
        or y == 'View document'
        or y == 'View file'
        or y == 'Edit office file'
        or y == 'Export transmittal package'
        or y == 'View transmittal'
        or y == 'Open the public link'
        or y == 'calibrate-entity'
       ):
        return 'Reviewed Information'

    elif (y == 'Upload document' 
        or y == 'Create folder'
        or y == 'Create transmittal'
        or y == 'Share document with recipients'
        or y == 'Share file with recipients'
        or y == 'Upload file'
         ):
        return 'Sent Information'
    
    elif (y == 'Create issue' 
        or y == 'Edit markup'
        or y == 'Add documents to review process' 
        or y == 'Claim workflow task'
        or y == 'Initiate review process'
        or y == 'Notify reviewers'
        or y == 'Set approval status'
        or y == 'Submit review'
        or y == 'Add answer to issue'
        or y == 'Add attachment to issue'
        or y == 'Add comment to issue'
        or y == 'Assign issue'
        or y == 'Close issue'
        or y == 'View an existing review item'  
        or y == 'quality-issue-view'
        or y == 'Add a comment' 
        or y == 'Delegate workflow task' 
        or y == 'Send additional notifications'
        or y == 'Terminate review process'
        or y == 'Enable/Disable public link'
        or y == 'Copy documents to destination folder after the review process'
        or y == 'Quality issue respond'
        or y ==  'Add files to review process'
        or y ==  'Copy files to destination folder after the review process'
         ):
        return 'Issues MarkUps Review' 
    
    elif (y == 'Publish markup'
        or y == 'Create a published markup'
         ):
        return 'AddMarkUp'
    
    elif (y == 'Archive markup'
         ):
        return 'CloseMarkUp'
    
    elif (y == 'Copy item' 
        or y == 'Delete folder'
        or y == 'Delete item'
        or y == 'Export document log'
        or y == 'Export project activity log'
        or y == 'Move item'
        or y == 'Remove Location'
        or y == 'Rename document'
        or y == 'Rename folder'
        or y == 'Save approval workflow'
        or y == 'Set folder permission'
        or y == 'remove-company-permission'
        or y == 'Edit description'
        or y == 'Lock document'
        or y == 'Create public link for documents'
        or y == 'Unlock document'
        or y == 'Restore deleted item'
        or y == 'reset-company-permission'
        or y == 'Make current'
        or y == 'Share folder with recipients'
        or y == 'Print file'
        or y == 'Rename file'
        or y ==  'Export file activity log'
        or y ==  'Export file log'
        or y ==  'Edit item'
        or y == 'Lock file'
        or y == 'Unlock file'
         ):                     
        return 'Administrative'
    else:
        return 'undefined'

ORC_activity_progress['Type Action'] = ORC_activity_progress.apply(lambda y: rule(y['action_type2']), axis=1)          

#ORC_activity_progress = ORC_activity_progress[['name','team','action_type2','action_type1','Type Action', 'description','date','week','document','folder1','folder2']]

#ORC_activity_progress.head(10)

# %%
#Анализ уникальных значений
#ORC_activity_progress.action_type2.unique()
np.sort(ORC_activity_progress['Type Action'].unique())
#ORC_activity_progress.groupby(['team','name']).count()

ORC_activity_progress.groupby(['Type Action','action_type2']).count()
#ORC_activity_progress.date.min()
#ORC_activity_progress.head()
#ORC_activity_progress.query("name == 'Roman pozdnyakov'")
# Out:
#                                                     date  description   name  \
# Type Action      action_type2
# AddMarkUp        Create a published markup          3797         3797   3797
#                  Publish markup                     2876         2876   2876
# Administrative   Copy item                           182          182    182
#                  Create public link for documents      2            2      2
#                  Delete folder                       281          281    281
# ...                                                  ...          ...    ...
# Sent Information Upload file                       17285        17285  17285
# undefined        Hide folder path                      1            1      1
#                  Invite team member                    1            1      1
#                  Set review status                   118          118    118
#                  remove-permission                     1            1      1
#
# ...

# %%
with pd.ExcelWriter('ORC_Activity report.xlsx') as writer:  
    ORC_activity_progress.to_excel(writer, sheet_name='Avtivity')

# %%
# Анализ Issues
ORC_activity_progress_add_issue = ORC_activity_progress.query("action_type2 == 'Create issue' | action_type2 == 'View file'")
ORC_activity_progress_add_issue['Issue'] = ORC_activity_progress_add_issue['action_type2'].str.contains("Create issue")
ORC_activity_progress_add_issue['Null'] = ORC_activity_progress_add_issue['folder2'].isnull()

for i in range(len(ORC_activity_progress_add_issue.index)):
    if (ORC_activity_progress_add_issue['action_type2'].iloc[i] == 'Create issue'):
        if (ORC_activity_progress_add_issue['folder2'].iloc[i] == 'Unknown document'):
            if (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+1]):
                ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+1)]
            elif (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+2]):
                  ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+2)]
            elif (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+3]):
                ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+3)]

for i in range(len(ORC_activity_progress_add_issue.index)):                                                                                                                      
    if (ORC_activity_progress_add_issue['action_type2'].iloc[i] == 'Create issue'):
        if (ORC_activity_progress_add_issue['Null'].iloc[i] == True):
            ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+1)]
            if (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+1]):
                ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+1)]
            elif (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+2]):
                  ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+2)]
#            elif (ORC_activity_progress_add_issue['name'].iloc[i] == ORC_activity_progress_add_issue['name'].iloc[i+3]):
#                ORC_activity_progress_add_issue['folder2'].iloc[i] = ORC_activity_progress_add_issue['document'].iloc[(i+3)]

                
ORC_activity_progress_add_issue_cl = ORC_activity_progress_add_issue.query("action_type2 == 'Create issue'").drop(['date', 
                                                                       'name', 
                                                                       'description',
                                                                       'action_type1',
                                                                       'action_type2',
#                                                                       'document',
                                                                       'folder1',
#                                                                       'folder2', 
                                                                       'week',
                                                                       'date_week',
                                                                       'team',
                                                                       'Type Action',
                                                                       'Issue',
                                                                       'Null'
                                                                          ], axis = 1)            

ORC_activity_progress_add_issue_cl.insert(0, 'discipline', '')
ORC_activity_progress_add_issue_cl['AR'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("AR")
ORC_activity_progress_add_issue_cl['АР'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("АР")
ORC_activity_progress_add_issue_cl['АР2'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("АP")
ORC_activity_progress_add_issue_cl['Расст'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("Расст")

ORC_activity_progress_add_issue_cl['KR'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("KR")
ORC_activity_progress_add_issue_cl['КР'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("КР")
ORC_activity_progress_add_issue_cl['КР2'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("КP")

ORC_activity_progress_add_issue_cl['IOS'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("IOS")
ORC_activity_progress_add_issue_cl['ИОС'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("ИОС")

ORC_activity_progress_add_issue_cl['ГП'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("Генер")

ORC_activity_progress_add_issue_cl['EM'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("-EM")
ORC_activity_progress_add_issue_cl['ЭЭ'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("ЭЭ")
ORC_activity_progress_add_issue_cl['ПБ'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("ПБ")
ORC_activity_progress_add_issue_cl['OV'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("OV")

ORC_activity_progress_add_issue_cl['ТБЭ'] = ORC_activity_progress_add_issue_cl['folder2'].str.contains("ТБЭ")

for i in range(len(ORC_activity_progress_add_issue_cl.index)):
    if (ORC_activity_progress_add_issue_cl['AR'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'AR'
    if (ORC_activity_progress_add_issue_cl['АР'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'AR'
    if (ORC_activity_progress_add_issue_cl['АР2'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'AR'   
    if (ORC_activity_progress_add_issue_cl['Расст'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'AR'          

    if (ORC_activity_progress_add_issue_cl['KR'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'KR'
    if (ORC_activity_progress_add_issue_cl['КР'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'KR'
    if (ORC_activity_progress_add_issue_cl['КР2'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'KR'  

    if (ORC_activity_progress_add_issue_cl['IOS'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'IOS'
    if (ORC_activity_progress_add_issue_cl['ИОС'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'IOS'
        
    if (ORC_activity_progress_add_issue_cl['ГП'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'GP'
        
    if (ORC_activity_progress_add_issue_cl['EM'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'EM'
                                                                                                      
    if (ORC_activity_progress_add_issue_cl['ЭЭ'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'EE'                                                                                                      
    if (ORC_activity_progress_add_issue_cl['ПБ'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'PB'
    if (ORC_activity_progress_add_issue_cl['OV'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'OV'
        
    if (ORC_activity_progress_add_issue_cl['ТБЭ'].iloc[i] == True):
        ORC_activity_progress_add_issue_cl['discipline'].iloc[i] = 'ТБЭ' 

ORC_activity_progress_add_issue_num = ORC_activity_progress_add_issue_cl['document'].str.split(' ',expand=True)
ORC_activity_progress_add_issue_num.columns=['Issue','Id']
ORC_activity_progress_add_issue_cl['Id'] = ORC_activity_progress_add_issue_num['Id']  

ORC_activity_progress_add_issue_cl = ORC_activity_progress_add_issue_cl.drop(['document', 
                                                                       'AR', 
                                                                       'АР',
                                                                       'АР2',
                                                                       'Расст',
                                                                       'KR',
                                                                       'КР',
                                                                       'КР2', 
                                                                       'IOS',
                                                                       'ИОС',
                                                                       'ГП',
                                                                       'EM',
                                                                       'ЭЭ',
                                                                       'ПБ',
                                                                       'OV', 
                                                                       'ТБЭ'
                                                                          ], axis = 1)  

with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\03_ПД\20_BIM\997_Отчёты\Issues\Issues_docs.xlsx') as writer:  
    ORC_activity_progress_add_issue.to_excel(writer, sheet_name='Issue')
    ORC_activity_progress_add_issue_cl.to_excel(writer, sheet_name='Issue_Cl')
    ORC_activity_progress_add_issue_num.to_excel(writer, sheet_name='Issue_Num')
# Out:
# <ipython-input-15-f4e364172195>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_add_issue['Issue'] = ORC_activity_progress_add_issue['action_type2'].str.contains("Create issue")
# <ipython-input-15-f4e364172195>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_add_issue['Null'] = ORC_activity_progress_add_issue['folder2'].isnull()
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# ...

# %%
ORC_activity_progress_add_issue
# Out:
#              date                                        description  \
# 9      2021-09-30  Владислав Максимов viewed ORC_P_I_27_SPH_BIM_I...
# 29     2021-09-30  Владислав Максимов viewed ORC_P_I_25_SPH_BIM_I...
# 36     2021-09-30  Andrey Kumskov viewed ORC_P_I_4.1_SPH_BIM_IOS5...
# 37     2021-09-30  Andrey Kumskov viewed ORC_P_I_4.1_SPH_BIM_IOS5...
# 45     2021-09-30  Владислав Максимов viewed Раздел 5 Подраздел 5...
# ...           ...                                                ...
# 267289 2020-08-24                      Andrey Kumskov added Issue 5.
# 267292 2020-08-24                      Andrey Kumskov added Issue 4.
# 267299 2020-08-24                      Andrey Kumskov added Issue 3.
# 267507 2020-08-21                  Митрофанов Дмитрий added Issue 2.
# 268260 2020-08-18                  Митрофанов Дмитрий added Issue 1.
#
#                       name          action_type1  action_type2  \
# 9       Владислав Максимов           view-entity     View file
# ...

# %%
ORC_activity_progress_add_issue['Issue'] = ORC_activity_progress_add_issue['description'].str.contains("Review")
# Out:
# <ipython-input-16-1b9e6715faca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_add_issue['Issue'] = ORC_activity_progress_add_issue['description'].str.contains("Review")

# %%
#Список для простановки статусов
#issue_list = ORC_activity_progress_add_issue.to_list()
#ln = len(issue_list)

# %%
# Таблица активности компаний по времени (номер недели по оси Х)

ORC_Groupby_Team_Actions = ORC_activity_progress.pivot_table(values = 'action_type2', index = {'team', 'Type Action'}, columns = 'date_week', aggfunc = 'count').fillna(0)
#ORC_Groupby_Team_Actions
ORC_Groupby_Team_Actions_Users_Detail = ORC_activity_progress.pivot_table(values = 'action_type1', index = 'name', columns = {'action_type2'}, aggfunc = 'count').fillna(0)
ORC_Groupby_Team_Actions_Users_Sum = ORC_activity_progress.pivot_table(values = 'action_type2', index = 'name', columns = {'Type Action'}, aggfunc = 'count').fillna(0)
ORC_activity_progress
# Out:
#              date                                        description  \
# 0      2021-09-30                Александр Мантуров viewed Issue 98.
# 1      2021-09-30   Andrey Kumskov exported the Activity log report.
# 2      2021-09-30   Andrey Kumskov exported the Activity log report.
# 3      2021-09-30   Andrey Kumskov exported the Activity log report.
# 4      2021-09-30   Andrey Kumskov exported the Activity log report.
# ...           ...                                                ...
# 271423 2020-06-25  Andrey Kumskov renamed 03_Инженерно‐экологичес...
# 271424 2020-06-25  Andrey Kumskov renamed 02_Инженерно‐геологичес...
# 271425 2020-06-25  Andrey Kumskov renamed 01_Инженерно‐геодезичес...
# 271426 2020-06-25  Andrey Kumskov added subfolder 04_Экспертиза t...
# 271427 2020-06-25  Andrey Kumskov added subfolder 03_Результат to...
#
#                       name           action_type1  \
# 0       Александр Мантуров     quality-issue-view
# ...

# %%
ORC_activity_progress.query("'2020-11-01' <= date < '2021-02-09'")
# Out:
#              date                                        description  \
# 125088 2021-02-08  Александр Мантуров viewed ORC_P_I_3.1_SHP_BIM_...
# 125089 2021-02-08               Александр Мантуров viewed Issue 423.
# 125090 2021-02-08  Александр Мантуров viewed ORC_P_I_3.1_SPH_DRW_...
# 125091 2021-02-08  Александр Мантуров viewed ORC_P_I_3.1_SHP_BIM_...
# 125092 2021-02-08  Александр Мантуров viewed ORC_P_I_3.1_SHP_BIM_...
# ...           ...                                                ...
# 195256 2020-11-02                   Вячеслав Кочнов viewed Issue 73.
# 195257 2020-11-02  Вячеслав Кочнов viewed ORC_P_I_8_SPH_DRW_AR.07...
# 195258 2020-11-02                   Вячеслав Кочнов viewed Issue 73.
# 195259 2020-11-02                   Вячеслав Кочнов viewed Issue 81.
# 195260 2020-11-02                   Вячеслав Кочнов viewed Issue 85.
#
#                       name        action_type1        action_type2  \
# 125088  Александр Мантуров         view-entity           View file
# ...

# %%
ORC_activity_progress_2month = ORC_activity_progress.query("'2021-01-01' <= date < '2021-03-29'")
# Установка датафрема для печати по неделям
ORC_Groupby_Team_Actions_Plot = ORC_activity_progress_2month.query("team == 'VTBR' | team == 'Spectrum'")
ORC_Groupby_Team_Actions_Plot = ORC_Groupby_Team_Actions_Plot.pivot_table(values = 'action_type2', index = 'date_week', columns = {'team', 'Type Action'}, aggfunc = 'count').fillna(0)

ORC_Groupby_Team_Actions_Plot_All = ORC_activity_progress.query("team == 'VTBR' | team == 'Spectrum'")
ORC_Groupby_Team_Actions_Plot_All = ORC_Groupby_Team_Actions_Plot_All.pivot_table(values = 'action_type2', index = 'date_week', columns = {'team', 'Type Action'}, aggfunc = 'count').fillna(0)
ORC_Groupby_Team_Actions_Plot_All = ORC_Groupby_Team_Actions_Plot_All.reset_index()
ORC_Groupby_Team_Actions_Plot_All
# Out:
# team         date_week  Spectrum                             \
# Type Action            AddMarkUp Administrative CloseMarkUp
# 0           2020-06-22       0.0            0.0         0.0
# 1           2020-06-29       0.0           15.0         0.0
# 2           2020-07-06       0.0           36.0         0.0
# 3           2020-07-13       0.0            3.0         0.0
# 4           2020-07-20       0.0           23.0         0.0
# ..                 ...       ...            ...         ...
# 61          2021-08-30       0.0           26.0         0.0
# 62          2021-09-06       0.0           56.0         0.0
# 63          2021-09-13       0.0            0.0         0.0
# 64          2021-09-20       0.0            1.0         0.0
# 65          2021-09-27       1.0            0.0         0.0
#
# team                                                                     \
# Type Action Issues MarkUps Review Reviewed Information Sent Information
# ...

# %%
# Установка датафрема для печати по дням
ORC_Groupby_Team_Actions_Plot_days = ORC_activity_progress.query("team == 'VTBR' | team == 'Spectrum'")
ORC_Groupby_Team_Actions_Plot_days = ORC_Groupby_Team_Actions_Plot_days.pivot_table(values = 'action_type2', index = 'date', columns = {'team', 'Type Action'}, aggfunc = 'count').fillna(0)
ORC_Groupby_Team_Actions_Plot_days = ORC_Groupby_Team_Actions_Plot_days.reset_index()
ORC_Groupby_Team_Actions_Plot_days
#Группировка Company/Actions, вычисление активных маркапов
ORC_Groupby_Team_Actions_Plot_days = ORC_Groupby_Team_Actions_Plot_days.assign(Active_Marks_UP = ORC_Groupby_Team_Actions_Plot_days[('VTBR','AddMarkUp')] - ORC_Groupby_Team_Actions_Plot_days[('VTBR','CloseMarkUp')])
ORC_Groupby_Team_Actions_Plot_days
#Вычисление накопленных маркпов
Accum_MarksUp = ORC_Groupby_Team_Actions_Plot_days.Active_Marks_UP.to_list()
#for i in range (1, ORC_Groupby_Team_Actions_Plot_All['Accum_MarksUp'].size):

for i in range(1, len(Accum_MarksUp)):
    Accum_MarksUp[i] = Accum_MarksUp[i] + Accum_MarksUp[i-1]

ORC_Groupby_Team_Actions_Plot_days['Accum_MarksUp'] = pd.Series(Accum_MarksUp)
ORC_Groupby_Team_Actions_Plot_All_plot_days = pd.DataFrame(ORC_Groupby_Team_Actions_Plot_days['date'], columns = ['date']) 
ORC_Groupby_Team_Actions_Plot_All_plot_days['Accum_MarksUp'] = ORC_Groupby_Team_Actions_Plot_days['Accum_MarksUp']
ORC_Groupby_Team_Actions_Plot_All_plot_days = ORC_Groupby_Team_Actions_Plot_All_plot_days.query("'2020-12-01' <= date")
ORC_Groupby_Team_Actions_Plot_All_plot_days = ORC_Groupby_Team_Actions_Plot_All_plot_days.set_index('date')

with pd.ExcelWriter('ORC_Activity report_Markup_days.xlsx') as writer:  
    ORC_Groupby_Team_Actions_Plot_All_plot_days.to_excel(writer, sheet_name='Marks up by days')
ORC_Groupby_Team_Actions_Plot_All_plot_days
# Out:
#             Accum_MarksUp
# date
# 2020-12-01          624.0
# 2020-12-02          658.0
# 2020-12-03          664.0
# 2020-12-04          704.0
# 2020-12-05          704.0
# ...                   ...
# 2021-09-25         1018.0
# 2021-09-27         1091.0
# 2021-09-28         1094.0
# 2021-09-29         1092.0
# 2021-09-30         1041.0
#
# [252 rows x 1 columns]

# %%
#Закрытие Маркапов по дням last week
ORC_activity_progress_lweek = ORC_activity_progress.query("'2021-03-15' <= date <= '2021-05-06'")
ORC_activity_progress_lweek = ORC_activity_progress_lweek.query("action_type2 == 'Archive markup'")
# Установка датафрема для печати
ORC_Groupby_Team_Markupweek_Plot = ORC_activity_progress_lweek.query("team == 'VTBR' | team == 'Spectrum'")
ORC_Groupby_Team_Markupweek_Plot = ORC_Groupby_Team_Markupweek_Plot.pivot_table(index = 'date', columns = {'team', 'action_type2'}, aggfunc = 'count').fillna(0)

ORC_Groupby_Team_Markupweek_Plot
# Out:
#                 Type Action   action_type1      date_week    description  \
# team                   VTBR           VTBR           VTBR           VTBR
# action_type2 Archive markup Archive markup Archive markup Archive markup
# date
# 2021-03-15                8              8              8              8
# 2021-03-16               57             57             57             57
# 2021-03-17              100            100            100            100
# 2021-03-18              488            488            488            488
# 2021-03-19              366            366            366            366
# 2021-03-22              508            508            508            508
# 2021-03-23              160            160            160            160
# 2021-03-24               27             27             27             27
# 2021-03-25                8              8              8              8
# 2021-03-26                9              9              9              9
# ...

# %%
#Группировка Company/Actions
ORC_Groupby_Team_Actions_Plot_All = ORC_Groupby_Team_Actions_Plot_All.assign(Active_Marks_UP = ORC_Groupby_Team_Actions_Plot_All[('VTBR','AddMarkUp')] - ORC_Groupby_Team_Actions_Plot_All[('VTBR','CloseMarkUp')])
ORC_Groupby_Team_Actions_Plot_All
# Out:
# team         date_week  Spectrum                             \
# Type Action            AddMarkUp Administrative CloseMarkUp
# 0           2020-06-22       0.0            0.0         0.0
# 1           2020-06-29       0.0           15.0         0.0
# 2           2020-07-06       0.0           36.0         0.0
# 3           2020-07-13       0.0            3.0         0.0
# 4           2020-07-20       0.0           23.0         0.0
# ..                 ...       ...            ...         ...
# 61          2021-08-30       0.0           26.0         0.0
# 62          2021-09-06       0.0           56.0         0.0
# 63          2021-09-13       0.0            0.0         0.0
# 64          2021-09-20       0.0            1.0         0.0
# 65          2021-09-27       1.0            0.0         0.0
#
# team                                                                     \
# Type Action Issues MarkUps Review Reviewed Information Sent Information
# ...

# %%
#Группировка Actions/Company
ORC_Groupby_Team_Actions_Plot_All = ORC_Groupby_Team_Actions_Plot_All.assign(Active_Marks_UP = ORC_Groupby_Team_Actions_Plot_All[('AddMarkUp','VTBR')] - ORC_Groupby_Team_Actions_Plot_All[('CloseMarkUp', 'VTBR')])
ORC_Groupby_Team_Actions_Plot_All
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AddMarkUp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# ...

# %%
Accum_MarksUp = ORC_Groupby_Team_Actions_Plot_All.Active_Marks_UP.to_list()
#for i in range (1, ORC_Groupby_Team_Actions_Plot_All['Accum_MarksUp'].size):
Accum_MarksUp
for i in range(1, len(Accum_MarksUp)):
    Accum_MarksUp[i] = Accum_MarksUp[i] + Accum_MarksUp[i-1]
Accum_MarksUp
ORC_Groupby_Team_Actions_Plot_All['Accum_MarksUp'] = pd.Series(Accum_MarksUp)
ORC_Groupby_Team_Actions_Plot_All_plot = pd.DataFrame(ORC_Groupby_Team_Actions_Plot_All['date_week'], columns = ['date_week']) 
ORC_Groupby_Team_Actions_Plot_All_plot['Accum_MarksUp'] = ORC_Groupby_Team_Actions_Plot_All['Accum_MarksUp']
ORC_Groupby_Team_Actions_Plot_All_plot = ORC_Groupby_Team_Actions_Plot_All_plot.query("'2020-12-01' <= date_week")
ORC_Groupby_Team_Actions_Plot_All_plot = ORC_Groupby_Team_Actions_Plot_All_plot.set_index('date_week')
ORC_Groupby_Team_Actions_Plot_All_plot
# Out:
#             Accum_MarksUp
# date_week
# 2020-12-07          736.0
# 2020-12-14          980.0
# 2020-12-21         1140.0
# 2020-12-28         1636.0
# 2021-01-04         1747.0
# 2021-01-11         1882.0
# 2021-01-18         2439.0
# 2021-01-25         2963.0
# 2021-02-01         3209.0
# 2021-02-08         3470.0
# 2021-02-15         3407.0
# 2021-02-22         3188.0
# 2021-03-01         3003.0
# 2021-03-08         3173.0
# 2021-03-15         2551.0
# 2021-03-22         1881.0
# 2021-03-29         1865.0
# 2021-04-05         1616.0
# 2021-04-12         1343.0
# 2021-04-19         1194.0
# 2021-04-26          990.0
# 2021-05-03          989.0
# 2021-05-10          990.0
# 2021-05-17          990.0
# 2021-05-24          992.0
# 2021-05-31          992.0
# 2021-06-07          993.0
# 2021-06-14          996.0
# 2021-06-21         1013.0
# 2021-06-28         1013.0
# 2021-07-05         1016.0
# 2021-07-12         1016.0
# 2021-07-19         1016.0
# 2021-07-26         1016.0
# ...

# %%
my_color = ['red'] 
ORC_Groupby_Team_Actions_Plot_All_plot.plot(kind = 'line', figsize = [15, 7], title = 'График накопления Marks Up', color = my_color, linewidth = 2)

# %%
ORC_Groupby_Team_Actions_Plot
# Out:
# team         Spectrum                                                   \
# Type Action AddMarkUp Administrative CloseMarkUp Issues MarkUps Review
# date_week
# 2021-01-04        0.0            0.0         0.0                  37.0
# 2021-01-11       11.0           47.0         2.0                 659.0
# 2021-01-18        6.0          103.0         0.0                 332.0
# 2021-01-25       10.0           26.0         0.0                 476.0
# 2021-02-01        7.0           57.0         2.0                1582.0
# 2021-02-08       48.0           22.0         0.0                2172.0
# 2021-02-15       14.0          582.0         0.0                 844.0
# 2021-02-22        8.0         1365.0         0.0                 435.0
# 2021-03-01        5.0           73.0         0.0                 560.0
# 2021-03-08        3.0           22.0         0.0                 623.0
# 2021-03-15        0.0           41.0         0.0                 438.0
# ...

# %%
#Удаление колонок для Team - Type Action

ORC_Groupby_Team_Actions_Plot_Issues = ORC_Groupby_Team_Actions_Plot.drop([('Spectrum','Administrative'),
                                                                           ('VTBR','Administrative'),
                                                                           ('Spectrum','Reviewed Information'),
                                                                           ('VTBR','Reviewed Information'),
                                                                           ('Spectrum','Sent Information'),
                                                                           ('VTBR','Sent Information'),
                                                                           ('Spectrum','AddMarkUp'),
                                                                           ('VTBR','AddMarkUp'),                                                                           
                                                                           ('Spectrum','CloseMarkUp'),
                                                                           ('VTBR','CloseMarkUp')                                                                           
                                                                           
                                                                           
                                                                          ], axis = 1)

ORC_Groupby_Team_Actions_Plot_R_S = ORC_Groupby_Team_Actions_Plot.drop([('Spectrum','Administrative'),
                                                                        ('VTBR','Administrative'), 
                                                                        ('Spectrum','Issues MarkUps Review'),
                                                                        ('VTBR', 'Issues MarkUps Review'),
                                                                        ('Spectrum','AddMarkUp'),
                                                                        ('VTBR','AddMarkUp'),                                                                           
                                                                        ('Spectrum','CloseMarkUp'),
                                                                        ('VTBR','CloseMarkUp')                                                                         
                                                                       ], axis = 1)

ORC_Groupby_Team_Actions_Plot_MarkUp = ORC_Groupby_Team_Actions_Plot.drop([('Spectrum','Administrative'),
                                                                           ('VTBR','Administrative'),
                                                                           ('Spectrum','Reviewed Information'),
                                                                           ('VTBR','Reviewed Information'),
                                                                           ('Spectrum','Sent Information'),
                                                                           ('VTBR','Sent Information'),
                                                                           ('Spectrum','AddMarkUp'),
                                                                           ('Spectrum','CloseMarkUp'),
                                                                           ('Spectrum','Issues MarkUps Review'),
                                                                           ('VTBR', 'Issues MarkUps Review')
                                                                          ], axis = 1)

# %%
#Удаление колонок для Type Action - Team

ORC_Groupby_Team_Actions_Plot.columns = ['SPGR_Add_Mark',
                                         'VTBR_Add_Mark', 
                                         'SPGR_Admin',
                                         'VTBR_Admin', 
                                         'SPGR_Close_Mark', 
                                         'VTBR_Close_Mark', 
                                         'SPGR_Issue', 
                                         'VTBR_Issue', 
                                         'SPGR_Reviewed_Info', 
                                         'VTBR_Reviewed_Info', 
                                         'SPGR_Sent_Info', 
                                         'VTBR_Sent_Info']

ORC_Groupby_Team_Actions_Plot_Issues = ORC_Groupby_Team_Actions_Plot.drop([('SPGR_Admin'),
                                                                           ('VTBR_Admin'),
                                                                           ('SPGR_Reviewed_Info'),
                                                                           ('VTBR_Reviewed_Info'),
                                                                           ('SPGR_Sent_Info'),
                                                                           ('VTBR_Sent_Info'),
                                                                           ('SPGR_Add_Mark'),
                                                                           ('SPGR_Close_Mark'),
                                                                           ('VTBR_Add_Mark'),
                                                                           ('VTBR_Close_Mark')
                                                                          ], axis = 1)
#ORC_Groupby_Team_Actions_Plot_Issues = ORC_Groupby_Team_Actions_Plot_Issues.drop(['undefined'], axis = 1)

#ORC_Groupby_Team_Actions_Plot_R_S = ORC_Groupby_Team_Actions_Plot.drop(['undefined'], axis = 1)
ORC_Groupby_Team_Actions_Plot_R_S = ORC_Groupby_Team_Actions_Plot.drop([('SPGR_Admin'),
                                                                        ('VTBR_Admin'), 
                                                                        ('SPGR_Issue'),
                                                                        ('VTBR_Issue'),
                                                                        ('SPGR_Add_Mark'),
                                                                        ('VTBR_Add_Mark'),
                                                                        ('SPGR_Close_Mark'),
                                                                        ('VTBR_Close_Mark')                                                                
                                                                       ], axis = 1)

ORC_Groupby_Team_Actions_Plot_MarkUp = ORC_Groupby_Team_Actions_Plot.drop([('SPGR_Admin'),
                                                                           ('VTBR_Admin'),
                                                                           ('SPGR_Reviewed_Info'),
                                                                           ('VTBR_Reviewed_Info'),
                                                                           ('SPGR_Sent_Info'),
                                                                           ('VTBR_Sent_Info'),
                                                                           ('SPGR_Add_Mark'),
                                                                           ('SPGR_Close_Mark'),
                                                                           ('SPGR_Issue'),
                                                                           ('VTBR_Issue')
                                                                          ], axis = 1)

ORC_Groupby_Team_Actions_Plot_MarkUp
# Out:
#             VTBR_Add_Mark  VTBR_Close_Mark
# date_week
# 2021-01-04            0.0              0.0
# 2021-01-11           47.0            774.0
# 2021-01-18          103.0           3354.0
# 2021-01-25           26.0            450.0
# 2021-02-01           57.0            541.0
# 2021-02-08           22.0            315.0
# 2021-02-15          582.0           2048.0
# 2021-02-22         1365.0           1175.0
# 2021-03-01           73.0            666.0
# 2021-03-08           22.0            232.0
# 2021-03-15           41.0            805.0
# 2021-03-22           80.0            739.0

# %%
#my_color = ['lawngreen',  'skyblue','green', 'darkblue'] #Act - Team
my_color = ['lawngreen', 'green', 'skyblue', 'darkblue'] #Team - Act
#my_linewidth = ['1', '2']
#my_linestyle = ['-', '--']
ORC_Groupby_Team_Actions_Plot_R_S.plot(kind = 'line', figsize = [20, 7], title = 'График активностей по неделям', color = my_color, linewidth = 2)

# %%
ORC_Groupby_Team_Actions_Plot_MarkUp
# Out:
#             VTBR_Add_Mark  VTBR_Close_Mark
# date_week
# 2021-01-04            0.0              0.0
# 2021-01-11           47.0            774.0
# 2021-01-18          103.0           3354.0
# 2021-01-25           26.0            450.0
# 2021-02-01           57.0            541.0
# 2021-02-08           22.0            315.0
# 2021-02-15          582.0           2048.0
# 2021-02-22         1365.0           1175.0
# 2021-03-01           73.0            666.0
# 2021-03-08           22.0            232.0
# 2021-03-15           41.0            805.0
# 2021-03-22           80.0            739.0

# %%
my_color = ['darkgreen', 'darkblue']

#my_linewidth = ['1', '2']
#my_linestyle = ['-', '--']
ORC_Groupby_Team_Actions_Plot_Issues.plot(kind = 'line', figsize = [20, 7], title = 'График Issues по неделям', color = my_color, linewidth = 2)

# %%
my_color = ['red', 'lightcoral']
#my_linewidth = ['1', '2']
#my_linestyle = ['-', '--']
ORC_Groupby_Team_Actions_Plot_MarkUp.plot(kind = 'line', figsize = [15, 5], title = 'График MarkUps по неделям', color = my_color, linewidth = 2)

# %%
ORC_Groupby_Team_Actions_Plot_MarkUp
# Out:
#             VTBR_Add_Mark  VTBR_Close_Mark
# date_week
# 2021-01-04            0.0              0.0
# 2021-01-11           47.0            774.0
# 2021-01-18          103.0           3354.0
# 2021-01-25           26.0            450.0
# 2021-02-01           57.0            541.0
# 2021-02-08           22.0            315.0
# 2021-02-15          582.0           2048.0
# 2021-02-22         1365.0           1175.0
# 2021-03-01           73.0            666.0
# 2021-03-08           22.0            232.0
# 2021-03-15           41.0            805.0
# 2021-03-22           80.0            739.0

# %%
# Количество опубликованных маркапов
ORC_activity_progress.query("(action_type2 == 'Publish markup' | action_type2 == 'Create a published markup') & team == 'VTBR'").count()
# Out:
# date            6437
# description     6437
# name            6437
# action_type1    6437
# action_type2    6437
# document        6437
# folder1            0
# folder2            0
# week            6437
# year            6437
# date_week       6437
# team            6437
# Type Action     6437
# dtype: int64

# %%
# Количество закрытых маркапов
ORC_activity_progress.query("action_type2 == 'Archive markup' & team == 'VTBR'").count()
# Out:
# date            5396
# description     5396
# name            5396
# action_type1    5396
# action_type2    5396
# document        5396
# folder1            0
# folder2            0
# week            5396
# year            5396
# date_week       5396
# team            5396
# Type Action     5396
# dtype: int64

# %%
# Проверка 
# Суммарная таблица активностей по пользователям
ORC_activity_sum = ORC_activity_progress.groupby(['team']).count()
ORC_activity_sum = ORC_activity_sum.filter(items = ['team','action_type2'])
ORC_activity_sum.rename(columns = {"action_type2" : "number of activities"}, inplace=True)
ORC_activity_sum

# Проверка Суммарная таблица активностей по пользователям
ORC_activity_progress_weekly_sum = ORC_activity_progress.pivot_table(values = 'action_type2', index = {'team'}, columns = 'week', aggfunc = 'count').fillna(0)

# %%
# Краткий график
#Установка минимума
ORC_activity_progress_vtbr = ORC_activity_progress.query("team =='VTBR'")
ORC_activity_progress_group100 = ORC_activity_progress_vtbr.groupby(['name']).count().query('action_type2 > 500').reset_index()
ORC_activity_progress_vtbr.query("team =='VTBR'")
ORC_activity_progress_100 = ORC_activity_progress.merge(ORC_activity_progress_group100, on = 'name', how = 'right')
ORC_activity_progress_100
#Вывод на печать
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(20,7)})
ORC_countplot_VTBR = sns.countplot(x = 'name', data = ORC_activity_progress_100.filter(items = ['name', 'action_type2']))

# %%
with pd.ExcelWriter('ORC_Activity report.xlsx') as writer:  
    ORC_Groupby_Team_Actions_Users_Detail.to_excel(writer, sheet_name='Users_Detail')
    ORC_Groupby_Team_Actions_Users_Sum.to_excel(writer, sheet_name='Users_Sum')
    ORC_Groupby_Team_Actions.to_excel(writer, sheet_name='Weekly_Activity')
    ORC_activity_progress_weekly_sum.to_excel(writer, sheet_name='Weekly_Activity_Sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8ff5fd927aff> in <module>
#       1 with pd.ExcelWriter('ORC_Activity report.xlsx') as writer:
# ----> 2     ORC_Groupby_Team_Actions_Users_Detail.to_excel(writer, sheet_name='Users_Detail')
#       3     ORC_Groupby_Team_Actions_Users_Sum.to_excel(writer, sheet_name='Users_Sum')
#       4     ORC_Groupby_Team_Actions.to_excel(writer, sheet_name='Weekly_Activity')
#       5     ORC_activity_progress_weekly_sum.to_excel(writer, sheet_name='Weekly_Activity_Sum')
#
# NameError: name 'ORC_Groupby_Team_Actions_Users_Detail' is not defined

# %%
# Выборка кто когда делал Комментарии от ВТБ
ORC_activity_progress_markups = ORC_activity_progress.query("action_type2 == ['Edit markup','Publish markup', 'Create a published markup', 'Archive markup']")
ORC_activity_progress_markups = ORC_activity_progress_markups.query("'2021-07-01' <= date < '2021-09-30'")
#ORC_activity_progress_markups = ORC_activity_progress_markups.query("team == ['VTBR']")
ORC_activity_progress_markups_gr = ORC_activity_progress_markups.groupby(['name', 'action_type2']).count()
ORC_activity_progress_markups_srt = ORC_activity_progress_markups.sort_values(by=['name'])
ORC_activity_progress_markups.date.min()
with pd.ExcelWriter('ORC_Activity report_MarkUps.xlsx') as writer:  
    ORC_activity_progress_markups_gr.to_excel(writer, sheet_name='MarkUps by Users')
    ORC_activity_progress_markups_srt.to_excel(writer, sheet_name='All MarkUps')
ORC_activity_progress_markups_cplot = sns.countplot(x = 'name', data = ORC_activity_progress_markups.filter(items = ['name', 'action_type2']))

# %%
#Все трансмителлы для стадии ТД и ПД
ORC_activity_progress_crttrans = ORC_activity_progress.query("action_type2 == 'Create transmittal'")

ORC_activity_progress_crttrans['trans_td1'] = ORC_activity_progress_crttrans.folder2.str.contains("-T-")
ORC_activity_progress_crttrans['trans_td2'] = ORC_activity_progress_crttrans.folder2.str.contains("_T_")
ORC_activity_progress_crttrans['trans_td3'] = ORC_activity_progress_crttrans.folder2.str.contains("_Т_")
ORC_activity_progress_crttrans['trans_td4'] = ORC_activity_progress_crttrans.folder2.str.contains("-Т-")

ORC_activity_progress_crttrans['trans_pd1'] = ORC_activity_progress_crttrans.folder2.str.contains("-П-")
ORC_activity_progress_crttrans['trans_pd2'] = ORC_activity_progress_crttrans.folder2.str.contains("_P_")
ORC_activity_progress_crttrans['trans_pd3'] = ORC_activity_progress_crttrans.folder2.str.contains("-P-")
ORC_activity_progress_crttrans['trans_pd4'] = ORC_activity_progress_crttrans.folder2.str.contains("-П-")


ORC_activity_progress_crttrans_td = ORC_activity_progress_crttrans.query("trans_td1 == True or trans_td2 == True or trans_td3 == True or trans_td4 == True")
ORC_activity_progress_crttrans_pd = ORC_activity_progress_crttrans.query("trans_pd1 == True or trans_pd2 == True or trans_pd3 == True or trans_pd4 == True")

ORC_activity_progress_crttrans_split_td = ORC_activity_progress_crttrans_td.folder2.str.split('-', expand=True)

ORC_activity_progress_crttrans_td_jan = ORC_activity_progress_crttrans_td.query(" date <= '2021-01-26'")
ORC_activity_progress_crttrans_td_mar = ORC_activity_progress_crttrans_td.query("'2021-01-26'  < date <= '2021-03-18'")

#ORC_activity_progress.query("'2021-02-16' <= date < '2021-02-25'")

with pd.ExcelWriter('ORC_activity_progress_transmitel TD.xlsx') as writer:
    ORC_activity_progress_crttrans_td_jan.to_excel(writer, sheet_name='До 26.01.2021')
    ORC_activity_progress_crttrans_td_mar.to_excel(writer, sheet_name='26.01.2021 - 18.03.2021')
    ORC_activity_progress_crttrans_td.to_excel(writer, sheet_name='Всего документов ТД')
    


ORC_activity_progress_crttrans_td_group = ORC_activity_progress_crttrans_td.groupby(['folder2', 'date']).count()
ORC_activity_progress_crttrans_pd_group = ORC_activity_progress_crttrans_pd.groupby(['folder2', 'date']).count()

with pd.ExcelWriter('ORC_activity_progress_transmitel_group.xlsx') as writer:
    ORC_activity_progress_crttrans_td_group.to_excel(writer, sheet_name='Report_TD')
    ORC_activity_progress_crttrans_pd_group.to_excel(writer, sheet_name='Report_PD')
ORC_activity_progress_crttrans_pd
# Out:
# <ipython-input-20-05fded6b440d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_crttrans['trans_td1'] = ORC_activity_progress_crttrans.folder2.str.contains("-T-")
# <ipython-input-20-05fded6b440d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_crttrans['trans_td2'] = ORC_activity_progress_crttrans.folder2.str.contains("_T_")
# <ipython-input-20-05fded6b440d>:6: SettingWithCopyWarning:
# ...

# %%
#Все трансмителлы для стадии ПД
ORC_activity_progress_crttrans = ORC_activity_progress.query("action_type2 == 'Create transmittal'")

ORC_activity_progress_crttrans['trans_dp'] = ORC_activity_progress_crttrans.folder2.str.contains("ORC-П")
ORC_activity_progress_crttrans = ORC_activity_progress_crttrans.query("trans_pd == True")

ORC_activity_progress_crttrans_split = ORC_activity_progress_crttrans.folder2.str.split('-', expand=True)

ORC_activity_progress_crttrans_jan = ORC_activity_progress_crttrans.query(" date <= '2021-01-26'")
ORC_activity_progress_crttrans_mar = ORC_activity_progress_crttrans.query("'2021-01-26'  < date <= '2021-03-18'")

#ORC_activity_progress.query("'2021-02-16' <= date < '2021-02-25'")

with pd.ExcelWriter('ORC_activity_progress_transmitel TD.xlsx') as writer:
    ORC_activity_progress_crttrans_jan.query("trans_td == True").to_excel(writer, sheet_name='До 26.01.2021')
    ORC_activity_progress_crttrans_mar.query("trans_td == True").to_excel(writer, sheet_name='26.01.2021 - 18.03.2021')
    ORC_activity_progress_crttrans.query("trans_td == True").to_excel(writer, sheet_name='Всего документов ТД')
    
ORC_activity_progress_crttrans_mar

ORC_activity_progress_crttrans_group = ORC_activity_progress_crttrans.groupby(['folder2', 'date']).count()
ORC_activity_progress_crttrans_group
with pd.ExcelWriter('ORC_activity_progress_transmitel TD_group.xlsx') as writer:
    ORC_activity_progress_crttrans_group.to_excel(writer, sheet_name='Report')
# Out:
# <ipython-input-21-074b97f6c31f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_crttrans['trans_dp'] = ORC_activity_progress_crttrans.folder2.str.contains("ORC-П")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     897                 pass
# ...

# %%
#Документы загруженные Спектрум по стадии П
ORC_activity_progress.rename(columns = {"Type Action" : "Type_Action"}, inplace=True)
ORC_activity_progress_sentinf = ORC_activity_progress.query("action_type2 == 'Upload document' or action_type2 == 'Upload file'")


ORC_activity_progress_sentinf['pd1'] = ORC_activity_progress_sentinf.document.str.contains("-П-")
ORC_activity_progress_sentinf['pd2'] = ORC_activity_progress_sentinf.document.str.contains("_P_")
ORC_activity_progress_sentinf['pd3'] = ORC_activity_progress_sentinf.document.str.contains("-P-")
ORC_activity_progress_sentinf['pd4'] = ORC_activity_progress_sentinf.document.str.contains("-П-")

ORC_activity_progress_sentinf = ORC_activity_progress_sentinf.query("pd1 == True or pd2 == True or pd3 == True or pd4 == True").query("team == 'Spectrum'")

ORC_activity_progress_sentinf_gr = ORC_activity_progress_sentinf.groupby(['document', 'date']).count()

with pd.ExcelWriter('ORC_activity_progress_documents PD.xlsx') as writer:
    ORC_activity_progress_sentinf_gr.to_excel(writer, sheet_name='Documents PD')
# Out:
# <ipython-input-22-ac84daf396b4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_sentinf['pd1'] = ORC_activity_progress_sentinf.document.str.contains("-П-")
# <ipython-input-22-ac84daf396b4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ORC_activity_progress_sentinf['pd2'] = ORC_activity_progress_sentinf.document.str.contains("_P_")
# <ipython-input-22-ac84daf396b4>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
ORC_activity_progress_crttrans_split.columns = ['Проект', 'Стадия', 'Этап', 'Здание', 'Раздел', '5', '6']
ORC_activity_progress_crttrans_split_dot = ORC_activity_progress_crttrans_split['Раздел'].str.split('.',expand=True)
ORC_activity_progress_crttrans_split_dot.columns = ['Раздел', '5']
ORC_activity_progress_crttrans_split_dot = ORC_activity_progress_crttrans_split_dot.drop(['5'], axis = 1)
ORC_activity_progress_crttrans_split = ORC_activity_progress_crttrans_split.drop(['Раздел', '5', '6'], axis = 1)
ORC_activity_progress_crttrans_split = ORC_activity_progress_crttrans_split.join(ORC_activity_progress_crttrans_split_dot)
ORC_activity_progress_crttrans = ORC_activity_progress_crttrans.join(ORC_activity_progress_crttrans_split)
ORC_activity_progress_crttrans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-03e29a84474b> in <module>
# ----> 1 ORC_activity_progress_crttrans_split.columns = ['Проект', 'Стадия', 'Этап', 'Здание', 'Раздел', '5', '6']
#       2 ORC_activity_progress_crttrans_split_dot = ORC_activity_progress_crttrans_split['Раздел'].str.split('.',expand=True)
#       3 ORC_activity_progress_crttrans_split_dot.columns = ['Раздел', '5']
#       4 ORC_activity_progress_crttrans_split_dot = ORC_activity_progress_crttrans_split_dot.drop(['5'], axis = 1)
#       5 ORC_activity_progress_crttrans_split = ORC_activity_progress_crttrans_split.drop(['Раздел', '5', '6'], axis = 1)
#
# NameError: name 'ORC_activity_progress_crttrans_split' is not defined

# %%
with pd.ExcelWriter('ORC_activity_progress_crttrans.xlsx') as writer:
    ORC_activity_progress_crttrans.query("trans_td == True").to_excel(writer, sheet_name='Transmit')

# %%
ORC_activity_progress_vtbract = ORC_activity_progress.query("team == 'VTBR'").groupby(['name', 'Type Action']).count()
with pd.ExcelWriter('ORC_Activity report_VTBR_act.xlsx') as writer:  
    ORC_activity_progress_vtbract.to_excel(writer, sheet_name='VTBR Actions')

# %%
with pd.ExcelWriter('ORC_Activity report_All.xlsx') as writer:  
    ORC_activity_progress.to_excel(writer, sheet_name='ORC_activity_progress')
    ORC_Groupby_Team_Actions_Users_Sum.to_excel(writer, sheet_name='Users_Sum')
    ORC_Groupby_Team_Actions.to_excel(writer, sheet_name='Weekly_Activity')
    ORC_activity_progress_weekly_sum.to_excel(writer, sheet_name='Weekly_Activity_Sum')
