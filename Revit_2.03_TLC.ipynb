# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import datetime
import xlrd

# %%
# Установка функции

pr = 'TLC'
nb = '1'
ds = 'AR'
cat = 'door'

def ex_to_df(pr, nb, ds, cat, block = ''):
    global partname5
    partname5 = ""
    
#pr -project (TLC or ORC), nb - number of building (1, 2, 7.4 ...), ds - discipline (AR, KR, OV, VK ...), cat - category (door, wall)
    if (pr == "TLC"):
        sourcefolder = r"\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM"
        partname1 = r"\TLC_P_I_"        
        partname2 = r"_MK3_BIM_"
        partname4 = r"_Schedules"
        
        if (nb == '1'):
            sfbuilding = r"\1_Бизнес центр"
            partname1 = '\TLC_P_II_'
        elif (nb == '2'):
            sfbuilding = r"\2_АБК"
            partname1 = '\TLC_P_II_'
        elif (nb == '2.1'):
            sfbuilding = r"2.1_Офисное модульное здание"    
        elif (nb == '3'):
            sfbuilding = r"3_Гараж"
            partname1 = '\TLC_P_II_'
        elif (nb == '4'):
            sfbuilding = r"4_Мастерская" 
            partname1 = '\TLC_P_II_'            
        elif (nb == '5.1'):
            sfbuilding = r"5.1_КПП1"            
        elif (nb == '5.2'):
            sfbuilding = r"5.3_КПП2жд"              
        elif (nb == '5.3'):
            sfbuilding = r"5.3_КПП3" 
            partname1 = '\TLC_P_II_'
        elif (nb == '5.4'):
            sfbuilding = r"5.4_КПП4"  
            partname1 = '\TLC_P_II_'
        elif (nb == '5.5'):
            sfbuilding = r"5.5_КПП7жд"    
        elif (nb == '7.2'):
            sfbuilding = r"7.2" 
        elif (nb == '7.4'):
            sfbuilding = r"\7.4_Склад"
            partname1 = '\TLC_P_III_'
            partname5 = r". Блок " + block
        elif (nb == '8.1'):
            sfbuilding = r"8.1_РТП"  
        elif (nb == '11.5'):
            sfbuilding = r"\11.5_ТП"
            partname1 = '\TLC_P_II_'
            partname2 = r".1_MK3_BIM_"
        elif (nb == '11.5.1'):
            sfbuilding = r"\11.5.1_ТП"  
        elif (nb == '11.5.3'):
            sfbuilding = r"\11.5.3"
        elif (nb == '11.5.4'):
            sfbuilding = r"\11.5.4"  
            partname1 = '\TLC_P_II_'            
        elif (nb == '11.6.2'):
            sfbuilding = r"\11.6.2"              
        elif (nb == '14.1'):
            sfbuilding = r"\14.1_Котельная1"
            partname1 = '\TLC_P_II_'
        elif (nb == '14.2'):
            sfbuilding = r"\14.2_Котельная2"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.1'):
            sfbuilding = r"\15.1_СВК"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.2'):
            sfbuilding = r"\15.2_Склад ИМ"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.3'):
            sfbuilding = r"\15.3_Склад ПМ"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4'):
            sfbuilding = r"\15.4_Склад МК"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4.1'):
            sfbuilding = r"\15.4_Склад МК\15.4.1"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4.2'):
            sfbuilding = r"\15.4_Склад МК\15.4.2"
            partname1 = '\TLC_P_II_'            
        elif (nb == '15.5'):
            sfbuilding = r"\15.5_Склад ТГ"
            partname1 = '\TLC_P_II_'
            partname5 = r". Блок " + block
        elif (nb == '15.6'):
            sfbuilding = r"\15.6_Склад АТ" 
            partname1 = '\TLC_P_II_'
        elif (nb == '15.7'):
            sfbuilding = r"\15.7_Склад ТШП"     
            partname5 = r". Блок " + block 
            partname1 = '\TLC_P_IV_'
            partname5 = r". Блок " + block  
        elif (nb == '18'):
            sfbuilding = r"\18"            
        elif (nb == '21'):
            sfbuilding = r"21"
        elif (nb == 'NS'):
            sfbuilding = r"\External Networks"     
            partname1 = 'TLC_P_I-IV_'            

        if (ds == 'AR'):
            partname3 = r"AR_Архитектура"
            category = 'AR'
        elif (ds == 'KR'):
            partname3 = r"KR_Конструктив"
            category = 'KR'
        elif (ds == 'ES'):
            partname3 = r"ES_Электроснабжение"
            category = 'ES'
        elif (ds == 'OV'):
            partname3 = r"OV_ОВиК"
        elif (ds == 'VK'):
            partname3 = r"VK_Водоснабжение и канализация"
        elif (ds == 'PS'):
            partname3 = r"PS_Пожарная сигнализация"
            category = 'PS'
        elif (ds == 'PT'):
            partname3 = r"PT_Пожаротушение"
            category = 'PT' 
        elif (ds == 'SS'):
            partname3 = r"SS_Слаботочные системы"
            category = 'SS'             
        elif (ds == 'TX'):
            partname3 = r"TX_Технология"
            category = 'TX' 
        elif (ds == 'GS'):
            partname3 = r"GS_Газоснабжение"
            category = 'GS' 
        elif (ds == 'NESP'):
            partname3 = r"NES_Сильные токи"
            category = 'NESP'
        elif (ds == 'NESW'):
            partname3 = r"NES_Слабые токи"
            category = 'NESPW'  
        elif (ds == 'NVKV'):
            partname3 = r"NVK_Водоснабжение"
            category = 'NVKV'            
        elif (ds == 'NVKK'):
            partname3 = r"NVK_Канализация"
            category = 'NVKK'            
        elif (ds == 'TS'):
            partname3 = r"TS_Тепловая сеть"
            category = 'TS'      
        elif (ds == 'DER'):
            partname3 = r"ОЗДС_Дератизация"
            category = 'DER'            
            
    else:
        sf = 'Undefined'

    if (cat == 'Multi-Category MT'):
        nsheet = r"VTBR_Multi-Category MT"
    elif (cat == 'Multi-Category'):
        nsheet = r"VTBR_VTBR_Multi-Category"
    elif (cat == 'Ceiling'):
        nsheet = r"VTBR_Ceiling"
    elif (cat == 'Casework'):
        nsheet = r"VTBR_Casework"         
    elif (cat == 'Panel'):
        nsheet = r"VTBR_Panel"    
    elif (cat == 'Door'):
        nsheet = r"VTBR_Door"    
    elif (cat == 'Floor'):
        nsheet = r"VTBR_Floor"
    elif (cat == 'Furniture'):
        nsheet = r"VTBR_Furniture"
    elif (cat == 'Furniture System'):
        nsheet = r"VTBR_Furniture System"
    elif (cat == 'Roof'):
        nsheet = r"VTBR_Roof"    
    elif (cat == 'Room'):
        nsheet = r"VTBR_Room" 
    elif (cat == 'Window'):
        nsheet = r"VTBR_Window"
    elif (cat == 'Site'):
        nsheet = r"VTBR_Site"
    elif (cat == 'Specialty Equipment'):
        nsheet = r"VTBR_Specialty Equipment" 

    elif (cat == 'Structural Column'):
        nsheet = r"VTBR_Structural Column"
    elif (cat == 'Structural Foundation'):
        nsheet = r"VTBR_Structural Foundation"
    elif (cat == 'Structural Framing'):
        nsheet = r"VTBR_Structural Framing"
    elif (cat == 'Stairs MT'):
        nsheet = r"VTBR_Stairs MT"    
    elif (cat == 'Wall'):
        nsheet = r"VTBR_Wall"
    elif (cat == 'Structural Connection'):
        nsheet = r"VTBR_Structural Connection"

    elif (cat == 'Electrical Equipment'):
        nsheet = r"VTBR_Electrical Equipment"    
    elif (cat == 'Cable Tray Fitting'):
        nsheet = r"VTBR_Cable Tray Fitting"
    elif (cat == 'Cable Tray'):
        nsheet = r"VTBR_Cable Tray"
    elif (cat == 'Fire Alarm Device'):
        nsheet = r"VTBR_Fire Alarm Device"    
    elif (cat == 'Nurse Call Device'):
        nsheet = r"VTBR_Nurse Call Device" 
        
    elif (cat == 'Pipe'):
        nsheet = r"VTBR_Pipe"       
    elif (cat == 'Flex Pipe'):
        nsheet = r"VTBR_Flex Pipe"   
    elif (cat == 'Pipe Accessory'):
        nsheet = r"VTBR_Pipe Accessory"           
    elif (cat == 'Pipe Fitting'):
        nsheet = r"VTBR_Pipe Fitting"  
    elif (cat == 'Plumbing Fixture'):
        nsheet = r"VTBR_Plumbing Fixture"
    elif (cat == 'Mechanical Equipment'):
        nsheet = r"VTBR_Mechanical Equipment"          
    elif (cat == 'Sprinkler'):
        nsheet = r"VTBR_Sprinkler"           
    elif (cat == 'Wall'):
        nsheet = r"VTBR_Wall"           
        
        
    pathfile = sourcefolder + r"/" + sfbuilding + partname1 + nb + partname2 + partname3 + partname5 + partname4 + r".xlsx"
    
    df = pd.read_excel(pathfile, sheet_name = nsheet)
    
    if (df.size == 0):
        df = pd.DataFrame(columns=['Family and Type', 'Count'])
        
    df_mc = pd.read_excel(pathfile, sheet_name = 'VTBR_Multi-Category')
    df_mcmt = pd.read_excel(pathfile, sheet_name = 'VTBR_Multi-Category MT')
    df_m = pd.concat([df_mcmt,df_mc], join = "outer").fillna(0)
    if (cat == 'Multi-Category MT'):
        df = df_mcmt
    elif (cat == 'Multi-Category'):
        df = df_mc
    elif (cat == 'Room'):
        df = pd.read_excel(pathfile, sheet_name = 'VTBR_Room')
    else:
        df.insert(0, 'Category', (df.merge(df_m, on = 'Family and Type', how = 'left').Category))
    df.fillna(0, inplace = True)
    return df

# %%
# Установка функции
pathfolder = r"\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM"
pr = 'TLC'
nb = '1'
ds = 'AR'
partname5 = ""
sch_comm = pd.read_excel(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\0_Schedules\TLC_P_I_X_MK3_BIM_Комментарии.xlsx')
sch_comm = sch_comm.drop(['Discipline','Category'],axis=1)
#pr -project (TLC or ORC), nb - number of building (1, 2, 7.4 ...), ds - discipline (AR, KR, OV, VK ...), cat - category (door, wall)    
def ex_to_df_cnc(pr, nb, ds, block = ''):
    global partname5
    partname5 = ""
    
    if (pr == "TLC"):
        sourcefolder = r"\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM"
        partname1 = r"\TLC_P_I_"        
        partname2 = r"_MK3_BIM_"
        partname4 = r"_Schedules"

        if (nb == '1'):
            sfbuilding = r"\1_Бизнес центр"
            partname1 = '\TLC_P_II_'
        elif (nb == '2'):
            sfbuilding = r"\2_АБК"
            partname1 = '\TLC_P_II_'
        elif (nb == '2.1'):
            sfbuilding = r"2.1_Офисное модульное здание"            
        elif (nb == '3'):
            sfbuilding = r"3_Гараж"
            partname1 = '\TLC_P_II_'
        elif (nb == '4'):
            sfbuilding = r"4_Мастерская" 
            partname1 = '\TLC_P_II_'            
        elif (nb == '5.1'):
            sfbuilding = r"5.1_КПП1"            
        elif (nb == '5.2'):
            sfbuilding = r"5.2_КПП2жд"              
        elif (nb == '5.3'):
            sfbuilding = r"5.3_КПП3" 
            partname1 = '\TLC_P_II_'            
        elif (nb == '5.4'):
            sfbuilding = r"5.4_КПП4"   
            partname1 = '\TLC_P_II_'
        elif (nb == '5.5'):
            sfbuilding = r"5.5_КПП7жд" 
        elif (nb == '7.2'):
            sfbuilding = r"7.2"             
        elif (nb == '7.4'):
            sfbuilding = r"\7.4_Склад" 
            partname1 = '\TLC_P_III_'            
            partname5 = r". Блок " + block
        elif (nb == '8.1'):
            sfbuilding = r"8.1_РТП"    
        elif (nb == '11.5'):
            sfbuilding = r"\11.5_ТП"
            partname1 = '\TLC_P_II_'
            partname2 = r".1_MK3_BIM_"
        elif (nb == '11.5.1'):
            sfbuilding = r"\11.5.1_ТП"  
        elif (nb == '11.5.3'):
            sfbuilding = r"\11.5.3"
        elif (nb == '11.5.4'):
            sfbuilding = r"\11.5.4"
            partname1 = '\TLC_P_II_'            
        elif (nb == '11.6.2'):
            sfbuilding = r"\11.6.2"             
        elif (nb == '14.1'):
            sfbuilding = r"\14.1_Котельная1"
            partname1 = '\TLC_P_II_'
        elif (nb == '14.2'):
            sfbuilding = r"\14.2_Котельная2"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.1'):
            sfbuilding = r"\15.1_СВК"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.2'):
            sfbuilding = r"\15.2_Склад ИМ"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.3'):
            sfbuilding = r"\15.3_Склад ПМ"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4'):
            sfbuilding = r"\15.4_Склад МК"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4.1'):
            sfbuilding = r"\15.4_Склад МК\15.4.1"
            partname1 = '\TLC_P_II_'
        elif (nb == '15.4.2'):
            sfbuilding = r"\\15.4_Склад МК\15.4.2"
            partname1 = '\TLC_P_II_'            
        elif (nb == '15.5'):
            sfbuilding = r"\15.5_Склад ТГ"
            partname5 = r". Блок " + block
            partname1 = '\TLC_P_II_'
        elif (nb == '15.6'):
            sfbuilding = r"\15.6_Склад АТ" 
            partname1 = '\TLC_P_II_'
        elif (nb == '15.7'):
            sfbuilding = r"\15.7_Склад ТШП"     
            partname5 = r". Блок " + block  
            partname1 = '\TLC_P_IV_'
        elif (nb == '18'):
            sfbuilding = r"\18"              
        elif (nb == '21'):
            sfbuilding = r"21"
        elif (nb == 'NS'):
            sfbuilding = r"\External Networks"     
            partname1 = '\TLC_P_I-IV'              

        if (ds == 'AR'):
            partname3 = r"AR_Архитектура"
        elif (ds == 'KR'):
            partname3 = r"KR_Конструктив"
        elif (ds == 'ES'):
            partname3 = r"ES_Электроснабжение"
        elif (ds == 'OV'):
            partname3 = r"OV_ОВиК"  
        elif (ds == 'VK'):
            partname3 = r"VK_Водоснабжение и канализация"
        elif (ds == 'PS'):
            partname3 = r"PS_Пожарная сигнализация"
        elif (ds == 'PT'):
            partname3 = r"PT_Пожаротушение"
        elif (ds == 'SS'):
            partname3 = r"SS_Слаботочные системы"
        elif (ds == 'GS'):
            partname3 = r"GS_Газоснабжение"
            category = 'GS'
        elif (ds == 'TX'):
            partname3 = r"TX_Технология"
        
        elif (ds == 'NGS'):
            partname3 = r"GS_Газоснабжение"
            category = 'NGS' 
        elif (ds == 'NESP'):
            partname3 = r"NES_Сильные токи"
            category = 'NESP'
        elif (ds == 'NESW'):
            partname3 = r"NES_Слабые токи"
            category = 'NESPW'  
        elif (ds == 'NVKV'):
            partname3 = r"NVK_Водоснабжение"
            category = 'NVKV'            
        elif (ds == 'NVKK'):
            partname3 = r"NVK_Канализация"
            category = 'NVKK'            
        elif (ds == 'NTS'):
            partname3 = r"TS_Тепловая сеть"
            category = 'NTS' 
        elif (ds == 'DER'):
            partname3 = r"ОЗДС_Дератизация"
            category = 'DER'  

    pathfile = sourcefolder + r"/" + sfbuilding + partname1 + nb + partname2 + partname3 + partname5 + partname4 + r".xlsx"
    
    if nb == 'NS':
        pathfile = sourcefolder + r"/" + sfbuilding + partname1 + partname2 + partname3 + partname5 + partname4 + r".xlsx"

    xls = xlrd.open_workbook(pathfile, on_demand=True)
    listsht = xls.sheet_names()
    listdf = xls.sheet_names()
    leng = len(listdf)  

    #Заполнение списка датафремов 
    for i in range(leng): 
        listdf[i] = pd.read_excel(pathfile, sheet_name = listdf[i])

    #Заполнение нулевых спецификаций
    for i in range(leng): 
        if (listdf[i].size == 0):
            listdf[i] = pd.DataFrame(columns=['Family and Type', 'Count'])

    #Установка мульти категорий           
    df_mc = pd.read_excel(pathfile, sheet_name = 'VTBR_Multi-Category')
    df_mcmt = pd.read_excel(pathfile, sheet_name = 'VTBR_Multi-Category MT')
    #Объединение мульти и мульти материал
    df_m = pd.concat([df_mcmt,df_mc], join = "outer").fillna(0)
    #Установка датафр помещений  
    if 'VTBR_Room' in listsht:
        df_room = pd.read_excel(pathfile, sheet_name = 'VTBR_Room')

    #Удаление мульти спец (за хештегод - перемещение специв начало, в конец)  
    for i in range(len(listdf)):         
        if (listdf[i].equals(df_mcmt) == True):
            listdf.append(listdf[i])
            del listdf[i]
    for i in range(len(listdf)):           
        if (listdf[i].equals(df_mc) == True):
            listdf.append(listdf[i])
            del listdf[i]
    #listdf.insert(0 , listdf[-2])
    #listdf.insert(0 , listdf[-1])
    del listdf[-2:]


    #Удаление датафр помещений  
    if 'VTBR_Room' in listsht:    
        for i in range(len(listdf)):         
            if (listdf[i].equals(df_room) == True):
                listdf.append(listdf[i])
                del listdf[i]
        del listdf[-1:]
    
    for i in range(len(listdf)):          
        listdf[i].insert(0, 'Category', (listdf[i].merge(df_m, on = 'Family and Type', how = 'left').Category))
        listdf[i].fillna(0, inplace = True)  
    
    df_cnc = pd.concat([listdf[0]
                           ], join = "outer").fillna(0)
    for i in range(1, len(listdf)):
        df_cnc = pd.concat([df_cnc,
                            listdf[i]
                           ], join = "outer").fillna(0)
        
    df_cnc.reset_index(inplace=True, drop=True)
    df_cnc.insert(0, 'Discipline', ds)
#Перенос количества в конец   
    df_cnc.insert(6, 'Count1', df_cnc['Count'])
#    len(df_cnc.columns)
    df_cnc.drop(['Count'],axis=1, inplace=True)
    df_cnc.rename(columns = {"Count1" : "Count"}, inplace=True)
    
    #Объединение с таблице комментариев     
    df_cnc = df_cnc.merge(sch_comm, on = 'Family and Type', how = 'left')
    
    return df_cnc

# %%
# External Networks
# Загрузка спек по дисциплинам
sch_NGS = ex_to_df_cnc('TLC', 'NS', 'NGS')
sch_NESP = ex_to_df_cnc('TLC', 'NS', 'NESP')
sch_NESW = ex_to_df_cnc('TLC', 'NS', 'NESW')
sch_NVKV = ex_to_df_cnc('TLC', 'NS', 'NVKV')
sch_NVKK = ex_to_df_cnc('TLC', 'NS', 'NVKK')
sch_NTS = ex_to_df_cnc('TLC', 'NS', 'NTS')

sch_NGS_gr = sch_NGS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch_NESP_gr = sch_NESP.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch_NESW_gr = sch_NESW.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch_NVKV_gr = sch_NVKV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch_NVKK_gr = sch_NVKK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch_NTSS_gr = sch_NTS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})

sch_NS_mdiscipline = pd.concat([sch_NGS, 
                        sch_NESP,
                        sch_NESW,
                        sch_NVKV,                              
                        sch_NVKK,
                        sch_NTS
                     ], join = "outer").fillna(0)
sch_NS_mdiscipline.reset_index(inplace=True, drop=True)
sch_NS_mdiscipline.insert(0, 'Building', 'NS')

# Общая спека сгрупированная
sch_NS_mdiscipline_gr = pd.concat([sch_NGS_gr, 
                        sch_NESP_gr,
                        sch_NESW_gr,
                        sch_NVKV_gr,                                 
                        sch_NVKK_gr, 
                        sch_NTSS_gr        
                     ], join = "outer").fillna(0)
sch_NS_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch_NS_mdiscipline_gr.insert(0, 'Building', 'NS')

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\External Networks\01_Schedules\TLC_P_I-IV_MK3_BIM_NS_Наружные сети_Schedules_' + ct + '.xlsx') as writer:  
    sch_NS_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch_NS_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch_NGS.to_excel(writer, sheet_name='НС Газ')
    sch_NESP.to_excel(writer, sheet_name='НС Сильные токи')
    sch_NESW.to_excel(writer, sheet_name='НС Слабые токи')
    sch_NVKV.to_excel(writer, sheet_name='НС Водснаб')    
    sch_NVKK.to_excel(writer, sheet_name='НС Канал') 
    sch_NTS.to_excel(writer, sheet_name='НС ТС')

# %%
# 1 Building
# Загрузка спек по дисциплинам
sch1_AR = ex_to_df_cnc('TLC', '1', 'AR')
sch1_KR = ex_to_df_cnc('TLC', '1', 'KR')
sch1_ES = ex_to_df_cnc('TLC', '1', 'ES')
sch1_OV = ex_to_df_cnc('TLC', '1', 'OV')
sch1_VK = ex_to_df_cnc('TLC', '1', 'VK')
sch1_SS = ex_to_df_cnc('TLC', '1', 'SS')
sch1_PS = ex_to_df_cnc('TLC', '1', 'PS')
sch1_PT = ex_to_df_cnc('TLC', '1', 'PT')
sch1_TX = ex_to_df_cnc('TLC', '1', 'TX')


sch1_AR_room = ex_to_df('TLC', '1', 'AR', 'Room')
#Группировка спек по дисц
sch1_AR_gr = sch1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch1_KR_gr = sch1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch1_ES_gr = sch1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch1_OV_gr = sch1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch1_VK_gr = sch1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch1_SS_gr = sch1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch1_PS_gr = sch1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch1_PT_gr = sch1_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch1_TX_gr = sch1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch1_mdiscipline = pd.concat([sch1_AR, 
                        sch1_KR,
                        sch1_ES,
                        sch1_OV,
                        sch1_VK,
                        sch1_SS,                              
                        sch1_PS,
                        sch1_PT,                              
                        sch1_TX
                     ], join = "outer").fillna(0)
sch1_mdiscipline.reset_index(inplace=True, drop=True)
sch1_mdiscipline.insert(0, 'Building', '1')

# Общая спека по зданию сгрупированная
sch1_mdiscipline_gr = pd.concat([sch1_AR_gr, 
                        sch1_KR_gr,
                        sch1_ES_gr,
                        sch1_OV_gr,
                        sch1_VK_gr,
                        sch1_SS,                                 
                        sch1_PS_gr,
                        sch1_PT_gr,                                 
                        sch1_TX_gr        
                     ], join = "outer").fillna(0)
sch1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch1_mdiscipline_gr.insert(0, 'Building', '1')

# Сбор всех помещений в здании
sch1_room = pd.concat([sch1_AR_room, 
                     ], join = "outer").fillna(0)
sch1_room.reset_index(inplace=True, drop=True)
sch1_room.insert(0, 'Building', '1')
sch1_room.Area = pd.to_numeric(sch1_room.Area, errors='coerce')
sch1_room.Volume = pd.to_numeric(sch1_room.Volume, errors='coerce')
sch1_room.Perimeter = pd.to_numeric(sch1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch1_room_gr = sch1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\1_Бизнес центр\01_Schedules\TLC_P_I_1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch1_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch1_OV.to_excel(writer, sheet_name='OV_Schedule') 
    sch1_VK.to_excel(writer, sheet_name='VK_Schedule')
    sch1_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch1_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch1_PT.to_excel(writer, sheet_name='PT_Schedule')     
    sch1_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch1_room.to_excel(writer, sheet_name='All_Rooms')
    sch1_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 2 Building
# Загрузка спек по дисциплинам
sch2_AR = ex_to_df_cnc('TLC', '2', 'AR')
sch2_AR_room = ex_to_df('TLC', '2', 'AR', 'Room')

sch2_KR = ex_to_df_cnc('TLC', '2', 'KR')
sch2_OV = ex_to_df_cnc('TLC', '2', 'OV')
sch2_VK = ex_to_df_cnc('TLC', '2', 'VK')
sch2_ES = ex_to_df_cnc('TLC', '2', 'ES')
sch2_SS = ex_to_df_cnc('TLC', '2', 'SS')
sch2_PS = ex_to_df_cnc('TLC', '2', 'PS')
sch2_PT = ex_to_df_cnc('TLC', '2', 'PT')
sch2_TX = ex_to_df_cnc('TLC', '2', 'TX')

#Группировка спек по дисц
sch2_AR_gr = sch2_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch2_KR_gr = sch2_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch2_ES_gr = sch2_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_SS_gr = sch2_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_PS_gr = sch2_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_PT_gr = sch2_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_OV_gr = sch2_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_VK_gr = sch2_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch2_TX_gr = sch2_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch2_mdiscipline = pd.concat([sch2_AR, 
                        sch2_KR,
                        sch2_OV,  
                        sch2_VK,                                  
                        sch2_ES,
                        sch2_SS,                              
                        sch2_PS,
                        sch2_PT,                              
                        sch2_TX
                     ], join = "outer").fillna(0)
sch2_mdiscipline.reset_index(inplace=True, drop=True)
sch2_mdiscipline.insert(0, 'Building', '2')

# Общая спека по зданию сгрупированная
sch2_mdiscipline_gr = pd.concat([sch2_AR_gr, 
                        sch2_KR_gr,
                        sch2_OV_gr,    
                        sch2_VK_gr,   
                        sch2_ES_gr,
                        sch2_SS,                                 
                        sch2_PS_gr,
                        sch2_PT_gr,                                 
                        sch2_TX_gr        
                     ], join = "outer").fillna(0)
sch2_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch2_mdiscipline_gr.insert(0, 'Building', '2')

# Сбор всех помещений в здании
sch2_room = pd.concat([sch2_AR_room, 
                     ], join = "outer").fillna(0)
sch2_room.reset_index(inplace=True, drop=True)
sch2_room.insert(0, 'Building', '2')
sch2_room.Area = pd.to_numeric(sch2_room.Area, errors='coerce')
sch2_room.Volume = pd.to_numeric(sch2_room.Volume, errors='coerce')
sch2_room.Perimeter = pd.to_numeric(sch2_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch2_room_gr = sch2_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\2_АБК\01_Schedules\TLC_P_I_2_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch2_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch2_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch2_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch2_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch2_ES.to_excel(writer, sheet_name='ES_Schedule')  
    sch2_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch2_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch2_VK.to_excel(writer, sheet_name='VK_Schedule')
    sch2_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch2_PT.to_excel(writer, sheet_name='PT_Schedule')    
    sch2_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch2_room.to_excel(writer, sheet_name='All_Rooms')
    sch2_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 2.1 Building
# Загрузка спек по дисциплинам
#sch2d1_AR = ex_to_df_cnc('TLC', '2.1', 'AR')
#sch2d1_AR_room = ex_to_df('TLC', '2.1', 'AR', 'Room')
sch2d1_KR = ex_to_df_cnc('TLC', '2.1', 'KR')


#Группировка спек по дисц
#sch2d1_AR_gr = sch2d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch2d1_KR_gr = sch2d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})


# Общая спека по зданию
sch2d1_mdiscipline = pd.concat([sch2d1_KR
                     ], join = "outer").fillna(0)
sch2d1_mdiscipline.reset_index(inplace=True, drop=True)
sch2d1_mdiscipline.insert(0, 'Building', '2.1')

# Общая спека по зданию сгрупированная
sch2d1_mdiscipline_gr = pd.concat([sch2d1_KR_gr
                     ], join = "outer").fillna(0)
sch2d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch2d1_mdiscipline_gr.insert(0, 'Building', '2.1')

# Сбор всех помещений в здании
#sch2d1_room = pd.concat([sch2d1_AR_room 
#                     ], join = "outer").fillna(0)
#sch2d1_room.reset_index(inplace=True, drop=True)
#sch2d1_room.insert(0, 'Building', '2.1')
#sch2d1_room.Area = pd.to_numeric(sch2d1_room.Area, errors='coerce')
#sch2d1_room.Volume = pd.to_numeric(sch2d1_room.Volume, errors='coerce')
#sch2d1_room.Perimeter = pd.to_numeric(sch2d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch2d1_room_gr = sch2d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\2.1_Офисное модульное здание\01_Schedules\TLC_P_I_2.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch2d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch2d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch2d1_KR.to_excel(writer, sheet_name='KR_Schedule')

# %%
# 3 Building
# Загрузка спек по дисциплинам
sch3_AR = ex_to_df_cnc('TLC', '3', 'AR')
sch3_AR_room = ex_to_df('TLC', '3', 'AR', 'Room')
sch3_KR = ex_to_df_cnc('TLC', '3', 'KR')
sch3_ES = ex_to_df_cnc('TLC', '3', 'ES')
sch3_VK = ex_to_df_cnc('TLC', '3', 'VK')
sch3_OV = ex_to_df_cnc('TLC', '3', 'OV')
sch3_PS = ex_to_df_cnc('TLC', '3', 'PS')
sch3_SS = ex_to_df_cnc('TLC', '3', 'SS')
sch3_TX = ex_to_df_cnc('TLC', '3', 'TX')

#Группировка спек по дисц
sch3_AR_gr = sch3_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch3_KR_gr = sch3_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch3_ES_gr = sch3_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch3_OV_gr = sch3_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch3_VK_gr = sch3_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch3_SS_gr = sch3_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch3_PS_gr = sch3_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch3_TX_gr = sch3_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
# Общая спека по зданию
sch3_mdiscipline = pd.concat([sch3_AR, 
                            sch3_KR,
                            sch3_OV,
                            sch3_VK,                              
                            sch3_ES,
                            sch3_SS,
                            sch3_PS,                              
                            sch3_TX                              
                     ], join = "outer").fillna(0)
sch3_mdiscipline.reset_index(inplace=True, drop=True)
sch3_mdiscipline.insert(0, 'Building', '3')

# Общая спека по зданию сгрупированная
sch3_mdiscipline_gr = pd.concat([sch3_AR_gr, 
                            sch3_KR_gr,
                            sch3_ES_gr,
                            sch3_OV_gr,                                  
                            sch3_VK_gr,                                 
                            sch3_SS_gr, 
                            sch3_PS_gr, 
                            sch3_TX_gr                                  
                     ], join = "outer").fillna(0)
sch3_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch3_mdiscipline_gr.insert(0, 'Building', '3')

# Сбор всех помещений в здании
sch3_room = pd.concat([sch3_AR_room, 
                     ], join = "outer").fillna(0)
sch3_room.reset_index(inplace=True, drop=True)
sch3_room.insert(0, 'Building', '3')
sch3_room.Area = pd.to_numeric(sch3_room.Area, errors='coerce')
sch3_room.Volume = pd.to_numeric(sch3_room.Volume, errors='coerce')
sch3_room.Perimeter = pd.to_numeric(sch3_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch3_room_gr = sch3_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\3_Гараж\01_Schedules\TLC_P_I_3_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch3_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch3_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch3_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch3_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch3_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch3_OV.to_excel(writer, sheet_name='OV_Schedule')    
    sch3_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch3_SS.to_excel(writer, sheet_name='SS_Schedule')
    sch3_PS.to_excel(writer, sheet_name='PS_Schedule')    
    sch3_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch3_room.to_excel(writer, sheet_name='All_Rooms')
    sch3_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 4 Building
# Загрузка спек по дисциплинам
sch4_AR = ex_to_df_cnc('TLC', '4', 'AR')
sch4_AR_room = ex_to_df('TLC', '4', 'AR', 'Room')
sch4_KR = ex_to_df_cnc('TLC', '4', 'KR')
sch4_ES = ex_to_df_cnc('TLC', '4', 'ES')
sch4_OV = ex_to_df_cnc('TLC', '4', 'OV')
sch4_VK = ex_to_df_cnc('TLC', '4', 'VK')
sch4_PS = ex_to_df_cnc('TLC', '4', 'PS')
sch4_SS = ex_to_df_cnc('TLC', '4', 'SS')
sch4_TX = ex_to_df_cnc('TLC', '4', 'TX')

#Группировка спек по дисц
sch4_AR_gr = sch4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch4_KR_gr = sch4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch4_ES_gr = sch4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch4_OV_gr = sch4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch4_VK_gr = sch4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch4_SS_gr = sch4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch4_PS_gr = sch4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch4_TX_gr = sch4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch4_mdiscipline = pd.concat([sch4_AR, 
                        sch4_KR,
                        sch4_ES,
                        sch4_OV,
                        sch4_VK,                              
                        sch4_PS,
                        sch4_SS,                              
                        sch4_TX
                     ], join = "outer").fillna(0)
sch4_mdiscipline.reset_index(inplace=True, drop=True)
sch4_mdiscipline.insert(0, 'Building', '4')

# Общая спека по зданию сгрупированная
sch4_mdiscipline_gr = pd.concat([sch4_AR_gr, 
                        sch4_KR_gr,
                        sch4_ES_gr,
                        sch4_OV_gr,
                        sch4_VK_gr,                                 
                        sch4_PS_gr,
                        sch4_SS_gr,                                 
                        sch4_TX_gr        
                     ], join = "outer").fillna(0)
sch4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch4_mdiscipline_gr.insert(0, 'Building', '4')

# Сбор всех помещений в здании
sch4_room = pd.concat([sch4_AR_room, 
                     ], join = "outer").fillna(0)
sch4_room.reset_index(inplace=True, drop=True)
sch4_room.insert(0, 'Building', '4')
sch4_room.Area = pd.to_numeric(sch4_room.Area, errors='coerce')
sch4_room.Volume = pd.to_numeric(sch4_room.Volume, errors='coerce')
sch4_room.Perimeter = pd.to_numeric(sch4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch4_room_gr = sch4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\4_Мастерская\01_Schedules\TLC_P_I_4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch4_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch4_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch4_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch4_PS.to_excel(writer, sheet_name='PS_Schedule')
    sch4_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch4_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch4_room.to_excel(writer, sheet_name='All_Rooms')
    sch4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 5.1 Building
# Загрузка спек по дисциплинам
sch5d1_AR = ex_to_df_cnc('TLC', '5.1', 'AR')
sch5d1_AR_room = ex_to_df('TLC', '5.1', 'AR', 'Room')
sch5d1_KR = ex_to_df_cnc('TLC', '5.1', 'KR')
sch5d1_ES = ex_to_df_cnc('TLC', '5.1', 'ES')
sch5d1_OV = ex_to_df_cnc('TLC', '5.1', 'OV')
sch5d1_VK = ex_to_df_cnc('TLC', '5.1', 'VK')
sch5d1_SS = ex_to_df_cnc('TLC', '5.1', 'SS')
    #sch5d1_PS = ex_to_df_cnc('TLC', '5.1', 'PS')
sch5d1_TX = ex_to_df_cnc('TLC', '5.1', 'TX')

#Группировка спек по дисц
sch5d1_AR_gr = sch5d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch5d1_KR_gr = sch5d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch5d1_ES_gr = sch5d1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d1_OV_gr = sch5d1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d1_VK_gr = sch5d1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d1_SS_gr = sch5d1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch5d1_PS_gr = sch5d1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d1_TX_gr = sch5d1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch5d1_mdiscipline = pd.concat([sch5d1_AR, 
                        sch5d1_KR,
                        sch5d1_ES,
                        sch5d1_OV,   
                        sch5d1_VK, 
                        sch5d1_SS,                                 
    #                        sch5d1_PS,
                        sch5d1_TX
                     ], join = "outer").fillna(0)
sch5d1_mdiscipline.reset_index(inplace=True, drop=True)
sch5d1_mdiscipline.insert(0, 'Building', '5.1')

# Общая спека по зданию сгрупированная
sch5d1_mdiscipline_gr = pd.concat([sch5d1_AR_gr, 
                        sch5d1_KR_gr,
                        sch5d1_ES_gr,
                        sch5d1_OV_gr,   
                        sch5d1_VK_gr,  
                        sch5d1_SS_gr,                                   
    #                        sch5d1_PS_gr, 
                        sch5d1_TX_gr        
                     ], join = "outer").fillna(0)
sch5d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch5d1_mdiscipline_gr.insert(0, 'Building', '5.1')

# Сбор всех помещений в здании
sch5d1_room = pd.concat([sch5d1_AR_room, 
                     ], join = "outer").fillna(0)
sch5d1_room.reset_index(inplace=True, drop=True)
sch5d1_room.insert(0, 'Building', '5.1')
sch5d1_room.Area = pd.to_numeric(sch5d1_room.Area, errors='coerce')
sch5d1_room.Volume = pd.to_numeric(sch5d1_room.Volume, errors='coerce')
sch5d1_room.Perimeter = pd.to_numeric(sch5d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch5d1_room_gr = sch5d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\5.1_КПП1\01_Schedules\TLC_P_I_5.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch5d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch5d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch5d1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch5d1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch5d1_ES.to_excel(writer, sheet_name='ES_Schedule')  
    sch5d1_OV.to_excel(writer, sheet_name='OV_Schedule')    
    sch5d1_VK.to_excel(writer, sheet_name='VK_Schedule')
    sch5d1_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch5d1_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch5d1_room.to_excel(writer, sheet_name='All_Rooms')
    sch5d1_room_gr.to_excel(writer, sheet_name='Rooms by function')
#    sch5d1_ES.to_excel(writer, sheet_name='ES_Schedule')   
#    sch5d1_PS.to_excel(writer, sheet_name='PS_Schedule')

# %%
# 5.3 Building
# Загрузка спек по дисциплинам
sch5d3_AR = ex_to_df_cnc('TLC', '5.3', 'AR')
sch5d3_AR_room = ex_to_df('TLC', '5.3', 'AR', 'Room')
sch5d3_KR = ex_to_df_cnc('TLC', '5.3', 'KR')
sch5d3_OV = ex_to_df_cnc('TLC', '5.3', 'OV')
sch5d3_VK = ex_to_df_cnc('TLC', '5.3', 'VK')
sch5d3_ES = ex_to_df_cnc('TLC', '5.3', 'ES')
sch5d3_SS = ex_to_df_cnc('TLC', '5.3', 'SS')
sch5d3_PS = ex_to_df_cnc('TLC', '5.3', 'PS')
sch5d3_TX = ex_to_df_cnc('TLC', '5.3', 'TX')

#Группировка спек по дисц
sch5d3_AR_gr = sch5d3_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch5d3_KR_gr = sch5d3_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch5d3_OV_gr = sch5d3_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d3_VK_gr = sch5d3_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d3_ES_gr = sch5d3_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d3_SS_gr = sch5d3_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d3_PS_gr = sch5d3_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch5d3_TX_gr = sch5d3_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch5d3_mdiscipline = pd.concat([sch5d3_AR, 
                        sch5d3_KR,
                        sch5d3_ES,
                        sch5d3_OV,
                        sch5d3_VK,                                
                        sch5d3_PS,
                        sch5d3_SS,                                
                        sch5d3_TX
                     ], join = "outer").fillna(0)
sch5d3_mdiscipline.reset_index(inplace=True, drop=True)
sch5d3_mdiscipline.insert(0, 'Building', '5.3')

# Общая спека по зданию сгрупированная
sch5d3_mdiscipline_gr = pd.concat([sch5d3_AR_gr, 
                        sch5d3_KR_gr,
                        sch5d3_ES_gr,
                        sch5d3_OV_gr,
                        sch5d3_VK_gr,                                   
                        sch5d3_PS_gr, 
                        sch5d3_SS_gr,                                    
                        sch5d3_TX_gr        
                     ], join = "outer").fillna(0)
sch5d3_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch5d3_mdiscipline_gr.insert(0, 'Building', '5.3')

# Сбор всех помещений в здании
sch5d3_room = pd.concat([sch5d3_AR_room, 
                     ], join = "outer").fillna(0)
sch5d3_room.reset_index(inplace=True, drop=True)
sch5d3_room.insert(0, 'Building', '5.3')
sch5d3_room.Area = pd.to_numeric(sch5d3_room.Area, errors='coerce')
sch5d3_room.Volume = pd.to_numeric(sch5d3_room.Volume, errors='coerce')
sch5d3_room.Perimeter = pd.to_numeric(sch5d3_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch5d3_room_gr = sch5d3_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\5.3_КПП3\01_Schedules\TLC_P_I_5.3_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch5d3_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch5d3_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch5d3_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch5d3_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch5d3_ES.to_excel(writer, sheet_name='ES_Schedule')    
    sch5d3_OV.to_excel(writer, sheet_name='OV_Schedule') 
    sch5d3_VK.to_excel(writer, sheet_name='VK_Schedule')  
    sch5d3_SS.to_excel(writer, sheet_name='SS_Schedule')   
    sch5d3_PS.to_excel(writer, sheet_name='PS_Schedule')     
    sch5d3_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch5d3_room.to_excel(writer, sheet_name='All_Rooms')
    sch5d3_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 5.4 Building
# Загрузка спек по дисциплинам
sch5d4_AR = ex_to_df_cnc('TLC', '5.4', 'AR')
sch5d4_AR_room = ex_to_df('TLC', '5.4', 'AR', 'Room')
sch5d4_KR = ex_to_df_cnc('TLC', '5.4', 'KR')
sch5d4_OV = ex_to_df_cnc('TLC', '5.4', 'OV')
sch5d4_VK = ex_to_df_cnc('TLC', '5.4', 'VK')
sch5d4_ES = ex_to_df_cnc('TLC', '5.4', 'ES')
sch5d4_SS = ex_to_df_cnc('TLC', '5.4', 'SS')
sch5d4_PS = ex_to_df_cnc('TLC', '5.4', 'PS')
sch5d4_TX = ex_to_df_cnc('TLC', '5.4', 'TX')

#Группировка спек по дисц
sch5d4_AR_gr = sch5d4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch5d4_KR_gr = sch5d4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch5d4_ES_gr = sch5d4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch5d4_OV_gr = sch5d4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d4_VK_gr = sch5d4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d4_SS_gr = sch5d4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch5d4_PS_gr = sch5d4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch5d4_TX_gr = sch5d4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch5d4_mdiscipline = pd.concat([sch5d4_AR, 
                        sch5d4_KR,
                        sch5d4_ES,
                        sch5d4_OV,
                        sch5d4_VK, 
                        sch5d4_SS,                                
                        sch5d4_PS,
                        sch5d4_TX
                     ], join = "outer").fillna(0)
sch5d4_mdiscipline.reset_index(inplace=True, drop=True)
sch5d4_mdiscipline.insert(0, 'Building', '5.4')

# Общая спека по зданию сгрупированная
sch5d4_mdiscipline_gr = pd.concat([sch5d4_AR_gr, 
                        sch5d4_KR_gr,
                        sch5d4_ES_gr,
                        sch5d4_OV_gr, 
                        sch5d4_VK_gr,
                        sch5d4_SS_gr,                                   
                        sch5d4_PS_gr, 
                        sch5d4_TX_gr        
                     ], join = "outer").fillna(0)
sch5d4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch5d4_mdiscipline_gr.insert(0, 'Building', '5.4')

# Сбор всех помещений в здании
sch5d4_room = pd.concat([sch5d4_AR_room, 
                     ], join = "outer").fillna(0)
sch5d4_room.reset_index(inplace=True, drop=True)
sch5d4_room.insert(0, 'Building', '5.4')
sch5d4_room.Area = pd.to_numeric(sch5d4_room.Area, errors='coerce')
sch5d4_room.Volume = pd.to_numeric(sch5d4_room.Volume, errors='coerce')
sch5d4_room.Perimeter = pd.to_numeric(sch5d4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch5d4_room_gr = sch5d4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\5.4_КПП4\01_Schedules\TLC_P_I_5.4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch5d4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch5d4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch5d4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch5d4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch5d4_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch5d4_VK.to_excel(writer, sheet_name='VK_Schedule')
    sch5d4_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch5d4_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch5d4_SS.to_excel(writer, sheet_name='SS_Schedule') 
    sch5d4_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch5d4_room.to_excel(writer, sheet_name='All_Rooms')
    sch5d4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 7.2 Building
# Загрузка спек по дисциплинам
#sch7d2_AR = ex_to_df_cnc('TLC', '7.2', 'AR')
#sch7d2_AR_room = ex_to_df('TLC', '7.2', 'AR', 'Room')
sch7d2_KR = ex_to_df_cnc('TLC', '7.2', 'KR')


#Группировка спек по дисц
#sch7d2_AR_gr = sch7d2_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch7d2_KR_gr = sch7d2_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Общая спека по зданию
sch7d2_mdiscipline = pd.concat([
#                       sch7d2_AR, 
                        sch7d2_KR
                     ], join = "outer").fillna(0)
sch7d2_mdiscipline.reset_index(inplace=True, drop=True)
sch7d2_mdiscipline.insert(0, 'Building', '7.2')

# Общая спека по зданию сгрупированная
sch7d2_mdiscipline_gr = pd.concat([
#                        sch7d2_AR_gr, 
                        sch7d2_KR_gr       
                     ], join = "outer").fillna(0)
sch7d2_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch7d2_mdiscipline_gr.insert(0, 'Building', '7.2')

# Сбор всех помещений в здании
#sch7d2_room = pd.concat([sch7d2_AR_room, 
#                     ], join = "outer").fillna(0)
#sch7d2_room.reset_index(inplace=True, drop=True)
#sch7d2_room.insert(0, 'Building', '7.2')
#sch7d2_room.Area = pd.to_numeric(sch7d2_room.Area, errors='coerce')
#sch7d2_room.Volume = pd.to_numeric(sch7d2_room.Volume, errors='coerce')
#sch7d2_room.Perimeter = pd.to_numeric(sch7d2_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch7d2_room_gr = sch7d2_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\7.2\01_Schedules\TLC_P_I_7.2_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch7d2_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch7d2_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch7d2_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch7d2_KR.to_excel(writer, sheet_name='KR_Schedule')
#    sch7d2_room.to_excel(writer, sheet_name='All_Rooms')
#    sch7d2_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 7.4 Building
# Загрузка спек по дисциплинам
sch7d4_AR_A = ex_to_df_cnc('TLC', '7.4', 'AR', 'A')
sch7d4_AR_B = ex_to_df_cnc('TLC', '7.4', 'AR', 'B')
sch7d4_AR_C = ex_to_df_cnc('TLC', '7.4', 'AR', 'C')
sch74_AR_room_A = ex_to_df('TLC', '7.4', 'AR', 'Room', 'A')
sch74_AR_room_B = ex_to_df('TLC', '7.4', 'AR', 'Room', 'B')
sch74_AR_room_C = ex_to_df('TLC', '7.4', 'AR', 'Room', 'C')

sch7d4_KR_A = ex_to_df_cnc('TLC', '7.4', 'KR', 'A')
sch7d4_KR_B = ex_to_df_cnc('TLC', '7.4', 'KR', 'B')
sch7d4_KR_C = ex_to_df_cnc('TLC', '7.4', 'KR', 'C')

sch7d4_ES_A = ex_to_df_cnc('TLC', '7.4', 'ES', 'A')
sch7d4_ES_B = ex_to_df_cnc('TLC', '7.4', 'ES', 'B')
sch7d4_ES_C = ex_to_df_cnc('TLC', '7.4', 'ES', 'C')

sch7d4_OV_A = ex_to_df_cnc('TLC', '7.4', 'OV', 'A')
sch7d4_OV_B = ex_to_df_cnc('TLC', '7.4', 'OV', 'B')
sch7d4_OV_C = ex_to_df_cnc('TLC', '7.4', 'OV', 'C')

sch7d4_VK_A = ex_to_df_cnc('TLC', '7.4', 'VK', 'A')
sch7d4_VK_B = ex_to_df_cnc('TLC', '7.4', 'VK', 'B')
sch7d4_VK_C = ex_to_df_cnc('TLC', '7.4', 'VK', 'C')

sch7d4_PT_A = ex_to_df_cnc('TLC', '7.4', 'PT', 'A')
sch7d4_PT_B = ex_to_df_cnc('TLC', '7.4', 'PT', 'B')
sch7d4_PT_C = ex_to_df_cnc('TLC', '7.4', 'PT', 'C')

sch7d4_PS_A = ex_to_df_cnc('TLC', '7.4', 'PS', 'A')
sch7d4_PS_B = ex_to_df_cnc('TLC', '7.4', 'PS', 'B')
sch7d4_PS_C = ex_to_df_cnc('TLC', '7.4', 'PS', 'C')

sch7d4_SS_A = ex_to_df_cnc('TLC', '7.4', 'SS', 'A')
sch7d4_SS_B = ex_to_df_cnc('TLC', '7.4', 'SS', 'B')
sch7d4_SS_C = ex_to_df_cnc('TLC', '7.4', 'SS', 'C')

sch7d4_TX_A = ex_to_df_cnc('TLC', '7.4', 'TX', 'A')
sch7d4_TX_B = ex_to_df_cnc('TLC', '7.4', 'TX', 'B')
sch7d4_TX_C = ex_to_df_cnc('TLC', '7.4', 'TX', 'C')

sch7d4_AR = pd.concat([sch7d4_AR_A,
                        sch7d4_AR_B,
                        sch7d4_AR_C
                     ], join = "outer").fillna(0)                       
sch7d4_KR = pd.concat([sch7d4_KR_A,
                        sch7d4_KR_B,                                
                        sch7d4_KR_C
                     ], join = "outer").fillna(0)
sch7d4_ES = pd.concat([sch7d4_ES_A,
                        sch7d4_ES_B,                                
                        sch7d4_ES_C
                     ], join = "outer").fillna(0)
sch7d4_OV = pd.concat([sch7d4_OV_A,                                
                        sch7d4_OV_B,
                        sch7d4_OV_C
                     ], join = "outer").fillna(0)
sch7d4_VK = pd.concat([sch7d4_VK_A,                                
                        sch7d4_VK_B,
                        sch7d4_VK_C
                     ], join = "outer").fillna(0)
sch7d4_PT = pd.concat([sch7d4_PT_A,                                
                        sch7d4_PT_B,
                        sch7d4_PT_C
                     ], join = "outer").fillna(0)
sch7d4_PS = pd.concat([sch7d4_PS_A,                                
                        sch7d4_PS_B,
                        sch7d4_PS_C
                     ], join = "outer").fillna(0)
sch7d4_SS = pd.concat([sch7d4_SS_A,                                
                        sch7d4_SS_B,
                        sch7d4_SS_C
                     ], join = "outer").fillna(0)
sch7d4_TX = pd.concat([sch7d4_TX_A,
                        sch7d4_TX_B,                                
                        sch7d4_TX_C                                
                     ], join = "outer").fillna(0)

#Группировка спек по дисц
sch7d4_AR_gr = sch7d4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch7d4_KR_gr = sch7d4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch7d4_ES_gr = sch7d4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch7d4_VK_gr = sch7d4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch7d4_OV_gr = sch7d4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch7d4_PT_gr = sch7d4_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch7d4_PS_gr = sch7d4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch7d4_SS_gr = sch7d4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch7d4_TX_gr = sch7d4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch7d4_mdiscipline = pd.concat([
                        sch7d4_AR,
                        sch7d4_KR,
                        sch7d4_ES,    
                        sch7d4_OV,
                        sch7d4_VK,    
                        sch7d4_PT,
                        sch7d4_PS,    
                        sch7d4_SS,                                
                        sch7d4_TX     
                     ], join = "outer").fillna(0)
sch7d4_mdiscipline.reset_index(inplace=True, drop=True)
sch7d4_mdiscipline.insert(0, 'Building', '7.4')

#Общая спека по зданию сгрупированная
sch7d4_mdiscipline_gr = pd.concat([
                        sch7d4_AR_gr, 
                        sch7d4_KR_gr,
                        sch7d4_ES_gr,                                   
                        sch7d4_OV_gr, 
                        sch7d4_VK_gr,                                    
                        sch7d4_PT_gr,
                        sch7d4_PS_gr,                                   
                        sch7d4_SS_gr,                                   
                        sch7d4_TX_gr          
                     ], join = "outer").fillna(0)
sch7d4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch7d4_mdiscipline_gr.insert(0, 'Building', '7.4')

# Сбор всех помещений в здании
sch7d4_room = pd.concat([sch74_AR_room_A,
                         sch74_AR_room_B,
                         sch74_AR_room_C
                     ], join = "outer").fillna(0)
sch7d4_room.reset_index(inplace=True, drop=True)
sch7d4_room.insert(0, 'Building', '7.4')
sch7d4_room.Area = pd.to_numeric(sch7d4_room.Area, errors='coerce')
sch7d4_room.Volume = pd.to_numeric(sch7d4_room.Volume, errors='coerce')
sch7d4_room.Perimeter = pd.to_numeric(sch7d4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch7d4_room_gr = sch7d4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\7.4_Склад\01_Schedules\TLC_P_I_7.4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch7d4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch7d4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch7d4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch7d4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch7d4_ES.to_excel(writer, sheet_name='ES_Schedule')     
    sch7d4_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch7d4_VK.to_excel(writer, sheet_name='VK_Schedule')   
    sch7d4_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch7d4_PS.to_excel(writer, sheet_name='PS_Schedule')     
    sch7d4_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch7d4_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch7d4_room.to_excel(writer, sheet_name='All_Rooms')
    sch7d4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 8.1 Building
# Загрузка спек по дисциплинам
sch8d1_AR = ex_to_df_cnc('TLC', '8.1', 'AR')
sch8d1_KR = ex_to_df_cnc('TLC', '8.1', 'KR')
sch8d1_ES = ex_to_df_cnc('TLC', '8.1', 'ES')
sch8d1_SS = ex_to_df_cnc('TLC', '8.1', 'SS')
#sch8d1_OV = ex_to_df_cnc('TLC', '8.1', 'OV')
#sch8d1_VK = ex_to_df_cnc('TLC', '8.1', 'VK')
#sch8d1_PT = ex_to_df_cnc('TLC', '8.1', 'PT')
sch8d1_PS = ex_to_df_cnc('TLC', '8.1', 'PS')
#sch8d1_TX = ex_to_df_cnc('TLC', '8.1', 'TX')
sch8d1_AR_room = ex_to_df('TLC', '8.1', 'AR', 'Room')
#Группировка спек по дисц
sch8d1_AR_gr = sch8d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch8d1_KR_gr = sch8d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch8d1_ES_gr = sch8d1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch8d1_SS_gr = sch8d1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch8d1_OV_gr = sch8d1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch8d1_VK_gr = sch8d1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch8d1_PT_gr = sch8d1_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch8d1_PS_gr = sch8d1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch8d1_TX_gr = sch8d1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch8d1_mdiscipline = pd.concat([sch8d1_AR, 
                        sch8d1_KR,
                        sch8d1_ES,                                 
                        sch8d1_SS,                                  
#                        sch8d1_OV,
#                        sch8d1_VK,                                 
#                        sch8d1_PT,
                        sch8d1_PS,                                 
#                        sch8d1_TX
                     ], join = "outer").fillna(0)
sch8d1_mdiscipline.reset_index(inplace=True, drop=True)
sch8d1_mdiscipline.insert(0, 'Building', '8.1')

# Общая спека по зданию сгрупированная
sch8d1_mdiscipline_gr = pd.concat([sch8d1_AR_gr, 
                        sch8d1_KR_gr,
                        sch8d1_ES_gr,
                        sch8d1_SS_gr,                                    
#                        sch8d1_OV_gr,
#                        sch8d1_VK_gr,                                    
#                        sch8d1_PT_gr,
                        sch8d1_PS_gr,                                    
#                        sch8d1_TX_gr        
                     ], join = "outer").fillna(0)
sch8d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch8d1_mdiscipline_gr.insert(0, 'Building', '8.1')

# Сбор всех помещений в здании
sch8d1_room = pd.concat([sch8d1_AR_room, 
                     ], join = "outer").fillna(0)
sch8d1_room.reset_index(inplace=True, drop=True)
sch8d1_room.insert(0, 'Building', '8.1')
sch8d1_room.Area = pd.to_numeric(sch8d1_room.Area, errors='coerce')
sch8d1_room.Volume = pd.to_numeric(sch8d1_room.Volume, errors='coerce')
sch8d1_room.Perimeter = pd.to_numeric(sch8d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch8d1_room_gr = sch8d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\8.1_РТП\01_Schedules\TLC_P_I_8.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch8d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch8d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch8d1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch8d1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch8d1_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch8d1_SS.to_excel(writer, sheet_name='SS_Schedule')    
#    sch8d1_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch8d1_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch8d1_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch8d1_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch8d1_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch8d1_room.to_excel(writer, sheet_name='All_Rooms')
    sch8d1_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 11.5 Building
# Загрузка спек по дисциплинам
#sch11d5_AR = ex_to_df_cnc('TLC', '11.5', 'AR')
sch11d5_KR = ex_to_df_cnc('TLC', '11.5', 'KR')
sch11d5_ES = ex_to_df_cnc('TLC', '11.5', 'ES')
sch11d5_SS = ex_to_df_cnc('TLC', '11.5', 'SS')
#sch11d5_OV = ex_to_df_cnc('TLC', '11.5', 'OV')
#sch11d5_VK = ex_to_df_cnc('TLC', '11.5', 'VK')
#sch11d5_PT = ex_to_df_cnc('TLC', '11.5', 'PT')
sch11d5_PS = ex_to_df_cnc('TLC', '11.5', 'PS')
#sch11d5_TX = ex_to_df_cnc('TLC', '11.5', 'TX')
#sch11d5_AR_room = ex_to_df('TLC', '11.5', 'AR', 'Room')
#Группировка спек по дисц
#sch11d5_AR_gr = sch11d5_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch11d5_KR_gr = sch11d5_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch11d5_ES_gr = sch11d5_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch11d5_SS_gr = sch11d5_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5_OV_gr = sch11d5_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5_VK_gr = sch11d5_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5_PT_gr = sch11d5_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch11d5_PS_gr = sch11d5_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5_TX_gr = sch11d5_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch11d5_mdiscipline = pd.concat([#sch11d5_AR, 
                        sch11d5_KR,
                        sch11d5_ES,                                 
                        sch11d5_SS,                                  
#                        sch11d5_OV,
#                        sch11d5_VK,                                 
#                        sch11d5_PT,
                        sch11d5_PS,                                 
#                        sch11d5_TX
                     ], join = "outer").fillna(0)
sch11d5_mdiscipline.reset_index(inplace=True, drop=True)
sch11d5_mdiscipline.insert(0, 'Building', '11.5')

# Общая спека по зданию сгрупированная
sch11d5_mdiscipline_gr = pd.concat([#sch11d5_AR_gr, 
                        sch11d5_KR_gr,
                        sch11d5_ES_gr,
                        sch11d5_SS_gr,                                    
#                        sch11d5_OV_gr,
#                        sch11d5_VK_gr,                                    
#                        sch11d5_PT_gr,
                        sch11d5_PS_gr,                                    
#                        sch11d5_TX_gr        
                     ], join = "outer").fillna(0)
sch11d5_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch11d5_mdiscipline_gr.insert(0, 'Building', '11.5')

# Сбор всех помещений в здании
#sch11d5_room = pd.concat([sch11d5_AR_room, 
#                     ], join = "outer").fillna(0)
#sch11d5_room.reset_index(inplace=True, drop=True)
#sch11d5_room.insert(0, 'Building', '11.5')
#sch11d5_room.Area = pd.to_numeric(sch11d5_room.Area, errors='coerce')
#sch11d5_room.Volume = pd.to_numeric(sch11d5_room.Volume, errors='coerce')
#sch11d5_room.Perimeter = pd.to_numeric(sch11d5_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch11d5_room_gr = sch11d5_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\11.5_ТП\01_Schedules\TLC_P_I_11.5_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch11d5_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch11d5_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch11d5_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch11d5_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch11d5_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch11d5_SS.to_excel(writer, sheet_name='SS_Schedule')    
#    sch11d5_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch11d5_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch11d5_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch11d5_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch11d5_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch11d5_room.to_excel(writer, sheet_name='All_Rooms')
#    sch11d5_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 11.5.4 Building
# Загрузка спек по дисциплинам
#sch11d5d4_AR = ex_to_df_cnc('TLC', '11.5.4', 'AR')
sch11d5d4_KR = ex_to_df_cnc('TLC', '11.5.4', 'KR')
sch11d5d4_ES = ex_to_df_cnc('TLC', '11.5.4', 'ES')
sch11d5d4_SS = ex_to_df_cnc('TLC', '11.5.4', 'SS')
#sch11d5d4_OV = ex_to_df_cnc('TLC', '11.5.4', 'OV')
#sch11d5d4_VK = ex_to_df_cnc('TLC', '11.5.4', 'VK')
#sch11d5d4_PT = ex_to_df_cnc('TLC', '11.5.4', 'PT')
sch11d5d4_PS = ex_to_df_cnc('TLC', '11.5.4', 'PS')
#sch11d5d4_TX = ex_to_df_cnc('TLC', '11.5.4', 'TX')
#sch11d5d4_AR_room = ex_to_df('TLC', '11.5.4', 'AR', 'Room')
#Группировка спек по дисц
#sch11d5d4_AR_gr = sch11d5d4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch11d5d4_KR_gr = sch11d5d4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch11d5d4_ES_gr = sch11d5d4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch11d5d4_SS_gr = sch11d5d4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5d4_OV_gr = sch11d5d4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5d4_VK_gr = sch11d5d4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5d4_PT_gr = sch11d5d4_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch11d5d4_PS_gr = sch11d5d4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5d4_TX_gr = sch11d5d4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch11d5d4_mdiscipline = pd.concat([#sch11d5d4_AR, 
                        sch11d5d4_KR,
                        sch11d5d4_ES,                                 
                        sch11d5d4_SS,                                  
#                        sch11d5d4_OV,
#                        sch11d5d4_VK,                                 
#                        sch11d5d4_PT,
                        sch11d5d4_PS,                                 
#                        sch11d5d4_TX
                     ], join = "outer").fillna(0)
sch11d5d4_mdiscipline.reset_index(inplace=True, drop=True)
sch11d5d4_mdiscipline.insert(0, 'Building', '11.5.4')

# Общая спека по зданию сгрупированная
sch11d5d4_mdiscipline_gr = pd.concat([#sch11d5d4_AR_gr, 
                        sch11d5d4_KR_gr,
                        sch11d5d4_ES_gr,
                        sch11d5d4_SS_gr,                                    
#                        sch11d5d4_OV_gr,
#                        sch11d5d4_VK_gr,                                    
#                        sch11d5d4_PT_gr,
                        sch11d5d4_PS_gr,                                    
#                        sch11d5d4_TX_gr        
                     ], join = "outer").fillna(0)
sch11d5d4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch11d5d4_mdiscipline_gr.insert(0, 'Building', '11.5.4')

# Сбор всех помещений в здании
#sch11d5d4_room = pd.concat([sch11d5d4_AR_room, 
#                     ], join = "outer").fillna(0)
#sch11d5d4_room.reset_index(inplace=True, drop=True)
#sch11d5d4_room.insert(0, 'Building', '11.5.4')
#sch11d5d4_room.Area = pd.to_numeric(sch11d5d4_room.Area, errors='coerce')
#sch11d5d4_room.Volume = pd.to_numeric(sch11d5d4_room.Volume, errors='coerce')
#sch11d5d4_room.Perimeter = pd.to_numeric(sch11d5d4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch11d5d4_room_gr = sch11d5d4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\11.5.4\01_Schedules\TLC_P_I_11.5.4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch11d5d4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch11d5d4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch11d5d4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch11d5d4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch11d5d4_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch11d5d4_SS.to_excel(writer, sheet_name='SS_Schedule')    
#    sch11d5d4_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch11d5d4_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch11d5d4_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch11d5d4_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch11d5d4_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch11d5d4_room.to_excel(writer, sheet_name='All_Rooms')
#    sch11d5d4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 11.5.4 Building
# Загрузка спек по дисциплинам
#sch11d5d4_AR = ex_to_df_cnc('TLC', '11.5.4', 'AR')
sch11d5d4_KR = ex_to_df_cnc('TLC', '11.5.4', 'KR')
sch11d5d4_ES = ex_to_df_cnc('TLC', '11.5.4', 'ES')
sch11d5d4_SS = ex_to_df_cnc('TLC', '11.5.4', 'SS')
#sch11d5d4_OV = ex_to_df_cnc('TLC', '11.5.4', 'OV')
#sch11d5d4_VK = ex_to_df_cnc('TLC', '11.5.4', 'VK')
#sch11d5d4_PT = ex_to_df_cnc('TLC', '11.5.4', 'PT')
sch11d5d4_PS = ex_to_df_cnc('TLC', '11.5.4', 'PS')
#sch11d5d4_TX = ex_to_df_cnc('TLC', '11.5.4', 'TX')
#sch11d5d4_AR_room = ex_to_df('TLC', '11.5.4', 'AR', 'Room')
#Группировка спек по дисц
#sch11d5d4_AR_gr = sch11d5d4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch11d5d4_KR_gr = sch11d5d4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch11d5d4_ES_gr = sch11d5d4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch11d5d4_SS_gr = sch11d5d4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5d4_OV_gr = sch11d5d4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5d4_VK_gr = sch11d5d4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch11d5d4_PT_gr = sch11d5d4_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch11d5d4_PS_gr = sch11d5d4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch11d5d4_TX_gr = sch11d5d4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch11d5d4_mdiscipline = pd.concat([#sch11d5d4_AR, 
                        sch11d5d4_KR,
                        sch11d5d4_ES,                                 
                        sch11d5d4_SS,                                  
#                        sch11d5d4_OV,
#                        sch11d5d4_VK,                                 
#                        sch11d5d4_PT,
                        sch11d5d4_PS,                                 
#                        sch11d5d4_TX
                     ], join = "outer").fillna(0)
sch11d5d4_mdiscipline.reset_index(inplace=True, drop=True)
sch11d5d4_mdiscipline.insert(0, 'Building', '11.5.4')

# Общая спека по зданию сгрупированная
sch11d5d4_mdiscipline_gr = pd.concat([#sch11d5d4_AR_gr, 
                        sch11d5d4_KR_gr,
                        sch11d5d4_ES_gr,
                        sch11d5d4_SS_gr,                                    
#                        sch11d5d4_OV_gr,
#                        sch11d5d4_VK_gr,                                    
#                        sch11d5d4_PT_gr,
                        sch11d5d4_PS_gr,                                    
#                        sch11d5d4_TX_gr        
                     ], join = "outer").fillna(0)
sch11d5d4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch11d5d4_mdiscipline_gr.insert(0, 'Building', '11.5.4')

# Сбор всех помещений в здании
#sch11d5d4_room = pd.concat([sch11d5d4_AR_room, 
#                     ], join = "outer").fillna(0)
#sch11d5d4_room.reset_index(inplace=True, drop=True)
#sch11d5d4_room.insert(0, 'Building', '11.5.4')
#sch11d5d4_room.Area = pd.to_numeric(sch11d5d4_room.Area, errors='coerce')
#sch11d5d4_room.Volume = pd.to_numeric(sch11d5d4_room.Volume, errors='coerce')
#sch11d5d4_room.Perimeter = pd.to_numeric(sch11d5d4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch11d5d4_room_gr = sch11d5d4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\11.5.4\01_Schedules\TLC_P_I_11.5.4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch11d5d4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch11d5d4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch11d5d4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch11d5d4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch11d5d4_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch11d5d4_SS.to_excel(writer, sheet_name='SS_Schedule')    
#    sch11d5d4_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch11d5d4_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch11d5d4_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch11d5d4_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch11d5d4_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch11d5d4_room.to_excel(writer, sheet_name='All_Rooms')
#    sch11d5d4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 14.1 Building
# Загрузка спек по дисциплинам
#sch14d1_AR = ex_to_df_cnc('TLC', '14.1', 'AR')
sch14d1_KR = ex_to_df_cnc('TLC', '14.1', 'KR')
sch14d1_ES = ex_to_df_cnc('TLC', '14.1', 'ES')
sch14d1_SS = ex_to_df_cnc('TLC', '14.1', 'SS')
sch14d1_OV = ex_to_df_cnc('TLC', '14.1', 'OV')
sch14d1_GS = ex_to_df_cnc('TLC', '14.1', 'GS')
#sch14d1_VK = ex_to_df_cnc('TLC', '14.1', 'VK')
#sch14d1_PT = ex_to_df_cnc('TLC', '14.1', 'PT')
sch14d1_PS = ex_to_df_cnc('TLC', '14.1', 'PS')
#sch14d1_TX = ex_to_df_cnc('TLC', '14.1', 'TX')
#sch14d1_AR_room = ex_to_df('TLC', '14.1', 'AR', 'Room')
#Группировка спек по дисц
#sch14d1_AR_gr = sch14d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch14d1_KR_gr = sch14d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch14d1_ES_gr = sch14d1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch14d1_SS_gr = sch14d1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch14d1_OV_gr = sch14d1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch14d1_GS_gr = sch14d1_GS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch14d1_VK_gr = sch14d1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch14d1_PT_gr = sch14d1_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch14d1_PS_gr = sch14d1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch14d1_TX_gr = sch14d1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch14d1_mdiscipline = pd.concat([
#                        sch14d1_AR, 
                        sch14d1_KR,
                        sch14d1_ES,                                 
                        sch14d1_SS,                                  
                        sch14d1_OV,
                        sch14d1_GS,                                 
#                        sch14d1_VK,                                 
#                        sch14d1_PT,
                        sch14d1_PS,                                 
#                        sch14d1_TX
                     ], join = "outer").fillna(0)
sch14d1_mdiscipline.reset_index(inplace=True, drop=True)
sch14d1_mdiscipline.insert(0, 'Building', '14.1')

# Общая спека по зданию сгрупированная
sch14d1_mdiscipline_gr = pd.concat([
#                        sch14d1_AR_gr, 
                        sch14d1_KR_gr,
                        sch14d1_ES_gr,
                        sch14d1_SS_gr,                                    
                        sch14d1_OV_gr,
                        sch14d1_GS_gr,                                    
#                        sch14d1_VK_gr,                                    
#                        sch14d1_PT_gr,
                        sch14d1_PS_gr,                                    
#                        sch14d1_TX_gr        
                     ], join = "outer").fillna(0)
sch14d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch14d1_mdiscipline_gr.insert(0, 'Building', '14.1')

# Сбор всех помещений в здании
#sch14d1_room = pd.concat([sch14d1_AR_room, 
#                     ], join = "outer").fillna(0)
#sch14d1_room.reset_index(inplace=True, drop=True)
#sch14d1_room.insert(0, 'Building', '14.1')
#sch14d1_room.Area = pd.to_numeric(sch14d1_room.Area, errors='coerce')
#sch14d1_room.Volume = pd.to_numeric(sch14d1_room.Volume, errors='coerce')
#sch14d1_room.Perimeter = pd.to_numeric(sch14d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch14d1_room_gr = sch14d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\14.1_Котельная1\01_Schedules\TLC_P_I_14.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch14d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch14d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch14d1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch14d1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch14d1_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch14d1_GS.to_excel(writer, sheet_name='GS_Schedule')
    sch14d1_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch14d1_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch14d1_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch14d1_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch14d1_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch14d1_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch14d1_room.to_excel(writer, sheet_name='All_Rooms')
#    sch14d1_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 14.2 Building
# Загрузка спек по дисциплинам
#sch14d2_AR = ex_to_df_cnc('TLC', '14.2', 'AR')
sch14d2_KR = ex_to_df_cnc('TLC', '14.2', 'KR')
sch14d2_ES = ex_to_df_cnc('TLC', '14.2', 'ES')
sch14d2_SS = ex_to_df_cnc('TLC', '14.2', 'SS')
sch14d2_OV = ex_to_df_cnc('TLC', '14.2', 'OV')
sch14d2_GS = ex_to_df_cnc('TLC', '14.2', 'GS')
#sch14d2_VK = ex_to_df_cnc('TLC', '14.2', 'VK')
#sch14d2_PT = ex_to_df_cnc('TLC', '14.2', 'PT')
sch14d2_PS = ex_to_df_cnc('TLC', '14.2', 'PS')
#sch14d2_TX = ex_to_df_cnc('TLC', '14.2', 'TX')
#sch14d2_AR_room = ex_to_df('TLC', '14.2', 'AR', 'Room')
#Группировка спек по дисц
#sch14d2_AR_gr = sch14d2_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch14d2_KR_gr = sch14d2_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch14d2_ES_gr = sch14d2_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch14d2_SS_gr = sch14d2_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch14d2_OV_gr = sch14d2_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch14d2_GS_gr = sch14d2_GS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch14d2_VK_gr = sch14d2_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch14d2_PT_gr = sch14d2_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch14d2_PS_gr = sch14d2_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch14d2_TX_gr = sch14d2_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch14d2_mdiscipline = pd.concat([
#                        sch14d2_AR, 
                        sch14d2_KR,
                        sch14d2_ES,                                 
                        sch14d2_SS,                                  
                        sch14d2_OV,
                        sch14d2_GS,                                 
#                        sch14d2_VK,                                 
#                        sch14d2_PT,
                        sch14d2_PS,                                 
#                        sch14d2_TX
                     ], join = "outer").fillna(0)
sch14d2_mdiscipline.reset_index(inplace=True, drop=True)
sch14d2_mdiscipline.insert(0, 'Building', '14.2')

# Общая спека по зданию сгрупированная
sch14d2_mdiscipline_gr = pd.concat([
#                        sch14d2_AR_gr, 
                        sch14d2_KR_gr,
                        sch14d2_ES_gr,
                        sch14d2_SS_gr,                                    
                        sch14d2_OV_gr,
                        sch14d2_GS_gr,                                    
#                        sch14d2_VK_gr,                                    
#                        sch14d2_PT_gr,
                        sch14d2_PS_gr,                                    
#                        sch14d2_TX_gr        
                     ], join = "outer").fillna(0)
sch14d2_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch14d2_mdiscipline_gr.insert(0, 'Building', '14.2')

# Сбор всех помещений в здании
#sch14d2_room = pd.concat([sch14d2_AR_room, 
#                     ], join = "outer").fillna(0)
#sch14d2_room.reset_index(inplace=True, drop=True)
#sch14d2_room.insert(0, 'Building', '14.2')
#sch14d2_room.Area = pd.to_numeric(sch14d2_room.Area, errors='coerce')
#sch14d2_room.Volume = pd.to_numeric(sch14d2_room.Volume, errors='coerce')
#sch14d2_room.Perimeter = pd.to_numeric(sch14d2_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch14d2_room_gr = sch14d2_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\14.2_Котельная2\01_Schedules\TLC_P_I_14.2_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch14d2_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch14d2_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch14d2_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch14d2_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch14d2_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch14d2_GS.to_excel(writer, sheet_name='GS_Schedule')
    sch14d2_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch14d2_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch14d2_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch14d2_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch14d2_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch14d2_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch14d2_room.to_excel(writer, sheet_name='All_Rooms')
#    sch14d2_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.1 Building
# Загрузка спек по дисциплинам
sch15d1_AR = ex_to_df_cnc('TLC', '15.1', 'AR')
sch15d1_KR = ex_to_df_cnc('TLC', '15.1', 'KR')
sch15d1_ES = ex_to_df_cnc('TLC', '15.1', 'ES')
sch15d1_SS = ex_to_df_cnc('TLC', '15.1', 'SS')
sch15d1_OV = ex_to_df_cnc('TLC', '15.1', 'OV')
sch15d1_VK = ex_to_df_cnc('TLC', '15.1', 'VK')
sch15d1_PT = ex_to_df_cnc('TLC', '15.1', 'PT')
sch15d1_PS = ex_to_df_cnc('TLC', '15.1', 'PS')
sch15d1_TX = ex_to_df_cnc('TLC', '15.1', 'TX')
sch15d1_DER = ex_to_df_cnc('TLC', '15.1', 'DER')
sch15d1_AR_room = ex_to_df('TLC', '15.1', 'AR', 'Room')
#Группировка спек по дисц
sch15d1_AR_gr = sch15d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d1_KR_gr = sch15d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d1_ES_gr = sch15d1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d1_SS_gr = sch15d1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d1_OV_gr = sch15d1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d1_VK_gr = sch15d1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d1_PT_gr = sch15d1_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d1_PS_gr = sch15d1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d1_TX_gr = sch15d1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d1_DER_gr = sch15d1_DER.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})


# Общая спека по зданию
sch15d1_mdiscipline = pd.concat([sch15d1_AR, 
                        sch15d1_KR,
                        sch15d1_ES,                                 
                        sch15d1_SS,                                  
                        sch15d1_OV,
                        sch15d1_VK,                                 
                        sch15d1_PT,
                        sch15d1_PS,                                 
                        sch15d1_TX,
                        sch15d1_DER,                                 
                     ], join = "outer").fillna(0)
sch15d1_mdiscipline.reset_index(inplace=True, drop=True)
sch15d1_mdiscipline.insert(0, 'Building', '15.1')

# Общая спека по зданию сгрупированная
sch15d1_mdiscipline_gr = pd.concat([sch15d1_AR_gr, 
                        sch15d1_KR_gr,
                        sch15d1_ES_gr,
                        sch15d1_SS_gr,                                    
                        sch15d1_OV_gr,
                        sch15d1_VK_gr,                                    
                        sch15d1_PT_gr,
                        sch15d1_PS_gr,                                    
                        sch15d1_TX_gr,
                        sch15d1_DER_gr,                                    
                     ], join = "outer").fillna(0)
sch15d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d1_mdiscipline_gr.insert(0, 'Building', '15.1')

# Сбор всех помещений в здании
sch15d1_room = pd.concat([sch15d1_AR_room, 
                     ], join = "outer").fillna(0)
sch15d1_room.reset_index(inplace=True, drop=True)
sch15d1_room.insert(0, 'Building', '15.1')
sch15d1_room.Area = pd.to_numeric(sch15d1_room.Area, errors='coerce')
sch15d1_room.Volume = pd.to_numeric(sch15d1_room.Volume, errors='coerce')
sch15d1_room.Perimeter = pd.to_numeric(sch15d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d1_room_gr = sch15d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.1_СВК\01_Schedules\TLC_P_I_15.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d1_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch15d1_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch15d1_OV.to_excel(writer, sheet_name='OV_Schedule') 
    sch15d1_VK.to_excel(writer, sheet_name='VK_Schedule')     
    sch15d1_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch15d1_PS.to_excel(writer, sheet_name='PS_Schedule')     
    sch15d1_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch15d1_DER.to_excel(writer, sheet_name='DER_Schedule')    
    sch15d1_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d1_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.2 Building
# Загрузка спек по дисциплинам
sch15d2_AR = ex_to_df_cnc('TLC', '15.2', 'AR')
sch15d2_KR = ex_to_df_cnc('TLC', '15.2', 'KR')
sch15d2_ES = ex_to_df_cnc('TLC', '15.2', 'ES')
sch15d2_OV = ex_to_df_cnc('TLC', '15.2', 'OV')
sch15d2_VK = ex_to_df_cnc('TLC', '15.2', 'VK')
sch15d2_PT = ex_to_df_cnc('TLC', '15.2', 'PT')
sch15d2_PS = ex_to_df_cnc('TLC', '15.2', 'PS')
sch15d2_SS = ex_to_df_cnc('TLC', '15.2', 'SS')
sch15d2_TX = ex_to_df_cnc('TLC', '15.2', 'TX')

sch15d2_AR_room = ex_to_df('TLC', '15.2', 'AR', 'Room')
#Группировка спек по дисц
sch15d2_AR_gr = sch15d2_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d2_KR_gr = sch15d2_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d2_ES_gr = sch15d2_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d2_OV_gr = sch15d2_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d2_VK_gr = sch15d2_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d2_PT_gr = sch15d2_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d2_PS_gr = sch15d2_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d2_SS_gr = sch15d2_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d2_TX_gr = sch15d2_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d2_mdiscipline = pd.concat([sch15d2_AR, 
                        sch15d2_KR,
                        sch15d2_ES,                                 
                        sch15d2_OV,
                        sch15d2_VK,                                 
                        sch15d2_PT,
                        sch15d2_PS,
                        sch15d2_SS,                                 
                        sch15d2_TX
                     ], join = "outer").fillna(0)
sch15d2_mdiscipline.reset_index(inplace=True, drop=True)
sch15d2_mdiscipline.insert(0, 'Building', '15.2')

# Общая спека по зданию сгрупированная
sch15d2_mdiscipline_gr = pd.concat([sch15d2_AR_gr, 
                        sch15d2_KR_gr,
                        sch15d2_ES_gr,                                    
                        sch15d2_OV_gr,
                        sch15d2_VK_gr,                                    
                        sch15d2_PT_gr,
                        sch15d2_PS_gr,
                        sch15d2_SS_gr,                                    
                        sch15d2_TX_gr        
                     ], join = "outer").fillna(0)
sch15d2_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d2_mdiscipline_gr.insert(0, 'Building', '15.2')

# Сбор всех помещений в здании
sch15d2_room = pd.concat([sch15d2_AR_room, 
                     ], join = "outer").fillna(0)
sch15d2_room.reset_index(inplace=True, drop=True)
sch15d2_room.insert(0, 'Building', '15.2')
sch15d2_room.Area = pd.to_numeric(sch15d2_room.Area, errors='coerce')
sch15d2_room.Volume = pd.to_numeric(sch15d2_room.Volume, errors='coerce')
sch15d2_room.Perimeter = pd.to_numeric(sch15d2_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d2_room_gr = sch15d2_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.2_Склад ИМ\01_Schedules\TLC_P_I_15.2_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d2_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d2_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d2_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d2_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d2_ES.to_excel(writer, sheet_name='EOM_Schedule')    
    sch15d2_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch15d2_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch15d2_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch15d2_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch15d2_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch15d2_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch15d2_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d2_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.3 Building
# Загрузка спек по дисциплинам
sch15d3_AR = ex_to_df_cnc('TLC', '15.3', 'AR')
sch15d3_KR = ex_to_df_cnc('TLC', '15.3', 'KR')
sch15d3_ES = ex_to_df_cnc('TLC', '15.3', 'ES')
sch15d3_OV = ex_to_df_cnc('TLC', '15.3', 'OV')
sch15d3_VK = ex_to_df_cnc('TLC', '15.3', 'VK')
sch15d3_PS = ex_to_df_cnc('TLC', '15.3', 'PS')
sch15d3_PT = ex_to_df_cnc('TLC', '15.3', 'PT')
sch15d3_SS = ex_to_df_cnc('TLC', '15.3', 'SS')
sch15d3_TX = ex_to_df_cnc('TLC', '15.3', 'TX')
sch15d3_DER = ex_to_df_cnc('TLC', '15.3', 'DER')
sch15d3_AR_room = ex_to_df('TLC', '15.3', 'AR', 'Room')
#Группировка спек по дисц
sch15d3_AR_gr = sch15d3_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d3_KR_gr = sch15d3_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d3_OV_gr = sch15d3_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d3_ES_gr = sch15d3_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d3_VK_gr = sch15d3_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d3_PS_gr = sch15d3_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d3_PT_gr = sch15d3_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d3_SS_gr = sch15d3_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d3_TX_gr = sch15d3_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d3_DER_gr = sch15d3_DER.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d3_mdiscipline = pd.concat([sch15d3_AR, 
                        sch15d3_KR,
                        sch15d3_ES,                                 
                        sch15d3_OV,
                        sch15d3_VK,                                 
                        sch15d3_PT,
                        sch15d3_PS,
                        sch15d3_SS,                                 
                        sch15d3_TX,
                        sch15d3_DER                                 
                     ], join = "outer").fillna(0)
sch15d3_mdiscipline.reset_index(inplace=True, drop=True)
sch15d3_mdiscipline.insert(0, 'Building', '15.3')

# Общая спека по зданию сгрупированная
sch15d3_mdiscipline_gr = pd.concat([sch15d3_AR_gr, 
                        sch15d3_KR_gr,
                        sch15d3_ES_gr,                                    
                        sch15d3_OV_gr,
                        sch15d3_VK_gr,                                   
                        sch15d3_PT_gr, 
                        sch15d3_PS_gr,  
                        sch15d3_SS_gr,                                    
                        sch15d3_TX_gr,
                        sch15d3_DER_gr                                    
                     ], join = "outer").fillna(0)
sch15d3_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d3_mdiscipline_gr.insert(0, 'Building', '15.3')

# Сбор всех помещений в здании
sch15d3_room = pd.concat([sch15d3_AR_room, 
                     ], join = "outer").fillna(0)
sch15d3_room.reset_index(inplace=True, drop=True)
sch15d3_room.insert(0, 'Building', '15.3')
sch15d3_room.Area = pd.to_numeric(sch15d3_room.Area, errors='coerce')
sch15d3_room.Volume = pd.to_numeric(sch15d3_room.Volume, errors='coerce')
sch15d3_room.Perimeter = pd.to_numeric(sch15d3_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d3_room_gr = sch15d3_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.3_Склад ПМ\01_Schedules\TLC_P_I_15.3_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d3_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d3_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d3_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d3_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d3_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch15d3_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch15d3_VK.to_excel(writer, sheet_name='VK_Schedule')
    sch15d3_PS.to_excel(writer, sheet_name='PS_Schedule')    
    sch15d3_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch15d3_SS.to_excel(writer, sheet_name='SS_Schedule')
    sch15d3_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch15d3_DER.to_excel(writer, sheet_name='TX_Schedule')    
    sch15d3_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d3_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.4 Building
# Загрузка спек по дисциплинам
sch15d4_AR = ex_to_df_cnc('TLC', '15.4', 'AR')
sch15d4_KR = ex_to_df_cnc('TLC', '15.4', 'KR')
sch15d4_ES = ex_to_df_cnc('TLC', '15.4', 'ES')
sch15d4_OV = ex_to_df_cnc('TLC', '15.4', 'OV')
sch15d4_VK = ex_to_df_cnc('TLC', '15.4', 'VK')
sch15d4_PT = ex_to_df_cnc('TLC', '15.4', 'PT')
sch15d4_PS = ex_to_df_cnc('TLC', '15.4', 'PS')
sch15d4_SS = ex_to_df_cnc('TLC', '15.4', 'SS')
sch15d4_TX = ex_to_df_cnc('TLC', '15.4', 'TX')
sch15d4_AR_room = ex_to_df('TLC', '15.4', 'AR', 'Room')
#Группировка спек по дисц
sch15d4_AR_gr = sch15d4_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d4_KR_gr = sch15d4_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d4_ES_gr = sch15d4_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4_OV_gr = sch15d4_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4_VK_gr = sch15d4_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4_PT_gr = sch15d4_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4_PS_gr = sch15d4_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d4_SS_gr = sch15d4_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4_TX_gr = sch15d4_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d4_mdiscipline = pd.concat([sch15d4_AR, 
                        sch15d4_KR,
                        sch15d4_ES,                                 
                        sch15d4_OV,
                        sch15d4_VK,                                 
                        sch15d4_PT,
                        sch15d4_PS,    
                        sch15d4_SS,                                   
                        sch15d4_TX
                     ], join = "outer").fillna(0)
sch15d4_mdiscipline.reset_index(inplace=True, drop=True)
sch15d4_mdiscipline.insert(0, 'Building', '15.4')

# Общая спека по зданию сгрупированная
sch15d4_mdiscipline_gr = pd.concat([sch15d4_AR_gr, 
                        sch15d4_KR_gr,
                        sch15d4_ES_gr,                                    
                        sch15d4_OV_gr,
                        sch15d4_VK_gr,                                    
                        sch15d4_PT_gr, 
                        sch15d4_PS_gr, 
                        sch15d4_SS_gr,                                      
                        sch15d4_TX_gr        
                     ], join = "outer").fillna(0)
sch15d4_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d4_mdiscipline_gr.insert(0, 'Building', '15.4')

# Сбор всех помещений в здании
sch15d4_room = pd.concat([sch15d4_AR_room, 
                     ], join = "outer").fillna(0)
sch15d4_room.reset_index(inplace=True, drop=True)
sch15d4_room.insert(0, 'Building', '15.4')
sch15d4_room.Area = pd.to_numeric(sch15d4_room.Area, errors='coerce')
sch15d4_room.Volume = pd.to_numeric(sch15d4_room.Volume, errors='coerce')
sch15d4_room.Perimeter = pd.to_numeric(sch15d4_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d4_room_gr = sch15d4_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.4_Склад МК\01_Schedules\TLC_P_I_15.4_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d4_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d4_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d4_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d4_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d4_ES.to_excel(writer, sheet_name='ES_Schedule')    
    sch15d4_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch15d4_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch15d4_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch15d4_PS.to_excel(writer, sheet_name='PS_Schedule')
    sch15d4_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch15d4_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch15d4_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d4_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.4.1 Building
# Загрузка спек по дисциплинам
sch15d4d1_AR = ex_to_df_cnc('TLC', '15.4.1', 'AR')
sch15d4d1_KR = ex_to_df_cnc('TLC', '15.4.1', 'KR')
sch15d4d1_ES = ex_to_df_cnc('TLC', '15.4.1', 'ES')
sch15d4d1_OV = ex_to_df_cnc('TLC', '15.4.1', 'OV')
sch15d4d1_VK = ex_to_df_cnc('TLC', '15.4.1', 'VK')
sch15d4d1_PT = ex_to_df_cnc('TLC', '15.4.1', 'PT')
sch15d4d1_PS = ex_to_df_cnc('TLC', '15.4.1', 'PS')
sch15d4d1_SS = ex_to_df_cnc('TLC', '15.4.1', 'SS')
sch15d4d1_TX = ex_to_df_cnc('TLC', '15.4.1', 'TX')
sch15d4d1_DER = ex_to_df_cnc('TLC', '15.4.1', 'DER')
sch15d4d1_AR_room = ex_to_df('TLC', '15.4.1', 'AR', 'Room')
#Группировка спек по дисц
sch15d4d1_AR_gr = sch15d4d1_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d4d1_KR_gr = sch15d4d1_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d4d1_ES_gr = sch15d4d1_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d1_OV_gr = sch15d4d1_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d1_VK_gr = sch15d4d1_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d1_PT_gr = sch15d4d1_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d1_PS_gr = sch15d4d1_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d4d1_SS_gr = sch15d4d1_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d1_TX_gr = sch15d4d1_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d4d1_DER_gr = sch15d4d1_DER.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d4d1_mdiscipline = pd.concat([sch15d4d1_AR, 
                        sch15d4d1_KR,
                        sch15d4d1_ES,                                 
                        sch15d4d1_OV,
                        sch15d4d1_VK,                                 
                        sch15d4d1_PT,
                        sch15d4d1_PS,    
                        sch15d4d1_SS,                                   
                        sch15d4d1_TX,
                        sch15d4d1_DER,                        
                     ], join = "outer").fillna(0)
sch15d4d1_mdiscipline.reset_index(inplace=True, drop=True)
sch15d4d1_mdiscipline.insert(0, 'Building', '15.4.1')

# Общая спека по зданию сгрупированная
sch15d4d1_mdiscipline_gr = pd.concat([sch15d4d1_AR_gr, 
                        sch15d4d1_KR_gr,
                        sch15d4d1_ES_gr,                                    
                        sch15d4d1_OV_gr,
                        sch15d4d1_VK_gr,                                    
                        sch15d4d1_PT_gr, 
                        sch15d4d1_PS_gr, 
                        sch15d4d1_SS_gr,                                      
                        sch15d4d1_TX_gr,
                        sch15d4d1_DER_gr,                                
                     ], join = "outer").fillna(0)
sch15d4d1_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d4d1_mdiscipline_gr.insert(0, 'Building', '15.4.1')

# Сбор всех помещений в здании
sch15d4d1_room = pd.concat([sch15d4d1_AR_room, 
                     ], join = "outer").fillna(0)
sch15d4d1_room.reset_index(inplace=True, drop=True)
sch15d4d1_room.insert(0, 'Building', '15.4.1')
sch15d4d1_room.Area = pd.to_numeric(sch15d4d1_room.Area, errors='coerce')
sch15d4d1_room.Volume = pd.to_numeric(sch15d4d1_room.Volume, errors='coerce')
sch15d4d1_room.Perimeter = pd.to_numeric(sch15d4d1_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d4d1_room_gr = sch15d4d1_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.4_Склад МК\15.4.1\01_Schedules\TLC_P_I_15.4.1_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d4d1_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d4d1_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d4d1_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d4d1_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d4d1_ES.to_excel(writer, sheet_name='ES_Schedule')    
    sch15d4d1_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch15d4d1_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch15d4d1_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch15d4d1_PS.to_excel(writer, sheet_name='PS_Schedule')
    sch15d4d1_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch15d4d1_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch15d4d1_DER.to_excel(writer, sheet_name='DER_Schedule')    
    sch15d4d1_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d4d1_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.4.2 Building
# Загрузка спек по дисциплинам
sch15d4d2_AR = ex_to_df_cnc('TLC', '15.4.2', 'AR')
sch15d4d2_KR = ex_to_df_cnc('TLC', '15.4.2', 'KR')
sch15d4d2_ES = ex_to_df_cnc('TLC', '15.4.2', 'ES')
sch15d4d2_OV = ex_to_df_cnc('TLC', '15.4.2', 'OV')
sch15d4d2_VK = ex_to_df_cnc('TLC', '15.4.2', 'VK')
sch15d4d2_PT = ex_to_df_cnc('TLC', '15.4.2', 'PT')
sch15d4d2_PS = ex_to_df_cnc('TLC', '15.4.2', 'PS')
sch15d4d2_SS = ex_to_df_cnc('TLC', '15.4.2', 'SS')
sch15d4d2_TX = ex_to_df_cnc('TLC', '15.4.2', 'TX')
#sch15d4d2_DER = ex_to_df_cnc('TLC', '15.4.2', 'DER')
sch15d4d2_AR_room = ex_to_df('TLC', '15.4.2', 'AR', 'Room')
#Группировка спек по дисц
sch15d4d2_AR_gr = sch15d4d2_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d4d2_KR_gr = sch15d4d2_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d4d2_ES_gr = sch15d4d2_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d2_OV_gr = sch15d4d2_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d2_VK_gr = sch15d4d2_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d2_PT_gr = sch15d4d2_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d2_PS_gr = sch15d4d2_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d4d2_SS_gr = sch15d4d2_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d4d2_TX_gr = sch15d4d2_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch15d4d2_DER_gr = sch15d4d2_DER.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d4d2_mdiscipline = pd.concat([sch15d4d2_AR, 
                        sch15d4d2_KR,
                        sch15d4d2_ES,                                 
                        sch15d4d2_OV,
                        sch15d4d2_VK,                                 
                        sch15d4d2_PT,
                        sch15d4d2_PS,    
                        sch15d4d2_SS,                                   
                        sch15d4d2_TX,
#                        sch15d4d2_DER,                        
                     ], join = "outer").fillna(0)
sch15d4d2_mdiscipline.reset_index(inplace=True, drop=True)
sch15d4d2_mdiscipline.insert(0, 'Building', '15.4.2')

# Общая спека по зданию сгрупированная
sch15d4d2_mdiscipline_gr = pd.concat([sch15d4d2_AR_gr, 
                        sch15d4d2_KR_gr,
                        sch15d4d2_ES_gr,                                    
                        sch15d4d2_OV_gr,
                        sch15d4d2_VK_gr,                                    
                        sch15d4d2_PT_gr, 
                        sch15d4d2_PS_gr, 
                        sch15d4d2_SS_gr,                                      
                        sch15d4d2_TX_gr,
#                        sch15d4d2_DER_gr,                                
                     ], join = "outer").fillna(0)
sch15d4d2_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d4d2_mdiscipline_gr.insert(0, 'Building', '15.4.2')

# Сбор всех помещений в здании
sch15d4d2_room = pd.concat([sch15d4d2_AR_room, 
                     ], join = "outer").fillna(0)
sch15d4d2_room.reset_index(inplace=True, drop=True)
sch15d4d2_room.insert(0, 'Building', '15.4.2')
sch15d4d2_room.Area = pd.to_numeric(sch15d4d2_room.Area, errors='coerce')
sch15d4d2_room.Volume = pd.to_numeric(sch15d4d2_room.Volume, errors='coerce')
sch15d4d2_room.Perimeter = pd.to_numeric(sch15d4d2_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d4d2_room_gr = sch15d4d2_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.4_Склад МК\15.4.2\01_Schedules\TLC_P_I_15.4.2_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d4d2_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d4d2_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d4d2_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d4d2_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d4d2_ES.to_excel(writer, sheet_name='ES_Schedule')    
    sch15d4d2_OV.to_excel(writer, sheet_name='OV_Schedule')
    sch15d4d2_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch15d4d2_PT.to_excel(writer, sheet_name='PT_Schedule')
    sch15d4d2_PS.to_excel(writer, sheet_name='PS_Schedule')
    sch15d4d2_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch15d4d2_TX.to_excel(writer, sheet_name='TX_Schedule')
#    sch15d4d2_DER.to_excel(writer, sheet_name='DER_Schedule')    
    sch15d4d2_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d4d2_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.5 Building
# Загрузка спек по дисциплинам
sch15d5_AR_A = ex_to_df_cnc('TLC', '15.5', 'AR', 'A')
sch15d5_AR_B = ex_to_df_cnc('TLC', '15.5', 'AR', 'B')
sch15d5_KR_A = ex_to_df_cnc('TLC', '15.5', 'KR', 'A')
sch15d5_KR_B = ex_to_df_cnc('TLC', '15.5', 'KR', 'B')
sch15d5_ES_A = ex_to_df_cnc('TLC', '15.5', 'ES', 'A')
sch15d5_ES_B = ex_to_df_cnc('TLC', '15.5', 'ES', 'B')
sch15d5_OV_A = ex_to_df_cnc('TLC', '15.5', 'OV', 'A')
#sch15d5_OV_B = ex_to_df_cnc('TLC', '15.5', 'OV', 'B')
sch15d5_VK_A = ex_to_df_cnc('TLC', '15.5', 'VK', 'A')
sch15d5_VK_B = ex_to_df_cnc('TLC', '15.5', 'VK', 'B')
sch15d5_PT_A = ex_to_df_cnc('TLC', '15.5', 'PT', 'A')
sch15d5_PT_B = ex_to_df_cnc('TLC', '15.5', 'PT', 'B')
sch15d5_PS_A = ex_to_df_cnc('TLC', '15.5', 'PS', 'A')
sch15d5_PS_B = ex_to_df_cnc('TLC', '15.5', 'PS', 'B')
sch15d5_SS_A = ex_to_df_cnc('TLC', '15.5', 'SS', 'A')
sch15d5_SS_B = ex_to_df_cnc('TLC', '15.5', 'SS', 'B')
sch15d5_TX_A = ex_to_df_cnc('TLC', '15.5', 'TX', 'A')
sch15d5_TX_B = ex_to_df_cnc('TLC', '15.5', 'TX', 'B')

sch15d5_AR = pd.concat([sch15d5_AR_A,
                        sch15d5_AR_B,
                     ], join = "outer").fillna(0)                       
sch15d5_KR = pd.concat([sch15d5_KR_A,
                        sch15d5_KR_B,                                
                     ], join = "outer").fillna(0)
sch15d5_ES = pd.concat([sch15d5_ES_A,
                        sch15d5_ES_B,
                     ], join = "outer").fillna(0) 
sch15d5_OV = pd.concat([sch15d5_OV_A,
#                        sch15d5_OV_B,
                     ], join = "outer").fillna(0)
sch15d5_VK = pd.concat([sch15d5_VK_A,
                        sch15d5_VK_B,
                     ], join = "outer").fillna(0) 
sch15d5_PT = pd.concat([sch15d5_PT_A,
                        sch15d5_PT_B,                                
                     ], join = "outer").fillna(0)
sch15d5_PS = pd.concat([sch15d5_PS_A,
                        sch15d5_PS_B,                                
                     ], join = "outer").fillna(0)
sch15d5_SS = pd.concat([sch15d5_SS_A,
                        sch15d5_SS_B,                                
                     ], join = "outer").fillna(0)
sch15d5_TX = pd.concat([sch15d5_TX_A,
                        sch15d5_TX_B,                                
                     ], join = "outer").fillna(0)

sch15d5_AR_room_A = ex_to_df('TLC', '15.5', 'AR', 'Room','A')
sch15d5_AR_room_B = ex_to_df('TLC', '15.5', 'AR', 'Room','B')

#Группировка спек по дисц
sch15d5_AR_gr = sch15d5_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d5_KR_gr = sch15d5_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d5_ES_gr = sch15d5_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d5_SS_gr = sch15d5_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d5_OV_gr = sch15d5_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d5_VK_gr = sch15d5_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d5_PT_gr = sch15d5_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d5_PS_gr = sch15d5_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d5_TX_gr = sch15d5_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d5_mdiscipline = pd.concat([sch15d5_AR, 
                        sch15d5_KR,
                        sch15d5_ES,                                 
                        sch15d5_OV,
                        sch15d5_VK,                                 
                        sch15d5_PT,
                        sch15d5_PS,
                        sch15d5_SS,                                 
                        sch15d5_TX
                     ], join = "outer").fillna(0)
sch15d5_mdiscipline.reset_index(inplace=True, drop=True)
sch15d5_mdiscipline.insert(0, 'Building', '15.5')

# Общая спека по зданию сгрупированная
sch15d5_mdiscipline_gr = pd.concat([sch15d5_AR_gr, 
                        sch15d5_KR_gr,
                        sch15d5_ES_gr, 
                        sch15d5_OV_gr,
                        sch15d5_VK_gr,
                        sch15d5_PT_gr, 
                        sch15d5_PS_gr,  
                        sch15d5_SS_gr,                                    
                        sch15d5_TX_gr        
                     ], join = "outer").fillna(0)
sch15d5_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d5_mdiscipline_gr.insert(0, 'Building', '15.5')

# Сбор всех помещений в здании
sch15d5_room = pd.concat([sch15d5_AR_room_A,
                          sch15d5_AR_room_B
                     ], join = "outer").fillna(0)
sch15d5_room.reset_index(inplace=True, drop=True)
sch15d5_room.insert(0, 'Building', '15.5')
sch15d5_room.Area = pd.to_numeric(sch15d5_room.Area, errors='coerce')
sch15d5_room.Volume = pd.to_numeric(sch15d5_room.Volume, errors='coerce')
sch15d5_room.Perimeter = pd.to_numeric(sch15d5_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d5_room_gr = sch15d5_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.5_Склад ТГ\01_Schedules\TLC_P_I_15.5_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d5_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d5_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d5_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d5_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d5_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch15d5_OV.to_excel(writer, sheet_name='OV_Schedule')   
    sch15d5_VK.to_excel(writer, sheet_name='VK_Schedule')     
    sch15d5_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch15d5_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch15d5_SS.to_excel(writer, sheet_name='SS_Schedule')     
    sch15d5_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch15d5_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d5_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
sch15d5_KR['Steel'] = sch15d5_KR['Family and Type'].str.contains("120х4_C255")
sch15d5_KR['Steel']
sch15d5_KR.query("Steel == True")

# %%
df15d5kr = pd.read_excel(pathfile, sheet_name = 'VTBR_Multi-Category')

# %%
# 15.6 Building
# Загрузка спек по дисциплинам
sch15d6_AR = ex_to_df_cnc('TLC', '15.6', 'AR')
sch15d6_KR = ex_to_df_cnc('TLC', '15.6', 'KR')
sch15d6_ES = ex_to_df_cnc('TLC', '15.6', 'ES')
sch15d6_OV = ex_to_df_cnc('TLC', '15.6', 'OV')
sch15d6_VK = ex_to_df_cnc('TLC', '15.6', 'VK')
sch15d6_PT = ex_to_df_cnc('TLC', '15.6', 'PT')
sch15d6_PS = ex_to_df_cnc('TLC', '15.6', 'PS')
sch15d6_SS = ex_to_df_cnc('TLC', '15.6', 'SS')
sch15d6_TX = ex_to_df_cnc('TLC', '15.6', 'TX')

sch15d6_AR_room = ex_to_df('TLC', '15.6', 'AR', 'Room')
#Группировка спек по дисц
sch15d6_AR_gr = sch15d6_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d6_KR_gr = sch15d6_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d6_ES_gr = sch15d6_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d6_OV_gr = sch15d6_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d6_VK_gr = sch15d6_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d6_PT_gr = sch15d6_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d6_PS_gr = sch15d6_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d6_SS_gr = sch15d6_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d6_TX_gr = sch15d6_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d6_mdiscipline = pd.concat([sch15d6_AR, 
                        sch15d6_KR,
                        sch15d6_ES,                                 
                        sch15d6_OV,
                        sch15d6_VK,                                 
                        sch15d6_PT,
                        sch15d6_PS,
                        sch15d6_SS,                                 
                        sch15d6_TX
                     ], join = "outer").fillna(0)
sch15d6_mdiscipline.reset_index(inplace=True, drop=True)
sch15d6_mdiscipline.insert(0, 'Building', '15.6')

# Общая спека по зданию сгрупированная
sch15d6_mdiscipline_gr = pd.concat([sch15d6_AR_gr, 
                        sch15d6_KR_gr,
                        sch15d6_ES_gr,                                    
                        sch15d6_OV_gr,
                        sch15d6_VK_gr,                                    
                        sch15d6_PT_gr,
                        sch15d6_PS_gr,
                        sch15d6_SS_gr,                                     
                        sch15d6_TX_gr        
                     ], join = "outer").fillna(0)
sch15d6_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d6_mdiscipline_gr.insert(0, 'Building', '15.6')

# Сбор всех помещений в здании
sch15d6_room = pd.concat([sch15d6_AR_room, 
                     ], join = "outer").fillna(0)
sch15d6_room.reset_index(inplace=True, drop=True)
sch15d6_room.insert(0, 'Building', '15.6')
sch15d6_room.Area = pd.to_numeric(sch15d6_room.Area, errors='coerce')
sch15d6_room.Volume = pd.to_numeric(sch15d6_room.Volume, errors='coerce')
sch15d6_room.Perimeter = pd.to_numeric(sch15d6_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d6_room_gr = sch15d6_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.6_Склад АТ\01_Schedules\TLC_P_I_15.6_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d6_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d6_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d6_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d6_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d6_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch15d6_OV.to_excel(writer, sheet_name='OV_Schedule') 
    sch15d6_VK.to_excel(writer, sheet_name='VK_Schedule')     
    sch15d6_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch15d6_PS.to_excel(writer, sheet_name='PS_Schedule')  
    sch15d6_SS.to_excel(writer, sheet_name='SS_Schedule')      
    sch15d6_TX.to_excel(writer, sheet_name='TX_Schedule') 
    sch15d6_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d6_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 15.7 Building
# Загрузка спек по дисциплинам
sch15d7_AR_A = ex_to_df_cnc('TLC', '15.7', 'AR', 'A')
sch15d7_AR_B = ex_to_df_cnc('TLC', '15.7', 'AR', 'B')
sch15d7_AR_C = ex_to_df_cnc('TLC', '15.7', 'AR', 'C')
sch15d7_AR_room_A = ex_to_df('TLC', '15.7', 'AR', 'Room', 'A')
sch15d7_AR_room_B = ex_to_df('TLC', '15.7', 'AR', 'Room', 'B')
sch15d7_AR_room_C = ex_to_df('TLC', '15.7', 'AR', 'Room', 'C')
sch15d7_KR_A = ex_to_df_cnc('TLC', '15.7', 'KR', 'A')
sch15d7_KR_B = ex_to_df_cnc('TLC', '15.7', 'KR', 'B')
sch15d7_KR_C = ex_to_df_cnc('TLC', '15.7', 'KR', 'C')
sch15d7_ES_A = ex_to_df_cnc('TLC', '15.7', 'ES', 'A')
sch15d7_ES_B = ex_to_df_cnc('TLC', '15.7', 'ES', 'B')
sch15d7_ES_C = ex_to_df_cnc('TLC', '15.7', 'ES', 'C')
sch15d7_OV_A = ex_to_df_cnc('TLC', '15.7', 'OV', 'A')
sch15d7_OV_B = ex_to_df_cnc('TLC', '15.7', 'OV', 'B')
sch15d7_OV_C = ex_to_df_cnc('TLC', '15.7', 'OV', 'C')
sch15d7_VK_A = ex_to_df_cnc('TLC', '15.7', 'VK', 'A')
sch15d7_VK_B = ex_to_df_cnc('TLC', '15.7', 'VK', 'B')
sch15d7_VK_C = ex_to_df_cnc('TLC', '15.7', 'VK', 'C')
sch15d7_PT_A = ex_to_df_cnc('TLC', '15.7', 'PT', 'A')
sch15d7_PT_B = ex_to_df_cnc('TLC', '15.7', 'PT', 'B')
sch15d7_PT_C = ex_to_df_cnc('TLC', '15.7', 'PT', 'C')
sch15d7_PS_A = ex_to_df_cnc('TLC', '15.7', 'PS', 'A')
sch15d7_PS_B = ex_to_df_cnc('TLC', '15.7', 'PS', 'B')
sch15d7_PS_C = ex_to_df_cnc('TLC', '15.7', 'PS', 'C')
sch15d7_SS_A = ex_to_df_cnc('TLC', '15.7', 'SS', 'A')
sch15d7_SS_B = ex_to_df_cnc('TLC', '15.7', 'SS', 'B')
sch15d7_SS_C = ex_to_df_cnc('TLC', '15.7', 'SS', 'C')
sch15d7_TX_A = ex_to_df_cnc('TLC', '15.7', 'TX', 'A')
sch15d7_TX_B = ex_to_df_cnc('TLC', '15.7', 'TX', 'B')
sch15d7_TX_C = ex_to_df_cnc('TLC', '15.7', 'TX', 'C')

sch15d7_AR = pd.concat([sch15d7_AR_A,
                        sch15d7_AR_B,
                        sch15d7_AR_C
                     ], join = "outer").fillna(0)                       
sch15d7_KR = pd.concat([sch15d7_KR_A,
                        sch15d7_KR_B,                                
                        sch15d7_KR_C
                     ], join = "outer").fillna(0)
sch15d7_ES = pd.concat([sch15d7_ES_A,
                        sch15d7_ES_B,                                
                        sch15d7_ES_C
                     ], join = "outer").fillna(0)
sch15d7_OV = pd.concat([sch15d7_OV_A,
                        sch15d7_OV_B,                                
                        sch15d7_OV_C
                     ], join = "outer").fillna(0)
sch15d7_VK = pd.concat([sch15d7_VK_A,
                        sch15d7_VK_B,                                
                        sch15d7_VK_C
                     ], join = "outer").fillna(0)
sch15d7_PT = pd.concat([sch15d7_PT_A,                                
                        sch15d7_PT_B,
                        sch15d7_PT_C
                     ], join = "outer").fillna(0)
sch15d7_PS = pd.concat([sch15d7_PS_A,                                
                        sch15d7_PS_B,
                        sch15d7_PS_C
                     ], join = "outer").fillna(0)
sch15d7_SS = pd.concat([sch15d7_SS_A,                                
                        sch15d7_SS_B,
                        sch15d7_SS_C
                     ], join = "outer").fillna(0)
sch15d7_TX = pd.concat([sch15d7_TX_A,
                        sch15d7_TX_B,                                
                        sch15d7_TX_C                                
                     ], join = "outer").fillna(0)

#Группировка спек по дисц
sch15d7_AR_gr = sch15d7_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch15d7_KR_gr = sch15d7_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch15d7_ES_gr = sch15d7_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d7_OV_gr = sch15d7_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d7_VK_gr = sch15d7_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
sch15d7_PS_gr = sch15d7_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d7_SS_gr = sch15d7_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d7_PT_gr = sch15d7_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch15d7_TX_gr = sch15d7_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch15d7_mdiscipline = pd.concat([sch15d7_AR,
                        sch15d7_KR, 
                        sch15d7_ES,
                        sch15d7_OV,
                        sch15d7_VK,
                        sch15d7_PS,                                 
                        sch15d7_PT,
                        sch15d7_SS,                                  
                        sch15d7_TX     
                     ], join = "outer").fillna(0)
sch15d7_mdiscipline.reset_index(inplace=True, drop=True)
sch15d7_mdiscipline.insert(0, 'Building', '15.7')

#Общая спека по зданию сгрупированная
sch15d7_mdiscipline_gr = pd.concat([sch15d7_AR_gr, 
                        sch15d7_KR_gr,
                        sch15d7_ES_gr,
                        sch15d7_OV_gr,
                        sch15d7_VK_gr, 
                        sch15d7_PS_gr,                                    
                        sch15d7_PT_gr,
                        sch15d7_SS_gr,                                    
                        sch15d7_TX_gr          
                     ], join = "outer").fillna(0)
sch15d7_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch15d7_mdiscipline_gr.insert(0, 'Building', '15.7')

# Сбор всех помещений в здании
sch15d7_room = pd.concat([sch15d7_AR_room_A,
                         sch15d7_AR_room_B,
                         sch15d7_AR_room_C
                     ], join = "outer").fillna(0)
sch15d7_room.reset_index(inplace=True, drop=True)
sch15d7_room.insert(0, 'Building', '15.7')
sch15d7_room.Area = pd.to_numeric(sch15d7_room.Area, errors='coerce')
sch15d7_room.Volume = pd.to_numeric(sch15d7_room.Volume, errors='coerce')
sch15d7_room.Perimeter = pd.to_numeric(sch15d7_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
sch15d7_room_gr = sch15d7_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\15.7_Склад ТШП\01_Schedules\TLC_P_I_15.7_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch15d7_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch15d7_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
    sch15d7_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch15d7_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch15d7_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch15d7_OV.to_excel(writer, sheet_name='OV_Schedule') 
    sch15d7_VK.to_excel(writer, sheet_name='VK_Schedule')    
    sch15d7_PT.to_excel(writer, sheet_name='PT_Schedule') 
    sch15d7_PS.to_excel(writer, sheet_name='PS_Schedule') 
    sch15d7_SS.to_excel(writer, sheet_name='SS_Schedule')    
    sch15d7_TX.to_excel(writer, sheet_name='TX_Schedule')
    sch15d7_room.to_excel(writer, sheet_name='All_Rooms')
    sch15d7_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# 18 Building
# Загрузка спек по дисциплинам
#sch18_AR = ex_to_df_cnc('TLC', '18', 'AR')
sch18_KR = ex_to_df_cnc('TLC', '18', 'KR')
sch18_ES = ex_to_df_cnc('TLC', '18', 'ES')
sch18_SS = ex_to_df_cnc('TLC', '18', 'SS')
#sch18_OV = ex_to_df_cnc('TLC', '18', 'OV')
#sch18_VK = ex_to_df_cnc('TLC', '18', 'VK')
#sch18_PT = ex_to_df_cnc('TLC', '18', 'PT')
#sch18_PS = ex_to_df_cnc('TLC', '18', 'PS')
#sch18_TX = ex_to_df_cnc('TLC', '18', 'TX')
#sch18_AR_room = ex_to_df('TLC', '18', 'AR', 'Room')
#Группировка спек по дисц
#sch18_AR_gr = sch18_AR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum','Volume': 'sum'})
sch18_KR_gr = sch18_KR.groupby(['Category', 'Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})
sch18_ES_gr = sch18_ES.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
sch18_SS_gr = sch18_SS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch18_OV_gr = sch18_OV.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch18_VK_gr = sch18_VK.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch18_PT_gr = sch18_PT.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Length': 'sum'})
#sch18_PS_gr = sch18_PS.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})
#sch18_TX_gr = sch18_TX.groupby(['Category','Discipline'], as_index=False).aggregate({'Count': 'sum'})

# Общая спека по зданию
sch18_mdiscipline = pd.concat([#sch18_AR, 
                        sch18_KR,
                        sch18_ES,                                 
                        sch18_SS,                                  
#                        sch18_OV,
#                        sch18_VK,                                 
#                        sch18_PT,
#                        sch18_PS,                                 
#                        sch18_TX
                     ], join = "outer").fillna(0)
sch18_mdiscipline.reset_index(inplace=True, drop=True)
sch18_mdiscipline.insert(0, 'Building', '18')

# Общая спека по зданию сгрупированная
sch18_mdiscipline_gr = pd.concat([#sch18_AR_gr, 
                        sch18_KR_gr,
                        sch18_ES_gr,
                        sch18_SS_gr,                                    
#                        sch18_OV_gr,
#                        sch18_VK_gr,                                    
#                        sch18_PT_gr,
#                        sch18_PS_gr,                                    
#                        sch18_TX_gr        
                     ], join = "outer").fillna(0)
sch18_mdiscipline_gr.reset_index(inplace=True, drop=True)
sch18_mdiscipline_gr.insert(0, 'Building', '18')

# Сбор всех помещений в здании
#sch18_room = pd.concat([sch18_AR_room, 
#                     ], join = "outer").fillna(0)
#sch18_room.reset_index(inplace=True, drop=True)
#sch18_room.insert(0, 'Building', '18')
#sch18_room.Area = pd.to_numeric(sch18_room.Area, errors='coerce')
#sch18_room.Volume = pd.to_numeric(sch18_room.Volume, errors='coerce')
#sch18_room.Perimeter = pd.to_numeric(sch18_room.Perimeter, errors='coerce')
# Группировка помещений по назначению 
#sch18_room_gr = sch18_room.groupby(['Building','Department'], as_index=False).aggregate({'Count': 'sum','Perimeter': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\18\01_Schedules\TLC_P_I_18_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch18_mdiscipline_gr.to_excel(writer, sheet_name='Total_Schedule')
    sch18_mdiscipline.to_excel(writer, sheet_name='Summary_Schedule')
#    sch18_AR.to_excel(writer, sheet_name='AR_Schedule')
    sch18_KR.to_excel(writer, sheet_name='KR_Schedule')
    sch18_ES.to_excel(writer, sheet_name='ES_Schedule')
    sch18_SS.to_excel(writer, sheet_name='SS_Schedule')    
#    sch18_OV.to_excel(writer, sheet_name='OV_Schedule') 
#    sch18_VK.to_excel(writer, sheet_name='VK_Schedule')     
#    sch18_PT.to_excel(writer, sheet_name='PT_Schedule') 
#    sch18_PS.to_excel(writer, sheet_name='PS_Schedule')     
#    sch18_TX.to_excel(writer, sheet_name='TX_Schedule') 
#    sch18_room.to_excel(writer, sheet_name='All_Rooms')
#    sch18_room_gr.to_excel(writer, sheet_name='Rooms by function')

# %%
# Схлопавание всех зданий в одну спецификацию
sch_buildings_category = pd.concat([
                        sch1_mdiscipline_gr,
                        sch2_mdiscipline_gr,
                        sch3_mdiscipline_gr,
                        sch4_mdiscipline_gr,
                        sch5d1_mdiscipline_gr,
                        sch7d4_mdiscipline_gr,                                    
                        sch15d1_mdiscipline_gr,                                    
                        sch15d2_mdiscipline_gr,
                        sch15d3_mdiscipline_gr,
                        sch15d4_mdiscipline_gr,
                        sch15d5_mdiscipline_gr,  
                        sch15d6_mdiscipline_gr, 
                        sch15d7_mdiscipline_gr                                     
                     ], join = "outer").fillna(0)
sch_buildings_category.reset_index(inplace=True, drop=True)
sch_buildings_category.insert(0, 'Project', 'TLC')

sch_buildings_room = pd.concat([
                        sch1_room,
                        sch2_room,
                        sch3_room,
                        sch4_room,
                        sch5d1_room,
                        sch7d4_room,                                    
                        sch15d1_room,                                    
                        sch15d2_room,
                        sch15d3_room,
                        sch15d4_room,
                        sch15d5_room,  
                        sch15d6_room, 
                        sch15d7_room
                     ], join = "outer").fillna(0)
sch_buildings_room.reset_index(inplace=True, drop=True)
sch_buildings_room.insert(0, 'Project', 'TLC')
sch_buildings_room_sum = sch_buildings_room.groupby(['Project', 'Building'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum'})

sch_buildings_Discipline = sch_buildings_category.groupby(['Project', 'Building','Discipline'], as_index=False).aggregate({'Count': 'sum', 'Area': 'sum', 'Volume': 'sum'})

# Проект TLC Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(pathfolder + r'\0_Schedules\TLC_P_I_X_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    sch_buildings_Discipline.to_excel(writer, sheet_name='Buildings, Discipline')
    sch_buildings_category.to_excel(writer, sheet_name='Buildings,Category')
    sch_buildings_room.to_excel(writer, sheet_name='Type of Rooms, Area')
    sch_buildings_room_sum.to_excel(writer, sheet_name='Total Area')
