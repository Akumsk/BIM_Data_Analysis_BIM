# %%
import pandas as pd
import numpy as np
import pathlib
import datetime
import xlrd
import openpyxl
from configurations import config 
import os

# %%
path_boq = config['path']['tlc_boq']

# %%
df_TLC_boq = pd.read_excel(path_boq + '\КП переторжка 2-BOQ_ver40_27.04.2022_ВТБН_ПСО_ЭСТА_МБМ_тернер 2' + r'.xlsx', sheet_name = 'Смета 1-3 этапы', header=15)
df_TLC_boq.drop(['Unnamed: 0',
              'Unnamed: 1',              
              'Unnamed: 2',              
              'Unnamed: 3',              
              'Unnamed: 4',              
              'Unnamed: 5',              
              'Unnamed: 6',
              'Unnamed: 7'],  
             axis=1, inplace=True)
df_TLC_boq.drop(df_TLC_boq.columns[11:], axis=1, inplace=True)

df_TLC_boq.rename(columns = {"No." : "Level_gr", 
                        "'Код статьи бюджета" : "Code", 
                        "Раздел, том, чертеж" : "Tom", 
                        "Наименование" : "Description", 
                        "Кол-во" : "Kol_vo",
                        "Ед. изм." : "Ed. izm.",
                        "Цена за ед. изм.\nРуб. с НДС (20%)" : "Price_one_mat",                          
                        'Unnamed: 15' : 'Price_one_work',                          
                        'Сумма\nРуб. с НДС (20%)': 'Price_sum_mat',                         
                        'Unnamed: 17': 'Price_sum_work',                         
                        'Стоимость Руб.,': 'Sum_price'
                         }, inplace=True)

df_TLC_boq['gr_1'] = np.nan
df_TLC_boq['gr_2'] = np.nan
df_TLC_boq['gr_3'] = np.nan
df_TLC_boq['gr_4'] = np.nan
df_TLC_boq['gr_5'] = np.nan
df_TLC_boq.Kol_vo = pd.to_numeric(df_TLC_boq.Kol_vo, errors='coerce')

# %%
for i in range(0,len(df_TLC_boq)):
    if ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 1)):
        df_TLC_boq.loc[i, 'gr_1'] = df_TLC_boq.loc[i, 'Description']
    elif ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 2)):
        df_TLC_boq.loc[i, 'gr_2'] = df_TLC_boq.loc[i, 'Description']       
    elif ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 3)):
        df_TLC_boq.loc[i, 'gr_3'] = df_TLC_boq.loc[i, 'Description'] 
    elif ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 4)):
        df_TLC_boq.loc[i, 'gr_4'] = df_TLC_boq.loc[i, 'Description']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Level_gr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-5095d56c6050> in <module>
#       1 for i in range(0,len(df_TLC_boq)):
# ----> 2     if ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 1)):
#       3         df_TLC_boq.loc[i, 'gr_1'] = df_TLC_boq.loc[i, 'Description']
#       4     elif ((pd.isna(df_TLC_boq.loc[i, 'Kol_vo']) == True) & (df_TLC_boq.loc[i,'Level_gr'] == 2)):
#       5         df_TLC_boq.loc[i, 'gr_2'] = df_TLC_boq.loc[i, 'Description']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Level_gr'

# %%
import re
str(df_TLC_boq.No[51])
count = len(re.findall(r'\b\d+\b', str(df_TLC_boq.No[51])))
count
# Out:
# 4

# %%
l = 
for i in range(df_TLC_boq.size):


df_TLC_boq['Level_gr'] = len(re.findall(r'\b\d+\b', str(df_TLC_boq.No)))
df_TLC_boq
# Out:
#                No Код статьи бюджета  Tom                       Description  \
# 0             NaN                NaN  NaN                               NaN
# 1             NaN                NaN  NaN                               NaN
# 2             NaN                NaN  NaN                            ЭТАП 1
# 3       0.1......                NaN  NaN                       Мобилизация
# 4      0.1.1.....                NaN  NaN  Банковские Гарантии, Страхование
# ...           ...                ...  ...                               ...
# 16660         NaN                NaN  NaN                    Лимитированные
# 16661         NaN                NaN  NaN                               NaN
# 16662         NaN                NaN  NaN                               NaN
# 16663         NaN                NaN  NaN                               NaN
# 16664         NaN                NaN  NaN                               NaN
#
#          Kol_vo Ed. izm. Price_one_mat Price_one_work Price_sum_mat  \
# 0           NaN      NaN      Материал         Работа      Материал
# 1           NaN      NaN           NaN            NaN           NaN
# 2           NaN      NaN           NaN            NaN           NaN
# 3      53004.11      NaN           NaN            NaN  162565630.61
# 4           NaN      NaN           NaN            NaN             0
# ...         ...      ...           ...            ...           ...
# 16660       NaN      NaN           NaN            NaN             0
# 16661       NaN      NaN           NaN            NaN           NaN
# 16662       NaN      NaN           NaN            NaN           NaN
# 16663       NaN      NaN           NaN            NaN           NaN
# 16664       NaN      NaN           NaN            NaN           NaN
#
#       Price_sum_work     Sum_price  gr_1  gr_2  gr_3  gr_4  gr_5  Level_gr
# 0             Работа     с НДС 20%   NaN   NaN   NaN   NaN   NaN        16
# 1                NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
# 2                NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
# 3       194551865.23  357117495.84   NaN   NaN   NaN   NaN   NaN        16
# 4       111013408.88  111013408.88   NaN   NaN   NaN   NaN   NaN        16
# ...              ...           ...   ...   ...   ...   ...   ...       ...
# 16660              0             0   NaN   NaN   NaN   NaN   NaN        16
# 16661            NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
# 16662            NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
# 16663            NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
# 16664            NaN           NaN   NaN   NaN   NaN   NaN   NaN        16
#
# [16665 rows x 17 columns]

# %%
for i in range(0,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 1)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i, 'Description']
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 2)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i, 'Description']       
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 3)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i, 'Description'] 
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 4)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i, 'Description']         
        
        
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_1']) == True)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'gr_1']
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_2']) == True)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i-1, 'gr_2']      
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_3']) == True)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i-1, 'gr_3'] 
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_4']) == True)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i-1, 'gr_4']         
        
with pd.ExcelWriter(r'X:\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\04 - ТД\08 - BIM\997_Отчеты\Power BI\Структура стоимости ППК все этапы (1 очередь)_gr' + '.xlsx') as writer:  
    df_test.to_excel(writer, sheet_name='1.1_МО')

df_test.to_csv(r'X:\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\04 - ТД\08 - BIM\997_Отчеты\Power BI\Структура стоимости ППК все этапы (1 очередь)_gr' + '.csv') 
                 
    
    
df_test.loc[740:770]
# Out:
#       Level_gr                       No                  Code  \
# 0          NaN                      NaN                   NaN
# 1          NaN                        1                   NaN
# 2          NaN                 1.1.....                   NaN
# 3          1.0                1.1.1....                   NaN
# 4          5.0               1.1.1.1...  02.01.08.02.01.01.08
# ...        ...                      ...                   ...
# 3566       NaN                      NaN                   NaN
# 3567       NaN                      NaN                   NaN
# 3568       NaN     02.01.08.02.08.01.08                   NaN
# 3569       NaN     02.01.08.02.08.01.08                   NaN
# 3570       NaN  02.01.08.02.08.01.20.04                     0
#
#                    Tom                                        Description  \
# 0                  NaN                                                NaN
# 1                  NaN                                                  2
# 2                  NaN  Многофункциональный мелкооптовый складской ком...
# 3                  NaN                                    Земляные работы
# 4     ORC_T_III_1.1_KR  Засыпка. Выполняется с отм -0.500 до отм -0.20...
# ...                ...                                                ...
# 3566               NaN                                                NaN
# 3567               NaN                                   Электроснабжение
# 3568               NaN                           ППГнг(А)-HF 3х2,5 -1 кВ
# 3569               NaN                             ППГнг(А)-HF 3х4 -1 кВ
# 3570               NaN  Гофрированная труба из ПВХ, Д25 (с учетом всех...
#
#      Ed_izm   Kol_vo  Kol_vo_podr Price_one_mat Price_one_work  ...  \
# 0       NaN      NaN          NaN      Материал         Работа  ...
# 1         4     3.00          NaN             5              6  ...
# 2       NaN      NaN          NaN           NaN            NaN  ...
# 3       NaN      NaN          NaN           NaN            NaN  ...
# 4        м3  9620.22          NaN           NaN            NaN  ...
# ...     ...      ...          ...           ...            ...  ...
# 3566    NaN      NaN          NaN           NaN            NaN  ...
# 3567    NaN      NaN          NaN           NaN            NaN  ...
# 3568     шт  1500.00          NaN           NaN            NaN  ...
# 3569     шт   500.00          NaN           NaN            NaN  ...
# 3570     шт  2000.00          NaN           NaN            NaN  ...
#
#        Sum_price                      Mark    Manufacturer Sovm_zak_obor  \
# 0      с НДС 20%                       NaN             NaN           NaN
# 1              9                       NaN             NaN           NaN
# 2              0                       NaN             NaN           NaN
# 3              0                       NaN             NaN           NaN
# 4              0                       NaN             NaN           NaN
# ...          ...                       ...             ...           ...
# 3566         NaN                       NaN             NaN           NaN
# 3567           0                       NaN             NaN           NaN
# 3568           0  ППГнг(А)-HF 3х2,5 -1 кВ   Сегмент Энерго           NaN
# 3569           0    ППГнг(А)-HF 3х4 -1 кВ   Сегмент Энерго           NaN
# 3570           0                     71725             DKC           NaN
#
#      Comments                gr_1                            gr_2  \
# 0         NaN                None                            None
# 1          10                None                            None
# 2         NaN                None                            None
# 3         NaN     Земляные работы                            None
# 4         NaN     Земляные работы                            None
# ...       ...                 ...                             ...
# 3566      NaN  Неучтенные затраты  Внутренние инженерные системы
# 3567      NaN  Неучтенные затраты  Внутренние инженерные системы
# 3568      NaN  Неучтенные затраты  Внутренние инженерные системы
# 3569      NaN  Неучтенные затраты  Внутренние инженерные системы
# 3570      NaN  Неучтенные затраты  Внутренние инженерные системы
#
#                                             gr_3                 gr_4  gr_5
# 0                                           None                 None  None
# 1                                           None                 None  None
# 2                                           None                 None  None
# 3                                           None                 None  None
# 4                                           None                 None  None
# ...                                          ...                  ...   ...
# 3566  Система передачи данных и Телефонная связь  Точки доступа Wi-Fi  None
# 3567  Система передачи данных и Телефонная связь  Точки доступа Wi-Fi  None
# 3568  Система передачи данных и Телефонная связь  Точки доступа Wi-Fi  None
# 3569  Система передачи данных и Телефонная связь  Точки доступа Wi-Fi  None
# 3570  Система передачи данных и Телефонная связь  Точки доступа Wi-Fi  None
#
# [3571 rows x 22 columns]

# %%
df_test.rename(columns = {"No." : "No", 
                                        "Код статьи" : "Code", 
                                        "Шифр тома" : "Tom", 
                                        "Наименование" : "Description", 
                                        "Ед. изм" : "Ed_izm",
                                        "Кол-во" : "Kol_vo",
                                         "Unnamed: 0" : "Level_gr",
'Кол-во подрядчиков' : 'Kol_vo_podr',                          
                          
                          
                          
                          
                          
                                         }, inplace=True)

#df_test.drop('gr_1', axis=1, inplace=True)
df_test.insert(7,'gr_1', None)
df_test.insert(8, 'gr_2', None)
df_test.insert(9, 'gr_3', None)
df_test.insert(10, 'gr_4', None)
df_test.insert(11, 'gr_5', None)
df_test.Kol_vo = pd.to_numeric(df_test.Kol_vo, errors='coerce')
df_test
# Out:
# Index(['Level_gr', 'No', 'Code', 'Tom', 'Description', 'Ed_izm', 'Kol_vo',
#        'gr_1', 'gr_2', 'gr_3', 'gr_4', 'gr_5', 'Kol_vo_podr', 'Price_one_mat',
#        'Price_one_work', 'Price_sum_mat', 'Price_sum_work', 'Sum_price',
#        'Mark', 'Manufacturer', 'Sovm_zak_obor', 'Comments'],
#       dtype='object')

# %%
for i in range(0,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 1)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i, 'Description']
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 2)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i, 'Description']       
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 3)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i, 'Description'] 
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 4)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i, 'Description']         


for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_1']) == True)):
         df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'gr_1']
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_2']) == True)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i-1, 'gr_2']      
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_3']) == True)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i-1, 'gr_3'] 
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_4']) == True)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i-1, 'gr_4']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kol_vo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-214-85479d01455a> in <module>
#       1 for i in range(0,len(df_test)):
# ----> 2     if ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 1)):
#       3         df_test.loc[i, 'gr_1'] = df_test.loc[i, 'Description']
#       4     elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 2)):
#       5         df_test.loc[i, 'gr_2'] = df_test.loc[i, 'Description']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Kol_vo'

# %%
df_test.rename(columns = {"No." : "No", 
                                        "Код статьи" : "Code", 
                                        "Шифр тома" : "Tom", 
                                        "Наименование" : "Description", 
                                        "Ед. изм" : "Ed_izm",
                                        "Кол-во" : "Kol_vo",
                                         "Unnamed: 0" : "Level_gr",
                                         }, inplace=True)

#df_test.drop('gr_1', axis=1, inplace=True)
df_test.insert(7,'gr_1', None)
df_test.insert(8, 'gr_2', None)
df_test.insert(9, 'gr_3', None)
df_test.insert(10, 'gr_4', None)
df_test.insert(11, 'gr_5', None)
df_test.Kol_vo = pd.to_numeric(df_test.Kol_vo, errors='coerce')
df_test
# Out:
#       Level_gr                       No                  Code  \
# 0          NaN                      NaN                   NaN
# 1          NaN                        1                   NaN
# 2          NaN                      NaN                   NaN
# 3          1.0                      NaN                   NaN
# 4          5.0                      NaN  02.01.08.02.01.01.08
# ...        ...                      ...                   ...
# 3566       NaN                      NaN                   NaN
# 3567       NaN                      NaN                   NaN
# 3568       NaN     02.01.08.02.08.01.08                   NaN
# 3569       NaN     02.01.08.02.08.01.08                   NaN
# 3570       NaN  02.01.08.02.08.01.20.04                   NaN
#
#                    Tom                                        Description  \
# 0                  NaN                                                NaN
# 1                  NaN                                                  2
# 2                  NaN  Многофункциональный мелкооптовый складской ком...
# 3                  NaN                                    Земляные работы
# 4     ORC_T_III_1.1_KR  Засыпка. Выполняется с отм -0.500 до отм -0.20...
# ...                ...                                                ...
# 3566               NaN                                                NaN
# 3567               NaN                                   Электроснабжение
# 3568               NaN                           ППГнг(А)-HF 3х2,5 -1 кВ
# 3569               NaN                             ППГнг(А)-HF 3х4 -1 кВ
# 3570               NaN  Гофрированная труба из ПВХ, Д25 (с учетом всех...
#
#      Ed_izm   Kol_vo  gr_1  gr_2  gr_3  ... Кол-во подрядчиков  \
# 0       NaN      NaN  None  None  None  ...                NaN
# 1         4     3.00  None  None  None  ...                NaN
# 2       NaN      NaN  None  None  None  ...                NaN
# 3       NaN      NaN  None  None  None  ...                NaN
# 4        м3  9620.22  None  None  None  ...                NaN
# ...     ...      ...   ...   ...   ...  ...                ...
# 3566    NaN      NaN  None  None  None  ...                NaN
# 3567    NaN      NaN  None  None  None  ...                NaN
# 3568     шт  1500.00  None  None  None  ...                NaN
# 3569     шт   500.00  None  None  None  ...                NaN
# 3570     шт  2000.00  None  None  None  ...                NaN
#
#      Цена за ед. изм\nРуб с НДС (20%) Unnamed: 14 Сумма\nРуб с НДС (20%)  \
# 0                            Материал      Работа               Материал
# 1                                   5           6                      7
# 2                                 NaN         NaN                      0
# 3                                 NaN         NaN                      0
# 4                                 NaN         NaN                      0
# ...                               ...         ...                    ...
# 3566                              NaN         NaN                    NaN
# 3567                              NaN         NaN                      0
# 3568                              NaN         NaN                      0
# 3569                              NaN         NaN                      0
# 3570                              NaN         NaN                      0
#
#      Unnamed: 16 Стоимость Руб, Марка / Артикул / Код / Размер  \
# 0         Работа      с НДС 20%                            NaN
# 1              8              9                            NaN
# 2              0              0                            NaN
# 3              0              0                            NaN
# 4              0              0                            NaN
# ...          ...            ...                            ...
# 3566         NaN            NaN                            NaN
# 3567           0              0                            NaN
# 3568           0              0       ППГнг(А)-HF 3х2,5 -1 кВ
# 3569           0              0         ППГнг(А)-HF 3х4 -1 кВ
# 3570           0              0                          71725
#
#        Производитель Совместно закупаемые оборудование/материалы Комментарии
# 0                NaN                                         NaN         NaN
# 1                NaN                                         NaN          10
# 2                NaN                                         NaN         NaN
# 3                NaN                                         NaN         NaN
# 4                NaN                                         NaN         NaN
# ...              ...                                         ...         ...
# 3566             NaN                                         NaN         NaN
# 3567             NaN                                         NaN         NaN
# 3568  Сегмент Энерго                                         NaN         NaN
# 3569  Сегмент Энерго                                         NaN         NaN
# 3570             DKC                                         NaN         NaN
#
# [3571 rows x 27 columns]

# %%
...
for i in range(1,len(df_test)):
    if ((df_test.loc[i, 'Kol_vo'] > 0) & (pd.isna(df_test.loc[i-1, 'Kol_vo']) == True) & (pd.isna(df_test.loc[i-1, 'Kol_vo']) == True)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'Description']
for i in range(2,len(df_test)):
    if ((df_test.loc[i, 'Kol_vo'] > 0) & (pd.isna(df_test.loc[i-1, 'Kol_vo']) == True) & (pd.isna(df_test.loc[i-2, 'Kol_vo']) == True)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i-2, 'Description']
for i in range(3,len(df_test)):
    if ((df_test.loc[i, 'Kol_vo'] > 0) & (pd.isna(df_test.loc[i-1, 'Kol_vo']) == True) & (pd.isna(df_test.loc[i-3, 'Kol_vo']) == True)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i-3, 'Description']        

        
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_1']) == True)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'gr_1']
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_2']) == True)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i-1, 'gr_2']      
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_3']) == True)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i-1, 'gr_3']            
        
df_test.loc[3160:3190]  
...
# Out:
#       Level_gr   No                     Code                           Tom  \
# 3160       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3161       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3162       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3163       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3164       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3165       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3166       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3167       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3168       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3169       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3170       5.0  NaN  02.01.08.02.08.15.06.02  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3171       3.0  NaN                      NaN                           NaN
# 3172       5.0  NaN  02.01.08.02.08.15.06.05  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3173       5.0  NaN  02.01.08.02.08.15.06.05  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3174       5.0  NaN  02.01.08.02.08.15.06.05  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3175       5.0  NaN  02.01.08.02.08.15.06.05  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3176       5.0  NaN  02.01.08.02.08.15.06.05  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3177       3.0  NaN                      NaN                           NaN
# 3178       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3179       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3180       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3181       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3182       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3183       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3184       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3185       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3186       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3187       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3188       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3189       5.0  NaN  02.01.08.02.08.15.06.03  ORC-T-III-1.1-SPH-SPC-BMS.SO
# 3190       3.0  NaN                      NaN                           NaN
#
#                                             Description Ed_izm   Kol_vo  \
# 3160      Клемма с винтовым зажимом ZS25, 25 мм2, серый     шт      3.0
# 3161   Клемма с винтовым зажимом ZS25-BL, 25 мм2, синий     шт      1.0
# 3162  Клемма с винтовым зажимом ZS25-PE, 25мм2, желт...     шт      1.0
# 3163        Клемма с винтовым зажимом ZS4, 4 мм2, серый     шт    150.0
# 3164  Клемма с винтовым зажимом ZS4-PE, 4мм2, желто-...     шт     50.0
# 3165                Торцевой изолятор ES4 для клемм ZS4     шт      3.0
# 3166  Держатель предохранителя ZS4-SF, 5х20 мм, 5х25...     шт      4.0
# 3167             Предохранитель FU520, 5х20 мм, 1 А         шт      4.0
# 3168       Держатель маркировки, устройство d=22 мм         шт      3.0
# 3169  DIN-рейка перфорированная OMEGA 3F, 35х7,5 мм,...     шт      3.0
# 3170  Короб перфорированный RL12, 60х100 мм, 2000 мм...     шт      5.0
# 3171                            Трубопроводная арматура    NaN      NaN
# 3172   Бобышка для датчика температуры    БП-А-G1/2-100     шт      2.0
# 3173                  Бобышка под кран    БП-КР-40-G1/2     шт     26.0
# 3174  Кран шаровый муфтовый со спускником G1/2 раб. ...     шт     26.0
# 3175  Трубка импульсная    1,6-70-ст20-МП-внутр.G1/2...     шт     19.0
# 3176                         Переходник G1/2 - G3/8         шт     19.0
# 3177                                Кабельная продукция    NaN      NaN
# 3178        Кабель контрольный    КПСТтг(А)-HF 1x2x0,75      м  12749.0
# 3179  Кабель контрольный, экранированный    КПСТЭтг(...      м    874.0
# 3180             Кабель контрольный    КППГнг(А)-HF 7x1      м    998.0
# 3181             Кабель контрольный    КППГнг(А)-HF 4x1      м  23571.0
# 3182                Кабель силовой    ППГнг(А)-HF 3х1,5      м   6579.0
# 3183  Кабель контрольный, экранированный    КППГЭнг(...      м  16036.0
# 3184                Кабель силовой    ППГнг(А)-HF 3х2,5      м   3971.0
# 3185  Кабель силовой, экранированный    ППГЭнг(А)-HF...      м   2760.0
# 3186  Кабель контрольный, экранированный    КПСТЭтг(...      м    114.0
# 3187     Кабель интерфейсный    КИПвЭнг(А)-HF 1x2x0,78       м   8968.0
# 3188                Кабель силовой    ППГнг(А)-HF 2x2,5      м   9975.0
# 3189                     Кабель монтажный    ПуГВ 1x2,5      м    950.0
# 3190                          Трубы и монтажные изделия    NaN      NaN
#
#                          gr_1        gr_2                   gr_3  ...  \
# 3160      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3161      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3162      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3163      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3164      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3165      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3166      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3167      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3168      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3169      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3170      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3171      Шкафы автоматизации  Автоматика  Кабеленесущие системы  ...
# 3172  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3173  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3174  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3175  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3176  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3177  Трубопроводная арматура  Автоматика  Кабеленесущие системы  ...
# 3178      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3179      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3180      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3181      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3182      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3183      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3184      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3185      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3186      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3187      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3188      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3189      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
# 3190      Кабельная продукция  Автоматика  Кабеленесущие системы  ...
#
#      Кол-во подрядчиков Цена за ед. изм\nРуб с НДС (20%) Unnamed: 14  \
# 3160                NaN                              NaN         NaN
# 3161                NaN                              NaN         NaN
# 3162                NaN                              NaN         NaN
# 3163                NaN                              NaN         NaN
# 3164                NaN                              NaN         NaN
# 3165                NaN                              NaN         NaN
# 3166                NaN                              NaN         NaN
# 3167                NaN                              NaN         NaN
# 3168                NaN                              NaN         NaN
# 3169                NaN                              NaN         NaN
# 3170                NaN                              NaN         NaN
# 3171                NaN                              NaN         NaN
# 3172                NaN                              NaN         NaN
# 3173                NaN                              NaN         NaN
# 3174                NaN                              NaN         NaN
# 3175                NaN                              NaN         NaN
# 3176                NaN                              NaN         NaN
# 3177                NaN                              NaN         NaN
# 3178                NaN                              NaN         NaN
# 3179                NaN                              NaN         NaN
# 3180                NaN                              NaN         NaN
# 3181                NaN                              NaN         NaN
# 3182                NaN                              NaN         NaN
# 3183                NaN                              NaN         NaN
# 3184                NaN                              NaN         NaN
# 3185                NaN                              NaN         NaN
# 3186                NaN                              NaN         NaN
# 3187                NaN                              NaN         NaN
# 3188                NaN                              NaN         NaN
# 3189                NaN                              NaN         NaN
# 3190                NaN                              NaN         NaN
#
#      Сумма\nРуб с НДС (20%) Unnamed: 16 Стоимость Руб,  \
# 3160                      0           0              0
# 3161                      0           0              0
# 3162                      0           0              0
# 3163                      0           0              0
# 3164                      0           0              0
# 3165                      0           0              0
# 3166                      0           0              0
# 3167                      0           0              0
# 3168                      0           0              0
# 3169                      0           0              0
# 3170                      0           0              0
# 3171                      0           0              0
# 3172                      0           0              0
# 3173                      0           0              0
# 3174                      0           0              0
# 3175                      0           0              0
# 3176                      0           0              0
# 3177                      0           0              0
# 3178                      0           0              0
# 3179                      0           0              0
# 3180                      0           0              0
# 3181                      0           0              0
# 3182                      0           0              0
# 3183                      0           0              0
# 3184                      0           0              0
# 3185                      0           0              0
# 3186                      0           0              0
# 3187                      0           0              0
# 3188                      0           0              0
# 3189                      0           0              0
# 3190                      0           0              0
#
#      Марка / Артикул / Код / Размер       Производитель  \
# 3160                1SNK512010R0000                 ABB
# 3161               1SNK512020R0000                  ABB
# 3162                1SNK512150R0000                 ABB
# 3163               1SNK505010R0000                  ABB
# 3164                1SNK505150R0000                 ABB
# 3165                1SNK505910R0000                 ABB
# 3166                1SNK508410R0000                 ABB
# 3167               1SNA008290R1300                  ABB
# 3168                          ZBZ33  Schneider Electric
# 3169                           2140                 DKC
# 3170                        00162RL                 DKC
# 3171                            NaN                 NaN
# 3172                            NaN                 NaN
# 3173                            NaN                 NaN
# 3174                            NaN                 NaN
# 3175                            NaN                 NaN
# 3176                            NaN             Danfoss
# 3177                            NaN                 NaN
# 3178                            NaN              Россия
# 3179                            NaN              Россия
# 3180                            NaN              Россия
# 3181                            NaN              Россия
# 3182                            NaN              Россия
# 3183                            NaN              Россия
# 3184                            NaN              Россия
# 3185                            NaN              Россия
# 3186                            NaN              Россия
# 3187                            NaN              Россия
# 3188                            NaN              Россия
# 3189                            NaN              Россия
# 3190                            NaN                 NaN
#
#      Совместно закупаемые оборудование/материалы Комментарии
# 3160                                         NaN         NaN
# 3161                                         NaN         NaN
# 3162                                         NaN         NaN
# 3163                                         NaN         NaN
# 3164                                         NaN         NaN
# 3165                                         NaN         NaN
# 3166                                         NaN         NaN
# 3167                                         NaN         NaN
# 3168                                         NaN         NaN
# 3169                                         NaN         NaN
# 3170                                         NaN         NaN
# 3171                                         NaN         NaN
# 3172                                         NaN         NaN
# 3173                                         NaN         NaN
# 3174                                         NaN         NaN
# 3175                                         NaN         NaN
# 3176                                         NaN         NaN
# 3177                                         NaN         NaN
# 3178                                         NaN         NaN
# 3179                                         NaN         NaN
# 3180                                         NaN         NaN
# 3181                                         NaN         NaN
# 3182                                         NaN         NaN
# 3183                                         NaN         NaN
# 3184                                         NaN         NaN
# 3185                                         NaN         NaN
# 3186                                         NaN         NaN
# 3187                                         NaN         NaN
# 3188                                         NaN         NaN
# 3189                                         NaN         NaN
# 3190                                         NaN         NaN
#
# [31 rows x 27 columns]

# %%
for i in range(0,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 1)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i, 'Description']
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 2)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i, 'Description']       
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 3)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i, 'Description'] 
    elif ((pd.isna(df_test.loc[i, 'Kol_vo']) == True) & (df_test.loc[i,'Level_gr'] == 4)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i, 'Description']         
        
        
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_1']) == True)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'gr_1']
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_2']) == True)):
        df_test.loc[i, 'gr_2'] = df_test.loc[i-1, 'gr_2']      
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_3']) == True)):
        df_test.loc[i, 'gr_3'] = df_test.loc[i-1, 'gr_3'] 
for i in range(1,len(df_test)):
    if ((pd.isna(df_test.loc[i, 'gr_4']) == True)):
        df_test.loc[i, 'gr_4'] = df_test.loc[i-1, 'gr_4']         
        
with pd.ExcelWriter(r'X:\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\04 - ТД\08 - BIM\997_Отчеты\Power BI\Структура стоимости ППК все этапы (1 очередь)_gr' + '.xlsx') as writer:  
    df_test.to_excel(writer, sheet_name='1.1_МО')

df_test.to_csv(r'X:\% ДПС\02 - ОРЦ\05 - ПИР\03 - ПРОЕКТ\04 - ТД\08 - BIM\997_Отчеты\Power BI\Структура стоимости ППК все этапы (1 очередь)_gr' + '.csv') 
                 
    
    
df_test.loc[740:770]
# Out:
#      Level_gr   No                     Code                Tom  \
# 740       5.0  NaN                      NaN   ORC-Т-III-1.1-VK
# 741       5.0  NaN                      NaN   ORC-Т-III-1.1-VK
# 742       5.0  NaN                      NaN   ORC-Т-III-1.1-VK
# 743       5.0  NaN                      NaN   ORC-Т-III-1.1-VK
# 744       5.0  NaN                      NaN   ORC-Т-III-1.1-VK
# 745       5.0  NaN     02.01.08.02.08.04.01   ORC-Т-III-1.1-VK
# 746       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 747       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 748       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 749       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 750       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 751       5.0  NaN     02.01.08.02.08.04.01      ORC-ТД-1.1-АР
# 752       3.0  NaN                      NaN                NaN
# 753       5.0  NaN  02.01.08.02.08.04.03.03   ORC-Т-III-1.1-VK
# 754       5.0  NaN  02.01.08.02.08.04.03.04   ORC-Т-III-1.1-VK
# 755       5.0  NaN  02.01.08.02.08.04.03.04   ORC-Т-III-1.1-VK
# 756       NaN  NaN     02.01.08.02.08.04.08   ORC-Т-III-1.1-VK
# 757       2.0  NaN                      NaN                NaN
# 758       3.0  NaN                      NaN                NaN
# 759       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 760       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 761       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 762       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 763       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 764       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 765       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 766       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 767       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 768       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 769       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
# 770       5.0  NaN     02.01.08.02.08.14.01  ORC-Т-III-1.1-OV3
#
#                                            Description  Ed_izm  Kol_vo  \
# 740            Шайба МЮПРО М10х29 ( В 1кг. - 110 штук)      шт  7716.0
# 741        Шпилька М10, DIN 975, 2000 мм, оцинкованная      шт  1286.0
# 742  Крепление V-образное для профнастила VZ М 10 с...      шт  1286.0
# 743                Анкер забивной (Цанга), М10, латунь      шт   318.0
# 744         Труба с резьбой, оцинкованная 1/2" 2000 мм      шт     6.0
# 745  Рулон K-FLEX ST , толщиной 10 мм K-FLEX ST Всп...       м    30.0
# 746  ВТ-1 Водосточная труба из оцинкованной стали 0...      шт     5.0
# 747  ВТ-2 Водосточная труба из оцинкованной стали 0...      шт    48.0
# 748  ВТ-3 Водосточная труба из оцинкованной стали 0...      шт     1.0
# 749  ВТ-4 Водосточная труба из оцинкованной стали 0...      шт     2.0
# 750  ВТ-5 Водосточная труба из оцинкованной стали 0...      шт     4.0
# 751  ПВ-1 Парапетные воронки заводской готовности, ...      шт    60.0
# 752                         Дренажная канализация (К4)     NaN     NaN
# 753  Труба канализационная чугунная безраструбная S...       м    10.0
# 754     Труба канализационная ПВХ Dy50 ГОСТ 32414-2013       м   740.0
# 755    Труба канализационная ПВХ Dy110 ГОСТ 32414-2013       м    21.0
# 756                             Пусконаладочные работы  компл.     1.0
# 757                         Отопление и теплоснабжение     NaN     NaN
# 758                               Отопительные приборы     NaN     NaN
# 759  Воздушная завеса без нагрева горизонтальная с ...      шт     1.0
# 760  Воздушная завеса без нагрева горизонтальная с ...      шт     2.0
# 761  Воздушная завеса без нагрева вертикальная с  п...      шт    14.0
# 762  Воздушная завеса без нагрева вертикальная с  п...      шт   108.0
# 763  Воздушно-тепловая завеса горизонтальная с водя...      шт     1.0
# 764  Воздушно-тепловая завеса горизонтальная с водя...      шт     1.0
# 765  Воздушно-тепловая завеса горизонтальная с водя...      шт     7.0
# 766  Воздушно-отопительный агрегат с водяным калори...      шт    92.0
# 767                         Консоль монтажная Heater        шт    92.0
# 768  Шланг сильфонный SS 1 м3/4 Г-Г "PODVODKA" вода...      шт   180.0
# 769                   Электрический конвектор NFC 4W 5      шт     2.0
# 770                 Электрический конвектор NFC 4W 10       шт     6.0
#
#                                                  gr_1  \
# 740  Дождевая канализация - внутренние водостоки (К2)
# 741  Дождевая канализация - внутренние водостоки (К2)
# 742  Дождевая канализация - внутренние водостоки (К2)
# 743  Дождевая канализация - внутренние водостоки (К2)
# 744  Дождевая канализация - внутренние водостоки (К2)
# 745  Дождевая канализация - внутренние водостоки (К2)
# 746  Дождевая канализация - внутренние водостоки (К2)
# 747  Дождевая канализация - внутренние водостоки (К2)
# 748  Дождевая канализация - внутренние водостоки (К2)
# 749  Дождевая канализация - внутренние водостоки (К2)
# 750  Дождевая канализация - внутренние водостоки (К2)
# 751  Дождевая канализация - внутренние водостоки (К2)
# 752  Дождевая канализация - внутренние водостоки (К2)
# 753                        Дренажная канализация (К4)
# 754                        Дренажная канализация (К4)
# 755                        Дренажная канализация (К4)
# 756                        Дренажная канализация (К4)
# 757                        Дренажная канализация (К4)
# 758                        Дренажная канализация (К4)
# 759                              Отопительные приборы
# 760                              Отопительные приборы
# 761                              Отопительные приборы
# 762                              Отопительные приборы
# 763                              Отопительные приборы
# 764                              Отопительные приборы
# 765                              Отопительные приборы
# 766                              Отопительные приборы
# 767                              Отопительные приборы
# 768                              Отопительные приборы
# 769                              Отопительные приборы
# 770                              Отопительные приборы
#
#                             gr_2                            gr_3  ...  \
# 740  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 741  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 742  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 743  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 744  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 745  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 746  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 747  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 748  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 749  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 750  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 751  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 752  Водоснабжение и канализация      Дренажная канализация (К4)  ...
# 753  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 754  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 755  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 756  Водоснабжение и канализация  Внутренние инженерные системы   ...
# 757   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 758  Водоснабжение и канализация            Отопительные приборы  ...
# 759   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 760   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 761   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 762   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 763   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 764   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 765   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 766   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 767   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 768   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 769   Отопление и теплоснабжение  Внутренние инженерные системы   ...
# 770   Отопление и теплоснабжение  Внутренние инженерные системы   ...
#
#     Кол-во подрядчиков Цена за ед. изм\nРуб с НДС (20%) Unnamed: 14  \
# 740                NaN                              NaN         NaN
# 741                NaN                              NaN         NaN
# 742                NaN                              NaN         NaN
# 743                NaN                              NaN         NaN
# 744                NaN                              NaN         NaN
# 745                NaN                              NaN         NaN
# 746                NaN                              NaN         NaN
# 747                NaN                              NaN         NaN
# 748                NaN                              NaN         NaN
# 749                NaN                              NaN         NaN
# 750                NaN                              NaN         NaN
# 751                NaN                              NaN         NaN
# 752                NaN                              NaN         NaN
# 753                NaN                              NaN         NaN
# 754                NaN                              NaN         NaN
# 755                NaN                              NaN         NaN
# 756                NaN                              NaN         NaN
# 757                NaN                              NaN         NaN
# 758                NaN                              NaN         NaN
# 759                NaN                              NaN         NaN
# 760                NaN                              NaN         NaN
# 761                NaN                              NaN         NaN
# 762                NaN                              NaN         NaN
# 763                NaN                              NaN         NaN
# 764                NaN                              NaN         NaN
# 765                NaN                              NaN         NaN
# 766                NaN                              NaN         NaN
# 767                NaN                              NaN         NaN
# 768                NaN                              NaN         NaN
# 769                NaN                              NaN         NaN
# 770                NaN                              NaN         NaN
#
#     Сумма\nРуб с НДС (20%) Unnamed: 16 Стоимость Руб,  \
# 740                      0           0              0
# 741                      0           0              0
# 742                      0           0              0
# 743                      0           0              0
# 744                      0           0              0
# 745                      0           0              0
# 746                      0           0              0
# 747                      0           0              0
# 748                      0           0              0
# 749                      0           0              0
# 750                      0           0              0
# 751                      0           0              0
# 752                      0           0              0
# 753                      0           0              0
# 754                      0           0              0
# 755                      0           0              0
# 756                      0           0              0
# 757                      0           0              0
# 758                      0           0              0
# 759                      0           0              0
# 760                      0           0              0
# 761                      0           0              0
# 762                      0           0              0
# 763                      0           0              0
# 764                      0           0              0
# 765                      0           0              0
# 766                      0           0              0
# 767                      0           0              0
# 768                      0           0              0
# 769                      0           0              0
# 770                      0           0              0
#
#     Марка / Артикул / Код / Размер  Производитель  \
# 740                         127088          Wavin
# 741                         102158          Wavin
# 742                      Крепеж 38          Wavin
# 743                         240112          Wavin
# 744                         113390          Wavin
# 745            10x1000-20 ST \n \n         K-FLEX
# 746                            NaN            NaN
# 747                            NaN            NaN
# 748                            NaN            NaN
# 749                            NaN            NaN
# 750                            NaN            NaN
# 751                            NaN            NaN
# 752                            NaN            NaN
# 753                            NaN         Duker
# 754                            NaN         Россия
# 755                            NaN         Россия
# 756                            NaN            NaN
# 757                            NaN            NaN
# 758                            NaN            NaN
# 759                     КЭВ-П4111A       Тепломаш
# 760                     КЭВ-П4144A       Тепломаш
# 761                PWZ-C 70-40 H/3           KORF
# 762                PWZ-C 90-50 H/4           KORF
# 763                    КЭВ-3П1154E       Тепломаш
# 764                   КЭВ-44П4131W       Тепломаш
# 765                   КЭВ-70П4141W       Тепломаш
# 766                            NaN       Sonniger
# 767                            NaN       Sonniger
# 768                            NaN       Sonniger
# 769                            NaN           NOBO
# 770                            NaN           NOBO
#
#     Совместно закупаемые оборудование/материалы Комментарии
# 740                                         NaN         NaN
# 741                                         NaN         NaN
# 742                                         NaN         NaN
# 743                                         NaN         NaN
# 744                                         NaN         NaN
# 745                                         NaN         NaN
# 746                                         NaN         NaN
# 747                                         NaN         NaN
# 748                                         NaN         NaN
# 749                                         NaN         NaN
# 750                                         NaN         NaN
# 751                                         NaN         NaN
# 752                                         NaN         NaN
# 753                                         NaN         NaN
# 754                                         NaN         NaN
# 755                                         NaN         NaN
# 756                                         NaN         NaN
# 757                                         NaN         NaN
# 758                                         NaN         NaN
# 759                                         NaN         NaN
# 760                                         NaN         NaN
# 761                                         NaN         NaN
# 762                                         NaN         NaN
# 763                                         NaN         NaN
# 764                                         NaN         NaN
# 765                                         NaN         NaN
# 766                                         NaN         NaN
# 767                                         NaN         NaN
# 768                                         NaN         NaN
# 769                                         NaN         NaN
# 770                                         NaN         NaN
#
# [31 rows x 27 columns]

# %%
#df_test.drop('gr_1', axis=1, inplace=True)
df_test.insert(6, 'gr_1', 0)
for i in range(1,len(df_test)):
    if ((df_test.loc[i, 'Kol_vo'] > 0) & (df_test.loc[i-1, 'Kol_vo'] is None)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'Description']   
        
df_test

# %%
df_test
# Out:
#     No                     Code               Tom  \
# 0  NaN                      NaN               NaN
# 1  NaN                      NaN               NaN
# 2  NaN                      NaN               NaN
# 3  NaN     02.01.08.02.01.01.08  ORC_T_III_1.1_KR
# 4  NaN                      NaN  ORC_T_III_1.1_KR
# 5  NaN     02.01.08.02.01.01.02  ORC_T_III_1.1_KR
# 6  NaN     02.01.08.02.01.01.03  ORC_T_III_1.1_KR
# 7  NaN                      NaN               NaN
# 8  NaN                      NaN               NaN
# 9  NaN        02.01.08.02.02.03  ORC_T_III_1.1_KR
# 10 NaN                      NaN               NaN
# 11 NaN                      NaN               NaN
# 12 NaN                      NaN               NaN
# 13 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 14 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 15 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 16 NaN                      NaN               NaN
# 17 NaN                      NaN               NaN
# 18 NaN                      NaN               NaN
# 19 NaN                      NaN               NaN
# 20 NaN                      NaN               NaN
# 21 NaN                      NaN  ORC-Т-III-2.1-SS
# 22 NaN                      NaN  ORC-Т-III-2.1-SS
# 23 NaN                      NaN  ORC-Т-III-2.1-SS
# 24 NaN  02.01.08.02.08.15.03.06  ORC-Т-III-2.1-SS
#
#                                           Description Ed_izm    Kol_vo  gr_1
# 0                                                 NaN    NaN       NaN     0
# 1   Многофункциональный мелкооптовый складской ком...    NaN       NaN     0
# 2                                     Земляные работы    NaN       NaN     0
# 3   Засыпка. Выполняется с отм -0.500 до отм -0.20...     м3   9620.22     0
# 4   Устр-во выемок для столбчатых фундаментов  в г...     м3  22143.00     0
# 5    Обратая засыпка выемок под столбчатые фундаменты     м3  20568.00     0
# 6   Подсыпка на глубину 500мм Выполняется под отмо...     м3    525.60     0
# 7                               Устройство фундамента    NaN       NaN     0
# 8                              Фундаменты под колонны    NaN       NaN     0
# 9    Плита фундаментая сборная инд-го изготовления...     шт     12.00     0
# 10                                             Каркас    NaN       NaN     0
# 11                        Железобетонные конструкции     NaN       NaN     0
# 12                                            Колонны    NaN       NaN     0
# 13  Колонна прямоугольная сборная   К1   \nБетон В...     шт     58.00     0
# 14  Колонна прямоугольная сборная  К2 \nБетон В35/...     шт      4.00     0
# 15  Колонна прямоугольная сборная  К3  \nБетон В35...     шт    112.00     0
# 16                                Опциональные работы    NaN       NaN     0
# 17  Система ИКСБ Многофункциональный производствен...    NaN       NaN     0
# 18                     Внутренние инженерные системы     NaN       NaN     0
# 19             Система контроля и управления доступом    NaN       NaN     0
# 20                    Серверное оборудование, АРМ, ПО    NaN       NaN     0
# 21  Рабочая станция i5-10500/8GB DDR4-3200 nECC/25...     шт      2.00     0
# 22  Монитор 24" 1920x1200, 5 мс, 300 кд/м2, 1000:1...     шт      4.00     0
# 23                    Клавиатура, USB HP Pavilion 300     шт      2.00     0
# 24         Лицензия на дополнительную рабочую станцию     шт      2.00     0

# %%
# Out:
# <ipython-input-62-086c8608d2e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['gr_1'][0] = 1

# %%
for i in range(1,len(df_test)):
    if ((df_test.loc[i, 'Kol_vo'] > 0) & (df_test.loc[i-1, 'Kol_vo'] is None)):
        df_test.loc[i, 'gr_1'] = df_test.loc[i-1, 'Description']   
        
df_test
# Out:
#     No                     Code               Tom  \
# 0  NaN                      NaN               NaN
# 1  NaN                      NaN               NaN
# 2  NaN                      NaN               NaN
# 3  NaN     02.01.08.02.01.01.08  ORC_T_III_1.1_KR
# 4  NaN                      NaN  ORC_T_III_1.1_KR
# 5  NaN     02.01.08.02.01.01.02  ORC_T_III_1.1_KR
# 6  NaN     02.01.08.02.01.01.03  ORC_T_III_1.1_KR
# 7  NaN                      NaN               NaN
# 8  NaN                      NaN               NaN
# 9  NaN        02.01.08.02.02.03  ORC_T_III_1.1_KR
# 10 NaN                      NaN               NaN
# 11 NaN                      NaN               NaN
# 12 NaN                      NaN               NaN
# 13 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 14 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 15 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 16 NaN                      NaN               NaN
# 17 NaN                      NaN               NaN
# 18 NaN                      NaN               NaN
# 19 NaN                      NaN               NaN
# 20 NaN                      NaN               NaN
# 21 NaN                      NaN  ORC-Т-III-2.1-SS
# 22 NaN                      NaN  ORC-Т-III-2.1-SS
# 23 NaN                      NaN  ORC-Т-III-2.1-SS
# 24 NaN  02.01.08.02.08.15.03.06  ORC-Т-III-2.1-SS
#
#                                           Description Ed_izm    Kol_vo  gr_1
# 0                                                 NaN    NaN       NaN     0
# 1   Многофункциональный мелкооптовый складской ком...    NaN       NaN     0
# 2                                     Земляные работы    NaN       NaN     0
# 3   Засыпка. Выполняется с отм -0.500 до отм -0.20...     м3   9620.22     0
# 4   Устр-во выемок для столбчатых фундаментов  в г...     м3  22143.00     0
# 5    Обратая засыпка выемок под столбчатые фундаменты     м3  20568.00     0
# 6   Подсыпка на глубину 500мм Выполняется под отмо...     м3    525.60     0
# 7                               Устройство фундамента    NaN       NaN     0
# 8                              Фундаменты под колонны    NaN       NaN     0
# 9    Плита фундаментая сборная инд-го изготовления...     шт     12.00     0
# 10                                             Каркас    NaN       NaN     0
# 11                        Железобетонные конструкции     NaN       NaN     0
# 12                                            Колонны    NaN       NaN     0
# 13  Колонна прямоугольная сборная   К1   \nБетон В...     шт     58.00     0
# 14  Колонна прямоугольная сборная  К2 \nБетон В35/...     шт      4.00     0
# 15  Колонна прямоугольная сборная  К3  \nБетон В35...     шт    112.00     0
# 16                                Опциональные работы    NaN       NaN     0
# 17  Система ИКСБ Многофункциональный производствен...    NaN       NaN     0
# 18                     Внутренние инженерные системы     NaN       NaN     0
# 19             Система контроля и управления доступом    NaN       NaN     0
# 20                    Серверное оборудование, АРМ, ПО    NaN       NaN     0
# 21  Рабочая станция i5-10500/8GB DDR4-3200 nECC/25...     шт      2.00     0
# 22  Монитор 24" 1920x1200, 5 мс, 300 кд/м2, 1000:1...     шт      4.00     0
# 23                    Клавиатура, USB HP Pavilion 300     шт      2.00     0
# 24         Лицензия на дополнительную рабочую станцию     шт      2.00     0

# %%
df_test.loc[3, 'Kol_vo']
# Out:
# 9620.22

# %%
#df_test.loc[0, 'gr_1'] = 1
df_test
# Out:
#     No                     Code               Tom  \
# 0  NaN                      NaN               NaN
# 1  NaN                      NaN               NaN
# 2  NaN                      NaN               NaN
# 3  NaN     02.01.08.02.01.01.08  ORC_T_III_1.1_KR
# 4  NaN                      NaN  ORC_T_III_1.1_KR
# 5  NaN     02.01.08.02.01.01.02  ORC_T_III_1.1_KR
# 6  NaN     02.01.08.02.01.01.03  ORC_T_III_1.1_KR
# 7  NaN                      NaN               NaN
# 8  NaN                      NaN               NaN
# 9  NaN        02.01.08.02.02.03  ORC_T_III_1.1_KR
# 10 NaN                      NaN               NaN
# 11 NaN                      NaN               NaN
# 12 NaN                      NaN               NaN
# 13 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 14 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 15 NaN     02.01.08.02.03.02.01  ORC_T_III_1.1_KR
# 16 NaN                      NaN               NaN
# 17 NaN                      NaN               NaN
# 18 NaN                      NaN               NaN
# 19 NaN                      NaN               NaN
# 20 NaN                      NaN               NaN
# 21 NaN                      NaN  ORC-Т-III-2.1-SS
# 22 NaN                      NaN  ORC-Т-III-2.1-SS
# 23 NaN                      NaN  ORC-Т-III-2.1-SS
# 24 NaN  02.01.08.02.08.15.03.06  ORC-Т-III-2.1-SS
#
#                                           Description Ed_izm    Kol_vo  \
# 0                                                 NaN    NaN       NaN
# 1   Многофункциональный мелкооптовый складской ком...    NaN       NaN
# 2                                     Земляные работы    NaN       NaN
# 3   Засыпка. Выполняется с отм -0.500 до отм -0.20...     м3   9620.22
# 4   Устр-во выемок для столбчатых фундаментов  в г...     м3  22143.00
# 5    Обратая засыпка выемок под столбчатые фундаменты     м3  20568.00
# 6   Подсыпка на глубину 500мм Выполняется под отмо...     м3    525.60
# 7                               Устройство фундамента    NaN       NaN
# 8                              Фундаменты под колонны    NaN       NaN
# 9    Плита фундаментая сборная инд-го изготовления...     шт     12.00
# 10                                             Каркас    NaN       NaN
# 11                        Железобетонные конструкции     NaN       NaN
# 12                                            Колонны    NaN       NaN
# 13  Колонна прямоугольная сборная   К1   \nБетон В...     шт     58.00
# 14  Колонна прямоугольная сборная  К2 \nБетон В35/...     шт      4.00
# 15  Колонна прямоугольная сборная  К3  \nБетон В35...     шт    112.00
# 16                                Опциональные работы    NaN       NaN
# 17  Система ИКСБ Многофункциональный производствен...    NaN       NaN
# 18                     Внутренние инженерные системы     NaN       NaN
# 19             Система контроля и управления доступом    NaN       NaN
# 20                    Серверное оборудование, АРМ, ПО    NaN       NaN
# 21  Рабочая станция i5-10500/8GB DDR4-3200 nECC/25...     шт      2.00
# 22  Монитор 24" 1920x1200, 5 мс, 300 кд/м2, 1000:1...     шт      4.00
# 23                    Клавиатура, USB HP Pavilion 300     шт      2.00
# 24         Лицензия на дополнительную рабочую станцию     шт      2.00
#
#                                                  gr_1
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                     Земляные работы
# 4   Засыпка. Выполняется с отм -0.500 до отм -0.20...
# 5   Устр-во выемок для столбчатых фундаментов  в г...
# 6    Обратая засыпка выемок под столбчатые фундаменты
# 7                                                   0
# 8                                                   0
# 9                              Фундаменты под колонны
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                            Колонны
# 14  Колонна прямоугольная сборная   К1   \nБетон В...
# 15  Колонна прямоугольная сборная  К2 \nБетон В35/...
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                    Серверное оборудование, АРМ, ПО
# 22  Рабочая станция i5-10500/8GB DDR4-3200 nECC/25...
# 23  Монитор 24" 1920x1200, 5 мс, 300 кд/м2, 1000:1...
# 24                    Клавиатура, USB HP Pavilion 300
