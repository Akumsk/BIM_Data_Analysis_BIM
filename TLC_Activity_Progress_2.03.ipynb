# %%
#Загрузка библиотек
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import datetime


TLC_activity_progress_nov = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_nov.csv')
TLC_activity_progress_nov = TLC_activity_progress_nov.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_nov.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_dec1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_dec1.csv')
TLC_activity_progress_dec1 = TLC_activity_progress_dec1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_dec1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_dec2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_dec2.csv')
TLC_activity_progress_dec2 = TLC_activity_progress_dec2.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_dec2.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_dec3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_dec3.csv')
TLC_activity_progress_dec3 = TLC_activity_progress_dec3.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_dec3.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_jan1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_jan1.csv')
TLC_activity_progress_jan1 = TLC_activity_progress_jan1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_jan1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_jan2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_jan2.csv')
TLC_activity_progress_jan2 = TLC_activity_progress_jan2.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_jan2.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_feb1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_feb1.csv')
TLC_activity_progress_feb1 = TLC_activity_progress_feb1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_feb1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_feb2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_feb2.csv')
TLC_activity_progress_feb2 = TLC_activity_progress_feb2.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_feb2.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


TLC_activity_progress_feb3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_feb3.csv')
TLC_activity_progress_feb3 = TLC_activity_progress_feb3.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_feb3.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_feb4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_feb4.csv')
TLC_activity_progress_feb4 = TLC_activity_progress_feb4.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_feb4.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_mar1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_mar1.csv')
TLC_activity_progress_mar1 = TLC_activity_progress_mar1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_mar1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_mar2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_mar2.csv')
TLC_activity_progress_mar2 = TLC_activity_progress_mar2.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_mar2.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_mar3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_mar3.csv')
TLC_activity_progress_mar3 = TLC_activity_progress_mar3.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_mar3.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_mar4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_mar4.csv')
TLC_activity_progress_mar4 = TLC_activity_progress_mar4.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_mar4.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_apr1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_apr1.csv')
TLC_activity_progress_apr1 = TLC_activity_progress_apr1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_apr1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_apr2 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_apr2.csv')
TLC_activity_progress_apr2 = TLC_activity_progress_apr2.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_apr2.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_apr3 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_apr3.csv')
TLC_activity_progress_apr3 = TLC_activity_progress_apr3.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_apr3.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_apr4 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_apr4.csv')
TLC_activity_progress_apr4 = TLC_activity_progress_apr4.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_apr4.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_apr5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_apr5.csv')
TLC_activity_progress_apr5 = TLC_activity_progress_apr5.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_apr5.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_may1 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_may1.csv')
TLC_activity_progress_may1 = TLC_activity_progress_may1.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_may1.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_may22 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_may22.csv')
TLC_activity_progress_may22 = TLC_activity_progress_may22.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_may22.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_may30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_may30.csv')
TLC_activity_progress_may30 = TLC_activity_progress_may30.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_may30.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_june5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_june5.csv')
TLC_activity_progress_june5 = TLC_activity_progress_june5.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_june5.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_june12 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_june12.csv')
TLC_activity_progress_june12 = TLC_activity_progress_june12.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_june12.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_june19 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_june19.csv')
TLC_activity_progress_june19 = TLC_activity_progress_june19.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_june19.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_june26 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_june26.csv')
TLC_activity_progress_june26 = TLC_activity_progress_june26.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_june26.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_june30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_june30.csv')
TLC_activity_progress_june30 = TLC_activity_progress_june30.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_june30.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_jul10 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_jul10.csv')
TLC_activity_progress_jul10 = TLC_activity_progress_jul10.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_jul10.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_jul24 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_jul24.csv')
TLC_activity_progress_jul24 = TLC_activity_progress_jul24.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_jul24.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_avg7 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_avg7.csv')
TLC_activity_progress_avg7 = TLC_activity_progress_avg7.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_avg7.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_avg20 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_avg20.csv')
TLC_activity_progress_avg20 = TLC_activity_progress_avg20.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_avg20.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_avg31 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_avg31.csv')
TLC_activity_progress_avg31 = TLC_activity_progress_avg31.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_avg31.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_sep11 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_sep11.csv')
TLC_activity_progress_sep11 = TLC_activity_progress_sep11.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_sep11.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_sep25 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_sep25.csv')
TLC_activity_progress_sep25 = TLC_activity_progress_sep25.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_sep25.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt5.csv')
TLC_activity_progress_okt5 = TLC_activity_progress_okt5.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt5.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)


TLC_activity_progress_okt9 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt9.csv')
TLC_activity_progress_okt9 = TLC_activity_progress_okt9.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt9.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt13 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt13.csv')
TLC_activity_progress_okt13 = TLC_activity_progress_okt13.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt13.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt17 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt17.csv')
TLC_activity_progress_okt17 = TLC_activity_progress_okt17.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt17.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt19 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt19.csv')
TLC_activity_progress_okt19 = TLC_activity_progress_okt19.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt19.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt24 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt24.csv')
TLC_activity_progress_okt24 = TLC_activity_progress_okt24.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt24.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt27 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt27.csv')
TLC_activity_progress_okt27 = TLC_activity_progress_okt27.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt27.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_okt31 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_okt31.csv')
TLC_activity_progress_okt31 = TLC_activity_progress_okt31.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_okt31.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_nov2_21 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_nov2_21.csv')
TLC_activity_progress_nov2_21 = TLC_activity_progress_nov2_21.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_nov2_21.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_nov5 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_nov5.csv')
TLC_activity_progress_nov5 = TLC_activity_progress_nov5.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_nov5.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_nov8 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_nov8.csv')
TLC_activity_progress_nov8 = TLC_activity_progress_nov8.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_nov8.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_nov15 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_nov15.csv')
TLC_activity_progress_nov15 = TLC_activity_progress_nov15.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_nov15.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_sep30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_sep30.csv')
TLC_activity_progress_sep30 = TLC_activity_progress_sep30.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_sep30.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)

TLC_activity_progress_sep30 = pd.read_csv(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\Activity/TLC_activity_sep30.csv')
TLC_activity_progress_sep30 = TLC_activity_progress_sep30.drop([0,1,2,3,4,5],axis=0)
TLC_activity_progress_sep30.rename(columns = {"Project name: TLC" : "date", 
                                        "Unnamed: 1" : "description", 
                                        "Unnamed: 2" : "name", 
                                        "Unnamed: 3" : "action_type1", 
                                        "Unnamed: 4" : "action_type2",
                                        "Unnamed: 5" : "document",
                                        "Unnamed: 6" : "folder1",
                                        "Unnamed: 7" : "folder2",}, inplace=True)
TLC_activity_progress = pd.concat([
                        TLC_activity_progress_nov15,  
                        TLC_activity_progress_nov8,  
                        TLC_activity_progress_nov5,  
                        TLC_activity_progress_nov2_21,  
                        TLC_activity_progress_okt31,  
                        TLC_activity_progress_okt27,  
                        TLC_activity_progress_okt24,  
                        TLC_activity_progress_okt19,  
                        TLC_activity_progress_okt17,  
                        TLC_activity_progress_okt13,  
                        TLC_activity_progress_okt9,  
                        TLC_activity_progress_okt5,  
                        TLC_activity_progress_sep30,    
                        TLC_activity_progress_sep25,    
                        TLC_activity_progress_sep11,    
                        TLC_activity_progress_avg31,     
                        TLC_activity_progress_avg20,     
                        TLC_activity_progress_avg7,     
                        TLC_activity_progress_jul24,     
                        TLC_activity_progress_jul10,     
                        TLC_activity_progress_june30,     
                        TLC_activity_progress_june26,     
                        TLC_activity_progress_june19,     
                        TLC_activity_progress_june12,     
                        TLC_activity_progress_june5,     
                        TLC_activity_progress_may30,     
                        TLC_activity_progress_may22,     
                        TLC_activity_progress_may1,     
                        TLC_activity_progress_apr5,     
                        TLC_activity_progress_apr4,     
                        TLC_activity_progress_apr3,     
                        TLC_activity_progress_apr2,     
                        TLC_activity_progress_apr1,     
                        TLC_activity_progress_mar4,  
                        TLC_activity_progress_mar3,  
                        TLC_activity_progress_mar2,    
                        TLC_activity_progress_mar1,
                        TLC_activity_progress_feb4,    
                        TLC_activity_progress_feb3,
                        TLC_activity_progress_feb2,
                        TLC_activity_progress_feb1,
                        TLC_activity_progress_jan2,
                        TLC_activity_progress_jan1,
                        TLC_activity_progress_dec3,
                        TLC_activity_progress_dec2,
                        TLC_activity_progress_dec1,
                        TLC_activity_progress_nov
                                  ])


TLC_activity_progress.reset_index(inplace=True, drop=True)

TLC_activity_progress.head()

# %%
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\TLC_Activity_' + ct + '.xlsx') as writer:  
    TLC_activity_progress.to_excel(writer, sheet_name='Report')

# %%
# Создание DF Review. #Поиск по слову. 
TLC_activity_progress['review'] = TLC_activity_progress['description'].str.contains("Review") #Поиск по слову.
TLC_activity_progress_review = TLC_activity_progress.query("review == True")
#TLC_activity_progress_review = TLC_activity_progress.query("review_status == '3' | review_status == '2' | review_status == '1'")

# %%
#Список для простановки статусов
review_list = TLC_activity_progress_review.description.to_list()
ln = len(review_list)
ln  
    #Создание колонки Review_status
TLC_activity_progress_review['review_status'] = TLC_activity_progress_review['action_type2'].map({'Add files to review process': '1','Submit review': '2','Set approval status': '3','Terminate review process': 'Void'})
#Чистка
#TLC_activity_progress_review.insert(9,'in report', '')

for i in range(ln):
    if (TLC_activity_progress_review['document'].iloc[i] == 'MK3_TLC_BEP.docx'
#        or TLC_activity_progress_review['document'].iloc[i] == 'TLC_P_AR1.pdf'
#        or TLC_activity_progress_review['document'].iloc[i] == 'TLC_P_AR2_2.pdf'
        or TLC_activity_progress_review['document'].iloc[i] == 'Test.docx'
        or TLC_activity_progress_review['document'].iloc[i] == 'Test.xlsx'
        or TLC_activity_progress_review['document'].iloc[i] == 'VTBR_Детализация BIM моделей.xlsx'
        or TLC_activity_progress_review['document'].iloc[i] == 'test_review.txt' 
        or TLC_activity_progress_review['document'].iloc[i] == 'Структура BEP.docx'
        or TLC_activity_progress_review['document'].iloc[i] == 'ТЛЦ_Требования к ПОС-модели.docx'       
        or TLC_activity_progress_review['document'].iloc[i] == 'Приложение 1.1. Техническое задание (Административный блок)_ver1.docx'    
        or TLC_activity_progress_review['document'].iloc[i] == 'TLC_P_I_1_MK3_DRW_AR_Office space_2020-06-19.pdf'    
        or TLC_activity_progress_review['document'].iloc[i] == 'Приложение 1.2. Техническое задание (Офисное здание)_ver1.docx'):
        
        TLC_activity_progress_review['review_status'].iloc[i] = 'N'
        
#TLC_activity_progress_review = TLC_activity_progress_review.copy()    
#TLC_activity_progress_review['review_status'] = TLC_activity_progress_review['document'].map({'K3_TLC_BEP.docx': 'X','Test.docx': 'X','VTBR_Детализация BIM моделей.xlsx': 'X','test_review.txt': 'X','Структура BEP.docx': 'X'})
TLC_activity_progress_review.review_status.unique()
#TLC_activity_progress_review.review_number.unique()
# Out:
# <ipython-input-4-0850b674d015>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TLC_activity_progress_review['review_status'] = TLC_activity_progress_review['action_type2'].map({'Add files to review process': '1','Submit review': '2','Set approval status': '3','Terminate review process': 'Void'})
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-0850b674d015>:24: SettingWithCopyWarning:
# ...

# %%
    #Создание колонки  Review_number
    #Разделение description по разделителю "#"
TLC_activity_progress_review_r1 = TLC_activity_progress_review.query("review_status == '1' | review_status == '2'| review_status == '3' | review_status == 'Void'")
#TLC_activity_progress_review_r1 = TLC_activity_progress_review_r1.drop(['date', 'description', 'name', 'action_type1'], axis =1)
TLC_activity_progress_review_r1

review_list = TLC_activity_progress_review_r1.description.to_list()
ln_short = len(review_list)


for i in range(ln_short):
        review_list[i] = review_list[i].split('#')
        del review_list[i][0]
        review_list[i] = ''.join(review_list[i])
        review_list[i] = review_list[i].split('.')
        review_list[i] = ''.join(review_list[i])

TLC_activity_progress_review_r1['review_number'] = pd.DataFrame(review_list)
for i in range(ln_short):
       TLC_activity_progress_review_r1['review_number'].iloc[i] = review_list[i]
TLC_activity_progress_review_r1
#Создание DF с номерами Review
TLC_activity_progress_review_r = TLC_activity_progress_review_r1.drop(['date', 
                                                                       'name', 
                                                                       'description',
                                                                       'action_type1',
                                                                       'action_type2',
                                                                       'document',
                                                                       'folder1',
                                                                       'folder2', 
                                                                       'review',
                                                                       'review_status'
                                                                       ], axis = 1)
#Создлание DF Документ - номер Review
TLC_activity_progress_review_doc_rev = TLC_activity_progress_review_r1.drop(['date', 
                                                                       'name', 
                                                                       'description',
                                                                       'action_type1',
                                                                       'action_type2',
                                                                       'folder1',
                                                                       'folder2', 
                                                                       'review',

                                                                       ], axis = 1)
TLC_activity_progress_review_doc_rev
# Out:
# <ipython-input-5-27b4ddb290d7>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TLC_activity_progress_review_r1['review_number'] = pd.DataFrame(review_list)
# <ipython-input-5-27b4ddb290d7>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TLC_activity_progress_review_r1['review_number'].iloc[i] = review_list[i]
#                                         document review_status review_number
# 1544    2021-11-03 протокол №6 - на подпись.xlsx             1           790
# 1599                                         NaN             2           779
# ...

# %%
#Выборка DF загруженные доки (1 статус) - номер Review 
TLC_activity_progress_review_doc_rev_1 = TLC_activity_progress_review_doc_rev.query("review_status == '1'")
TLC_activity_progress_review_doc_rev_1.rename(columns = {"document" : "document_rev"}, inplace=True)
TLC_activity_progress_review_doc_rev_1 = TLC_activity_progress_review_doc_rev_1.drop(['review_status'], axis =1)
TLC_activity_progress_review_doc_rev_1

#Добавление Review Number к таблице Review по статусу 1
TLC_activity_progress_review = TLC_activity_progress_review.join(TLC_activity_progress_review_r)
TLC_activity_progress_review = TLC_activity_progress_review.merge(TLC_activity_progress_review_doc_rev_1, on = 'review_number')
TLC_activity_progress_review
# Out:
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                 date  \
# 0      Fri, 12 Nov 2021 11:38:50 GMT
# 1      Fri, 12 Nov 2021 11:28:37 GMT
# 2      Fri, 12 Nov 2021 08:06:31 GMT
# 3      Fri, 12 Nov 2021 11:27:30 GMT
# 4      Fri, 12 Nov 2021 08:04:51 GMT
# ...                              ...
# 21088  Mon, 09 Nov 2020 12:07:51 GMT
# 21089  Mon, 09 Nov 2020 12:16:24 GMT
# 21090  Mon, 09 Nov 2020 12:16:08 GMT
# 21091  Fri, 06 Nov 2020 13:27:52 GMT
# 21092  Fri, 06 Nov 2020 09:03:52 GMT
#
#                                              description             name  \
# 0      Anna Shafranova added file 2021-11-03 протокол...  Anna Shafranova
# ...

# %%
TLC_activity_progress_review_doc_rev_3 = TLC_activity_progress_review_doc_rev.query("review_status == '3'")
TLC_activity_progress_review_doc_rev_3.rename(columns = {"document" : "document_rev_new"}, inplace=True)
TLC_activity_progress_review_doc_rev_3 = TLC_activity_progress_review_doc_rev_3.drop(['review_status'], axis =1)
TLC_activity_progress_review_doc_rev_3

#Добавление Review Number к таблице Review по статусу 3
TLC_activity_progress_review = TLC_activity_progress_review.merge(TLC_activity_progress_review_doc_rev_3, on = 'review_number', how = 'outer')
TLC_activity_progress_review.document_rev_new = TLC_activity_progress_review.document_rev_new.fillna(TLC_activity_progress_review.document_rev)
TLC_activity_progress_review
# Out:
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                 date  \
# 0      Fri, 12 Nov 2021 11:38:50 GMT
# 1      Fri, 12 Nov 2021 11:28:37 GMT
# 2      Fri, 12 Nov 2021 08:06:31 GMT
# 3      Fri, 12 Nov 2021 11:27:30 GMT
# 4      Fri, 12 Nov 2021 08:04:51 GMT
# ...                              ...
# 29821  Mon, 09 Nov 2020 12:16:08 GMT
# 29822  Fri, 06 Nov 2020 13:27:52 GMT
# 29823  Fri, 06 Nov 2020 09:03:52 GMT
# 29824                            NaN
# 29825                            NaN
#
#                                              description             name  \
# 0      Anna Shafranova added file 2021-11-03 протокол...  Anna Shafranova
# ...

# %%
    #Создание колонки  Building
    #Разделение document по разделителю "_"
document_list = TLC_activity_progress_review.document_rev.to_list()
ln = len(document_list)
ln

for i in range(ln):
        document_list[i] = str(document_list[i]).split('_')
        del document_list[i][0]
        document_list[i] = ''.join(document_list[i])

bad_chars = [ ".pdf", "[", "]"]
for i in range(ln):
        for j in bad_chars: 
            document_list[i] = document_list[i].replace(j, '')         



for i in range(ln):
        if 'Детализация BIM моделей.xlsx' in document_list[i]:
            document_list[i] = ""
        if 'TLCBEP.docx' in document_list[i]:
            document_list[i] = ""
        if 'ver1.docx' in document_list[i]:
            document_list[i] = ""         
        if 'PI1MK3DRWAROffice space2020-06-19' in document_list[i]:
            document_list[i] = ""               
        if 'PAR1' in document_list[i]:
            document_list[i] = "" 
        if 'PAR22' in document_list[i]:
            document_list[i] = ""
        if 'review.txt' in document_list[i]:
            document_list[i] = ""   
            
TLC_activity_progress_review = TLC_activity_progress_review.copy()
TLC_activity_progress_review['building'] = pd.DataFrame(document_list)
for i in range(ln):
       TLC_activity_progress_review['building'].iloc[i] = document_list[i]

#TLC_activity_progress_review.query("review_status == '1'")
#TLC_activity_progress_review.building
#document_list[193]
TLC_activity_progress_review.building.unique()
#TLC_activity_progress_review
#TLC_activity_progress_review.iloc[193]
# Out:
# array(['', 'TZ', '3', '2', '1', 'Q', 'ver2.xlsx', '2-1ES', 'RD-I-7-2-TH',
#        'TDII4MK3BIMARАрхитектура.rvt',
#        'TDII4MK3BIMESЭлектроснабжение.rvt',
#        'TDII3MK3BIMESЭлектроснабжение.rvt',
#        'TDII3MK3BIMKRКонструктив.rvt', 'TDII3MK3BIMARАрхитектура.rvt',
#        'TDII4MK3BIMKRКонструктив.rvt', 'TDII15.2MK3BIMKRКонструктив.rvt',
#        'TDII5.3MK3BIMVKВодоснабжение и канализация.rvt',
#        'TDII15.2MK3BIMARАрхитектура.rvt',
#        'TDIII7.4MK3BIMOVОВиК. Блок C.rvt',
#        'TDIII7.4MK3BIMVKВодоснабжение и канализация. Блок C.rvt',
#        'TDIII7.4MK3BIMPTПожаротушение. Блок C.rvt',
#        'TDIII7.4MK3BIMSSСлаботочные системы. Блок A.rvt',
#        'TDIII7.4MK3BIMVKВодоснабжение и канализация. Блок A.rvt',
#        'TDIII7.4MK3BIMPSПожарная сигнализация. Блок C.rvt',
#        'TDIII7.4MK3BIMESЭлектроснабжение. Блок Aотсоединено.rvt',
#        'TDIII7.4MK3BIMKRКонструктив. Блок C.rvt',
#        'TDIII7.4MK3BIMSSСлаботочные системы. Блок B.rvt',
# ...

# %%
    #Создание колонки  discipline 
    #Разделение document по разделителю "_"
discipline_list = TLC_activity_progress_review.document_rev.to_list()

ln = len(discipline_list)
ln
#bad_chars = [ r"[", r"'", ".pdf", "["] 

for i in range(ln):
        discipline_list[i] = str(discipline_list[i]).split('_')
        del discipline_list[i][-1:0:-1]
        discipline_list[i] = str(discipline_list[i]).split('-')
        del discipline_list[i][0:2]      
        del discipline_list[i][-1:0:-1]
        discipline_list[i] = ''.join(discipline_list[i])        
discipline_list
#Поиск индекса по значению
#[i for i,x in enumerate(discipline_list) if '2' in x][0]


bad_chars = [ ".pdf", "[", "]", "'"]
for i in range(ln):
        for j in bad_chars: 
            discipline_list[i] = discipline_list[i].replace(j, '') 

for i in range(ln):
        discipline_list[i] = str(discipline_list[i]).split('.')
        del discipline_list[i][-1:0:-1]
        discipline_list[i] = ''.join(discipline_list[i])
#чистка
for i in range(ln):
        if 'AR' in discipline_list[i]:
            discipline_list[i] = "AR"
        if 'KR' in discipline_list[i]:
            discipline_list[i] = "KR"
        if 'PZU' in discipline_list[i]:
            discipline_list[i] = "PZU'"
        if '19' in discipline_list[i]:
            discipline_list[i] = ""
#discipline_list[221]
TLC_activity_progress_review['discipline'] = pd.DataFrame(discipline_list)
for i in range(ln):
       TLC_activity_progress_review['discipline'].iloc[i] = discipline_list[i]
        

#Исключения, заполняемые "вручную"
for i in range(ln):
        if TLC_activity_progress_review['document_rev_new'].iloc[i] == 'TLC-P-AR2_2.pdf':
            TLC_activity_progress_review['discipline'].iloc[i] = 'AR'
            TLC_activity_progress_review['building'].iloc[i] = '2'        
        if TLC_activity_progress_review['document_rev_new'].iloc[i] == 'TLC_P_AR1.pdf':
            TLC_activity_progress_review['discipline'].iloc[i] = 'AR'
            TLC_activity_progress_review['building'].iloc[i] = '1'
        
        
TLC_activity_progress_review.discipline.unique()
TLC_activity_progress_review_group = TLC_activity_progress_review.groupby(['building', 'discipline', 'document_rev_new','review_number', 'review_status']).count()#.query("building == '4'")
TLC_activity_progress_review_group = TLC_activity_progress_review_group.drop(['date', 
#                                                                              'document',
                                                                             'description',
                                                                              'name',
                                                                              'action_type1',
                                                                              'action_type2',
                                                                              'folder1',
                                                                              'folder2',
                                                                              'review'
                                                                             ], axis = 1)

# %%
now = datetime.datetime.now()
ct = now.strftime("%Y-%m-%d")
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\TLC_Review_status_' + ct + '.xlsx') as writer:  
    TLC_activity_progress_review_group.to_excel(writer, sheet_name='Review Report')

# %%
#Фильтр для документов стадии ТД
TLC_activity_progress_review_group = TLC_activity_progress_review_group.reset_index()
TLC_activity_progress_review_group['review_td'] = TLC_activity_progress_review_group['document_rev_new'].str.contains("-P-")
TLC_activity_progress_review_group_td = TLC_activity_progress_review_group.query("review_td == False")
TLC_activity_progress_review_group_td['review_td'] = TLC_activity_progress_review_group_td['document_rev_new'].str.contains("-П-")
TLC_activity_progress_review_group_td = TLC_activity_progress_review_group_td.query("review_td == False")
TLC_activity_progress_review_group_td['review_td'] = TLC_activity_progress_review_group_td['document_rev_new'].str.contains("_P_")
TLC_activity_progress_review_group_td = TLC_activity_progress_review_group_td.query("review_td == False")
TLC_activity_progress_review_group_td = TLC_activity_progress_review_group_td.drop(['review_td', 
                                                                             'document_rev',
                                                                              'document',
                                                                             ], axis = 1)
TLC_activity_progress_review_group_td = TLC_activity_progress_review_group_td.groupby(['building', 'discipline', 'document_rev_new','review_number', 'review_status']).count()
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\TLC_Review_status_TD_' + ct + '.xlsx') as writer:  
    TLC_activity_progress_review_group_td.to_excel(writer, sheet_name='Review Report')
# Out:
# <ipython-input-11-9ea3174eac05>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TLC_activity_progress_review_group_td['review_td'] = TLC_activity_progress_review_group_td['document_rev_new'].str.contains("-П-")

# %%
#Фильтр для документов стадии ТД fin
TLC_activity_progress_review_group_td_fin = TLC_activity_progress_review_group_td.query("review_number > '479'")
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\% ДПС\03 - ТЛЦ\05 - ПИР\03 - ПРОЕКТ\20 BIM\997_Отчёты\TLC_Review_status_TD_fin_' + ct + '.xlsx') as writer:  
    TLC_activity_progress_review_group_td_fin.to_excel(writer, sheet_name='Review Report')

# %%
TLC_activity_progress_review_group_TD = TLC_activity_progress_review_group.query(document_rev_new.str.contains("-TD-"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bf58d58a7289> in <module>
# ----> 1 TLC_activity_progress_review_group_TD = TLC_activity_progress_review_group.query(document_rev_new.str.contains("-TD-"))
#
# NameError: name 'document_rev_new' is not defined

# %%
TLC_activity_progress_review_group = TLC_activity_progress_review_group.reset_index()

# %%
#Вывод на печать 
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(20,7)})
#TLC_countplot_VTBR = sns.countplot(x = 'name', data = TLC_activity_progress_100.filter(items = ['name', 'action_type2']))
#TLC_countplot_rew = sns.countplot(x = 'discipline', data = TLC_activity_progress_review.discipline)

TLC_activity_progress_review_plot = TLC_activity_progress_review.query("review_status == '3'").groupby(['building', 'discipline'], as_index=False).count()
TLC_activity_progress_review_plot = TLC_activity_progress_review_plot.sort_values(by=['building'])
sns.countplot(x = 'building', data = TLC_activity_progress_review_plot)

# %%
'''
labels = TLC_activity_progress_review.building

TLC_activity_progress_review_plot1 = TLC_activity_progress_review.query("review_status == '1'").groupby(['building', 'discipline'], as_index=False).count()
TLC_activity_progress_review_plot = TLC_activity_progress_review_plot.sort_values(by=['building'])
on_rewiew = [20, 34, 30, 35, 27]
approved = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
# Out:
#   File "<ipython-input-83-c7e6ce9f5688>", line 40
#     plt.show()
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
# Анализ переименований файлов
'''
TLC_activity_progress_rename_f = TLC_activity_progress.query("action_type2 == 'Rename file'")

TLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f['description'].str.split('renamed ',expand=True).drop(0, axis =1)
TLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split[1].str.split(' in the ',expand=True) 
TLC_activity_progress_rename_f_split_0 = TLC_activity_progress_rename_f_split[0].str.split(' to ',expand=True)
TLC_activity_progress_rename_f_split_0.rename(columns = {0 : "file_name", 1 : "new_file_name"}, inplace=True)
TLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split.join(TLC_activity_progress_rename_f_split_0)
TLC_activity_progress_rename_f_split.rename(columns = {1 : "folder"}, inplace=True)
TLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split.drop(0, axis =1)
TLC_activity_progress_rename_f_split

TLC_activity_progress_rename_f_split_gr = TLC_activity_progress_rename_f_split.groupby(['file_name','new_file_name']).count()

with pd.ExcelWriter('Rename_names_folder.xlsx') as writer:  
    TLC_activity_progress_rename_f_split.to_excel(writer)
    
TLC_activity_progress_rename_f_split.groupby(['folder','file_name','new_file_name']).count()

TLC_activity_progress_rename_f_split['file_name'].unique()
'''
# Out:
# '\nTLC_activity_progress_rename_f = TLC_activity_progress.query("action_type2 == \'Rename file\'")\n\nTLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f[\'description\'].str.split(\'renamed \',expand=True).drop(0, axis =1)\nTLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split[1].str.split(\' in the \',expand=True) \nTLC_activity_progress_rename_f_split_0 = TLC_activity_progress_rename_f_split[0].str.split(\' to \',expand=True)\nTLC_activity_progress_rename_f_split_0.rename(columns = {0 : "file_name", 1 : "new_file_name"}, inplace=True)\nTLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split.join(TLC_activity_progress_rename_f_split_0)\nTLC_activity_progress_rename_f_split.rename(columns = {1 : "folder"}, inplace=True)\nTLC_activity_progress_rename_f_split = TLC_activity_progress_rename_f_split.drop(0, axis =1)\nTLC_activity_progress_rename_f_split\n\nTLC_activity_progress_rename_f_split_gr = TLC_activity_progress_rename_f
# ...

# %%
#Определение колонки с датой
TLC_activity_progress['date'] = pd.to_datetime(TLC_activity_progress['date']).dt.date
TLC_activity_progress['date'] = pd.to_datetime(TLC_activity_progress['date'])
TLC_activity_progress['week'] = pd.to_datetime(TLC_activity_progress['date']).dt.week
TLC_activity_progress['year'] = pd.to_datetime(TLC_activity_progress['date']).dt.year

#Преобразование номера недели в дату

TLC_activity_progress = TLC_activity_progress.assign(date_week = '')

TLC_activity_progress['year'] = TLC_activity_progress['year'].astype(str)
TLC_activity_progress['year'] = TLC_activity_progress['year'] + '-W'+ TLC_activity_progress['week'].astype("str")


for i in range(TLC_activity_progress['year'].size):
    TLC_activity_progress['date_week'].iloc[i] = datetime.datetime.strptime(TLC_activity_progress['year'].iloc[i] + '-1', '%G-W%V-%u')

TLC_activity_progress['date_week'] = pd.to_datetime(TLC_activity_progress['date_week'], format='%Y%m%d', errors='ignore')
TLC_activity_progress['year'] = pd.to_datetime(TLC_activity_progress['date']).dt.year


#Преобразование Object to  Text
#TLC_activity_progress['description'] = TLC_activity_progress['description'].astype('str', copy=False)

TLC_activity_progress
# Out:
# C:\Users\kumskov_ag\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#              date                                        description  \
# 0      2021-11-15   Andrey Kumskov exported the Activity log report.
# 1      2021-11-15   Andrey Kumskov exported the Activity log report.
# 2      2021-11-15   Andrey Kumskov exported the Activity log report.
# 3      2021-11-15   Andrey Kumskov exported the Activity log report.
# 4      2021-11-15   Andrey Kumskov exported the Activity log report.
# ...           ...                                                ...
# 360235 2020-05-25  Andrey Kumskov deleted 4.1_Мелкооптовый склад ...
# ...

# %%
TLC_activity_progress.query("week == '53'")
# Out:
#              date                                        description  \
# 274290 2020-12-30  Marina Ermolova notified project member Denis ...
# 274291 2020-12-30  Marina Ermolova notified project member Alexan...
# 274292 2020-12-30  Marina Ermolova notified reviewer Шундиков Арт...
# 274293 2020-12-30  Marina Ermolova added file TLC-TD-TS.xlsx to R...
# 274294 2020-12-30               Marina Ermolova created Review #331.
# ...           ...                                                ...
# 275627 2020-12-28         Veronica Leonova viewed TLC-P-PZ2_OPZ.pdf.
# 275628 2020-12-28                 Veronica Leonova viewed Issue 238.
# 275629 2020-12-28         Veronica Leonova viewed TLC-P-PZ2_OPZ.pdf.
# 275630 2020-12-28                 Veronica Leonova viewed Issue 238.
# 275631 2020-12-28                 Veronica Leonova viewed Issue 243.
#
#                     name             action_type1  \
# 274290   Marina Ermolova         notify-observers
# ...

# %%
def rule(x):
    if (x == 'Alexandr Schedrin' 
        or x == 'Dmitrii Elistratov' 
        or x == 'Marina Ermolova' 
        or x == 'Yuri Bazylev' 
        or x == 'Светлана Простова' 
        or x == 'Сергей Шорохов'
        or x == 'Maksim Aleksandrov'
        or x == 'Dmitry Zhukov'
        or x == 'Скобелева Елисавета'
        or x == 'Анастасия Махтарова'
        or x == 'Denis Fishman'
        or x == 'Артур Спирин'
        or x == 'Egorov Maksim'
        or x == 'Elena Antonova'
        or x == 'Янбулат Тимур'
        or x == 'Olga Lomakina'
        or x == 'Наталья Липовка'
        or x == 'Mikhail Isaev'
        or x == 'Алексей Арефьев'
        or x == 'Евгений Болтунов'
        or x == 'Екатерина Филиппиа'
        or x == 'Наталия Дудник'
        or x == 'Veronica Leonova'
        or x == 'Дмитрий Петров'
        or x == 'Елена Лисовская'
        or x == 'Лариса Овчиникова'
        or x == 'Dmitrii Elistratov'
        or x == 'Vyacheslav Litvinov'
        or x == 'Айбим BIM360'
        or x == 'Дмитрий Семенченко'
         ):
        return 'MK3'
    
    elif (x == 'Andrey Kumskov' 
        or x == 'Юлия Морозова' 
        or x == 'Алексей Голиков' 
        or x == 'Владимир Гаськов' 
        or x == 'Шундиков Артем' 
        or x == 'Москвин Илья'
        or x == 'Митрофанов Дмитрий'
        or x == 'Александр Звонов'
        or x == 'Сергей Абрамов'
        or x == 'Мария Реутова'
        or x == 'Евгений Стуров'          
        or x == 'Денис Баранов'         
        or x == 'Мария Реутова'
        or x == 'Anna Shafranova' 
        or x == 'Дамир Фатехов' 
        or x == 'Anton Kasparian'
        or x == 'Георгий Телепнев'
        or x == 'Сергей Шамолин'
        or x ==  'Дженков Максим'
        or x == 'Denis Pasechnik'
        or x == 'Вадим Шеховцов'
        or x ==  'Sergey Tsarev'
        or x ==  'Alexander Gureev'          
        or x ==  'Павел Ирышков'           
        or x ==  'Roman pozdnyakov'          
        or x ==  'Елена Колесникова'
         ):
        return 'VTBR'
    
    elif ('Review' in x):
#    elif (x.find("Review") != -1):
        return 'Review'
    
    else:
        return 'undefined'


TLC_activity_progress['team'] = TLC_activity_progress.apply(lambda x: rule(x['name']), axis=1)
#TLC_activity_progress = TLC_activity_progress[['name','team','action_type2','action_type1', 'description','date','week','document','folder1','folder2']]

#
def rule(y):
    if (y == 'Download source file/Export sheet' 
        or y == 'Export item' 
        or y == 'Print document' 
        or y == 'View document' 
        or y == 'Edit office file'
        or y == 'calibrate-entity'
        or y == 'View transmittal'
        or y == 'View file'
       ):
        return 'Reviewed Information'

    elif (y == 'Upload document' 
        or y == 'Create folder'
        or y == 'Create transmittal'
        or y == 'Upload file'
        or y == 'Share file with recipients'
         ):
        return 'Sent Information'
    
    elif (y == 'Create issue' 
        or y == 'Edit markup'
        or y == 'Publish markup'
        or y == 'Add documents to review process' 
        or y == 'Claim workflow task'
        or y == 'Initiate review process'
        or y == 'Notify reviewers'
        or y == 'Set approval status'
        or y == 'Submit review'
        or y == 'Publish markup'
        or y == 'Add answer to issue'
        or y == 'Add attachment to issue'
        or y == 'Add comment to issue'
        or y == 'Assign issue'
        or y == 'Close issue'
        or y == 'View an existing review item'  
        or y == 'quality-issue-view'
        or y == 'Archive markup'
        or y == 'Terminate review process'
        or y == 'Add a comment'  
        or y == 'Delegate workflow task'
        or y == 'Quality issue respond'
        or y == 'Create a published markup'
        or y ==  'Copy documents to destination folder after the review process'
        or y ==  'Send additional notifications'
        or y == 'Add files to review process'
        or y == 'Copy files to destination folder after the review process'
        or y == 'Updated a comment in a review'
         ):
        return 'Issues Markups Review'   
    
    elif (y == 'Copy item' 
        or y == 'Delete folder'
        or y == 'Delete item'
        or y == 'Export document log'
        or y == 'Export project activity log'
        or y == 'Move item'
        or y == 'Remove Location'
        or y == 'Rename document'
        or y == 'Rename file'
        or y == 'Rename folder'
        or y == 'Save approval workflow'
        or y == 'Set folder permission'
        or y == 'remove-company-permission'
        or y == 'Edit description'
        or y == 'Restore deleted item'
        or y == 'Archive approval workflow'
        or y == 'Export file log'
        or y == 'Make current'
        or y == 'Print file'
        or y == 'Remove/reset folder permission'
         ):                     
        return 'Administrative'
    else:
        return 'undefined'

TLC_activity_progress['Type Action'] = TLC_activity_progress.apply(lambda y: rule(y['action_type2']), axis=1)          

TLC_activity_progress
# Out:
#              date                                        description  \
# 0      2021-11-15   Andrey Kumskov exported the Activity log report.
# 1      2021-11-15   Andrey Kumskov exported the Activity log report.
# 2      2021-11-15   Andrey Kumskov exported the Activity log report.
# 3      2021-11-15   Andrey Kumskov exported the Activity log report.
# 4      2021-11-15   Andrey Kumskov exported the Activity log report.
# ...           ...                                                ...
# 360235 2020-05-25  Andrey Kumskov deleted 4.1_Мелкооптовый склад ...
# 360236 2020-05-25  Andrey Kumskov deleted 4.5_Крупноотптовый скла...
# 360237 2020-05-25  Andrey Kumskov deleted 4.3_Мелкооптовый склад ...
# 360238 2020-05-25  Andrey Kumskov deleted 4.2_Крупнооптовый склад...
# 360239 2020-05-25  Andrey Kumskov deleted 4.1_Мелкооптовый склад ...
#
#                   name           action_type1                 action_type2  \
# ...

# %%
#Анализ уникальных значений

#TLC_activity_progress.action_type2.unique()
#np.sort(TLC_activity_progress.team.unique())
#TLC_activity_progress.groupby(['Type Action','action_type2']).count()
#TLC_activity_progress.date.min()
TLC_activity_progress.groupby(['team', 'name']).count()
#TLC_activity_progress.query("document == 'TLC-P-AR10_15-5.pdf'")
# Out:
#                                date  description  action_type1  action_type2  \
# team      name
# MK3       Alexandr Schedrin    5958         5958          5958          5958
#           Denis Fishman       17763        17763         17763         17763
#           Dmitrii Elistratov     89           89            89            89
#           Dmitry Zhukov        3430         3430          3430          3430
#           Egorov Maksim         285          285           285           285
# ...                             ...          ...           ...           ...
# undefined Надежда Карпенко     2528         2528          2528          2528
#           Роман Махнев           33           33            33            33
#           Роман Пугач           873          873           873           873
#           Юрий Базылев          132          132           132           132
#           валерий сав           339          339           339           339
#
# ...

# %%
#Выборка по загружаемым документам MK3
#TLC_activity_progress_upload = TLC_activity_progress.query("action_type2 == 'Upload document' | action_type2 == 'Rename document'").query("team == 'MK3'")
#TLC_Groupby_upload = TLC_activity_progress_upload.pivot_table(values = 'action_type2', index = {'team', 'folder1'}, columns = 'week', aggfunc = 'count').fillna(0)
TLC_2020_11_20 = TLC_activity_progress.query("date.astype('str') == '2020-11-20'")
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\# BIM\11_BIM прогресс\Activity progress\2020_11_20.xlsx') as writer:  
    TLC_2020_11_20.to_excel(writer, sheet_name='Users_Detail')

# %%
#Номер последней недели
max_week = TLC_activity_progress.week.max()
#Выборка для двух посл месяцев
TLC_activity_progress_2month = TLC_activity_progress.query("week > (46 - 8)")
max_week
# Out:
# 53

# %%
# Таблица активности компаний по времени (номер недели по оси Х)
TLC_Groupby_Team_Actions = TLC_activity_progress.pivot_table(values = 'action_type2', index = {'team', 'Type Action'}, columns = 'date_week', aggfunc = 'count').fillna(0)
TLC_Groupby_Team_Actions

TLC_Groupby_Team_Actions_2m = TLC_activity_progress_2month.pivot_table(values = 'action_type2', index = {'team', 'Type Action'}, columns = 'date_week', aggfunc = 'count').fillna(0)
TLC_Groupby_Team_Actions_2m
# Out:
# date_week                        2020-09-21  2020-09-28  2020-10-05  \
# Type Action           team
# Administrative        MK3              46.0        26.0        25.0
#                       VTBR              7.0        86.0        66.0
#                       undefined         0.0         0.0         0.0
# Issues Markups Review MK3              50.0       166.0       655.0
#                       VTBR            247.0       421.0       456.0
#                       undefined         0.0         0.0         0.0
# Reviewed Information  MK3             797.0      1316.0      1607.0
#                       VTBR           1961.0      2782.0      2565.0
#                       undefined         0.0         0.0         0.0
# Sent Information      MK3              91.0       307.0       249.0
#                       VTBR              2.0        23.0        12.0
#                       undefined         0.0         0.0         0.0
# ...

# %%
#Детальная выборка по пользователям и активностям
TLC_Groupby_Team_Actions_Users_Detail = TLC_activity_progress.pivot_table(values = 'action_type1', index = 'name', columns = {'action_type2'}, aggfunc = 'count').fillna(0)
#Общая выборка по пользователям и по типам активностей
TLC_Groupby_Team_Actions_Users_Sum = TLC_activity_progress.pivot_table(values = 'action_type2', index = 'name', columns = {'Type Action'}, aggfunc = 'count').fillna(0)
TLC_Groupby_Team_Actions_Users_Sum
# Out:
# Type Action            Administrative  Issues Markups Review  \
# name
# Akeksey adidur                    0.0                    0.0
# Alexander Gureev                  0.0                    3.0
# Alexander Sarro                  29.0                    0.0
# Alexandr Schedrin              1109.0                  855.0
# Anastasia Borisenkova             0.0                    0.0
# ...                               ...                    ...
# Шундиков Артем                   32.0                  103.0
# Юлия Морозова                     0.0                    0.0
# Юрий Базылев                      0.0                   53.0
# Янбулат Тимур                    31.0                 1545.0
# валерий сав                       0.0                    0.0
#
# Type Action            Reviewed Information  Sent Information  undefined
# name
# Akeksey adidur                        931.0               1.0        0.0
# Alexander Gureev                     3328.0               0.0        0.0
# ...

# %%
# Установка датафрема для печати
TLC_Groupby_Team_Actions_Plot = TLC_activity_progress_2month.pivot_table(values = 'action_type2', index = 'date_week', columns = {'team', 'Type Action'}, aggfunc = 'count').fillna(0)


#TLC_Groupby_Team_Actions_Plot['MK3','Administrative']
TLC_Groupby_Team_Actions_Plot.columns
# Out:
# MultiIndex([(       'Administrative',       'MK3'),
#             (       'Administrative',      'VTBR'),
#             (       'Administrative', 'undefined'),
#             ('Issues Markups Review',       'MK3'),
#             ('Issues Markups Review',      'VTBR'),
#             ('Issues Markups Review', 'undefined'),
#             ( 'Reviewed Information',       'MK3'),
#             ( 'Reviewed Information',      'VTBR'),
#             ( 'Reviewed Information', 'undefined'),
#             (     'Sent Information',       'MK3'),
#             (     'Sent Information',      'VTBR'),
#             (     'Sent Information', 'undefined'),
#             (            'undefined',      'VTBR')],
#            names=['Type Action', 'team'])

# %%
TLC_Groupby_Team_Actions_Plot_R_S = TLC_Groupby_Team_Actions_Plot.drop([('Administrative',  'MK3'),
                                                                        ('Administrative', 'VTBR'), 
                                                                        ('Issues Markups Review',  'MK3'),
                                                                        ('Issues Markups Review', 'VTBR')
                                                                       ], axis = 1)
TLC_Groupby_Team_Actions_Plot_Issues = TLC_Groupby_Team_Actions_Plot.drop([('Administrative',  'MK3'),
                                                                           ('Administrative', 'VTBR'),
                                                                           ('Reviewed Information',  'MK3'),
                                                                           ('Reviewed Information', 'VTBR'),
                                                                           ('Sent Information',  'MK3'),
                                                                           ('Sent Information', 'VTBR')
                                                                          ], axis = 1)

# %%
my_color = ['lawngreen', 'skyblue', 'green', 'darkblue']
#my_linewidth = ['1', '2']
#my_linestyle = ['-', '--']
TLC_Groupby_Team_Actions_Plot_R_S.plot(kind = 'line', figsize = [20, 7], title = 'График активностей по неделям', color = my_color, linewidth = 2)

# %%
TLC_Groupby_Team_Actions
# Out:
# date_week                        2020-05-25  2020-06-01  2020-06-08  \
# Type Action           team
# Administrative        MK3               0.0         0.0        18.0
#                       VTBR             28.0        43.0        13.0
#                       undefined         0.0         0.0         0.0
# Issues Markups Review MK3               0.0         0.0         0.0
#                       VTBR              0.0         0.0         0.0
#                       undefined         0.0         0.0         0.0
# Reviewed Information  MK3              82.0        60.0        21.0
#                       VTBR              5.0         6.0        89.0
#                       undefined         0.0         0.0         0.0
# Sent Information      MK3               0.0        13.0        38.0
#                       VTBR            122.0       352.0        83.0
#                       undefined         0.0         0.0         0.0
# ...

# %%
my_color = ['green','darkblue']
#my_linewidth = ['1', '2']
#my_linestyle = ['-', '--']
TLC_Groupby_Team_Actions_Plot_Issues.plot(kind = 'line', figsize = [20, 7], title = 'График Issues по неделям', color = my_color, linewidth = 2)

# %%
# Краткий график

#Выборка VTBR
#TLC_activity_progress_vtbr = TLC_activity_progress.query("team =='VTBR'")
#Установка минимума для всего периода
TLC_activity_progress_group100 = TLC_activity_progress.groupby(['name']).count().query('action_type2 > 1000').reset_index()
TLC_activity_progress_100 = TLC_activity_progress.merge(TLC_activity_progress_group100, on = 'name', how = 'right')

#Установка минимума для 2 месяцев
TLC_activity_progress_group100_2m = TLC_activity_progress_2month.groupby(['name']).count().query('action_type2 > 1000').reset_index()
TLC_activity_progress_100_2m = TLC_activity_progress_2month.merge(TLC_activity_progress_group100, on = 'name', how = 'right')

#Вывод на печать 
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(15,5)})
#TLC_countplot_VTBR = sns.countplot(x = 'name', data = TLC_activity_progress_100.filter(items = ['name', 'action_type2']))
TLC_countplot_2m = sns.countplot(x = 'name', data = TLC_activity_progress_100_2m.filter(items = ['name', 'action_type2']))

# %%
# Краткий график

#Выборка VTBR
#TLC_activity_progress_vtbr = TLC_activity_progress.query("team =='VTBR'")
#Установка минимума
TLC_activity_progress_group100 = TLC_activity_progress.groupby(['name']).count().query('action_type2 > 400').reset_index()
TLC_activity_progress_group100
TLC_activity_progress_100 = TLC_activity_progress.merge(TLC_activity_progress_group100, on = 'name', how = 'right')
TLC_activity_progress_100

#Вывод на печать
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(22,6)})
TLC_countplot = sns.countplot(x = 'name', data = TLC_activity_progress_100.filter(items = ['name', 'action_type2']))

# %%
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(r'\\192.168.128.12\VTBN_Disk\# BIM\11_BIM прогресс\Activity progress\TLC_Activity report_' + ct + '.xlsx') as writer:  
    TLC_Groupby_Team_Actions_Users_Detail.to_excel(writer, sheet_name='Users_Detail')
    TLC_Groupby_Team_Actions_Users_Sum.to_excel(writer, sheet_name='Users_Sum')
    TLC_Groupby_Team_Actions.to_excel(writer, sheet_name='Weekly_Activity')
#    TLC_activity_progress_weekly_sum.to_excel(writer, sheet_name='Weekly_Activity_Sum')
#    TLC_Groupby_upload.to_excel(writer, sheet_name='Upload Documents by week')

# %%
# Выборка кто когда делал Комментарии
TLC_activity_progress_markups = TLC_activity_progress.query("action_type2 == ['Edit markup', 'Publish markup', 'Create a published markup', 'Archive markup']")
TLC_activity_progress_markups = TLC_activity_progress_markups.query("'2021-10-20' <= date < '2021-11-15'")
#TLC_activity_progress_markups = TLC_activity_progress_markups.query("team == ['VTBR']")
TLC_activity_progress_markups_gr = TLC_activity_progress_markups.groupby(['name', 'action_type2']).count()
TLC_activity_progress_markups_srt = TLC_activity_progress_markups.sort_values(by=['name'])

with pd.ExcelWriter('TLC_Activity report_MarkUps.xlsx') as writer:  
    TLC_activity_progress_markups_gr.to_excel(writer, sheet_name='MarkUps by Users')
    TLC_activity_progress_markups_srt.to_excel(writer, sheet_name='All MarkUps')

# %%
TLC_activity_progress_markups_gr = TLC_activity_progress_markups.groupby(['name', 'action_type2']).count()

# %%
TLC_activity_progress_markups
# Out:
#             date                                        description  \
# 711   2021-11-12  Вадим Шеховцов published a markup on TLC-P-IOS...
# 712   2021-11-12  Вадим Шеховцов published a markup on TLC-P-IOS...
# 757   2021-11-12  Вадим Шеховцов published a markup on TLC-P-PB3...
# 814   2021-11-12  Владимир Гаськов created a published markup on...
# 828   2021-11-12  Andrey Vorobiyev archived a markup from TLC-RD...
# ...          ...                                                ...
# 30007 2021-10-21  Сергей Шамолин created a published markup on T...
# 30008 2021-10-21  Владимир Гаськов created a published markup on...
# 30105 2021-10-21  Сергей Шамолин created a published markup on T...
# 30114 2021-10-21  Владимир Гаськов created a published markup on...
# 30126 2021-10-21  Сергей Шамолин archived a markup from TLC-RD-I...
#
#                    name      action_type1               action_type2  \
# 711      Вадим Шеховцов  markup-published             Publish markup
# ...

# %%
TLC_activity_progress_markups.query("name == ['Скобелева Елисавета']").head(20)
# Out:
#             date                                        description  \
# 6516  2021-11-10  Скобелева Елисавета created a published markup...
# 6545  2021-11-10  Скобелева Елисавета created a published markup...
# 7579  2021-11-09  Скобелева Елисавета created a published markup...
# 7602  2021-11-09  Скобелева Елисавета created a published markup...
# 8516  2021-11-09  Скобелева Елисавета created a published markup...
# 8522  2021-11-09  Скобелева Елисавета created a published markup...
# 8693  2021-11-09  Скобелева Елисавета created a published markup...
# 8759  2021-11-09  Скобелева Елисавета created a published markup...
# 8764  2021-11-09  Скобелева Елисавета created a published markup...
# 17259 2021-11-01  Скобелева Елисавета created a published markup...
# 17261 2021-11-01  Скобелева Елисавета created a published markup...
# 17265 2021-11-01  Скобелева Елисавета created a published markup...
# 23602 2021-10-27  Скобелева Елисавета edited a markup on TLC-RD-...
# ...

# %%
#Закрытие Маркапов по дням last week
TLC_activity_progress_lweek = TLC_activity_progress.query("'2021-03-15' <= date <= '2021-03-30'")
TLC_activity_progress_lweek = TLC_activity_progress_lweek.query("action_type2 == 'Archive markup'")
# Установка датафрема для печати
TLC_Groupby_Team_Markupweek_Plot = TLC_activity_progress_lweek.query("team == 'VTBR' | team == 'MK3'")
TLC_Groupby_Team_Markupweek_Plot = TLC_Groupby_Team_Markupweek_Plot.pivot_table(index = 'date', columns = {'team', 'action_type2'}, aggfunc = 'count').fillna(0)

TLC_Groupby_Team_Markupweek_Plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1e1535aa4d63> in <module>
#       1 #Закрытие Маркапов по дням last week
# ----> 2 TLC_activity_progress_lweek = TLC_activity_progress.query("'2021-03-15' <= date <= '2021-03-30'")
#       3 TLC_activity_progress_lweek = TLC_activity_progress_lweek.query("action_type2 == 'Archive markup'")
#       4 # Установка датафрема для печати
#       5 TLC_Groupby_Team_Markupweek_Plot = TLC_activity_progress_lweek.query("team == 'VTBR' | team == 'MK3'")
#
# NameError: name 'TLC_activity_progress' is not defined

# %%
#Выборка VTBR по всему проекту кто что делал

TLC_activity_progress_vtbract = TLC_activity_progress.query("team == 'VTBR'").groupby(['name', 'Type Action']).count()
with pd.ExcelWriter('TLC_Activity report_VTBR_act.xlsx') as writer:  
    TLC_activity_progress_vtbract.to_excel(writer, sheet_name='VTBR Actions')

# %%
# Out:
# 26
