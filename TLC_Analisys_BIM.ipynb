# %%
import pandas as pd
import numpy as np
#import pathlib
import datetime
#import xlrd
#import openpyxl
from configurations import config 
#import os
from rschedule import rschedule

# %%
path_proj = config['path']['tlc']

# %%
# Creating objects
#Создание объектов ОРЦ
build_tlc_1 = rschedule('tlc', '1_Бизнес центр')
build_tlc_2d1 = rschedule('tlc', '2.1_Офисное модульное здание')
build_tlc_2 = rschedule('tlc', '2_АБК')
build_tlc_3 = rschedule('tlc', '3_Гараж')
build_tlc_4 = rschedule('tlc', '4_Мастерская')
build_tlc_5d1 = rschedule('tlc', '5.1_КПП1')
build_tlc_5d2 = rschedule('tlc', '5.2_КПП2')
build_tlc_5d3 = rschedule('tlc', '5.3_КПП3')
build_tlc_5d4 = rschedule('tlc', '5.4_КПП4')
build_tlc_7d2 = rschedule('tlc', '7.2')
build_tlc_7d4 = rschedule('tlc', '7.4_Склад')
build_tlc_8d1 = rschedule('tlc', '8.1_РТП')
build_tlc_11d5d1 = rschedule('tlc', '11.5.1')
build_tlc_11d5d2 = rschedule('tlc', '11.5.2')
build_tlc_11d5d3 = rschedule('tlc', '11.5.3')
build_tlc_11d5d4 = rschedule('tlc', '11.5.4')
build_tlc_11d6 = rschedule('tlc', '11.6')
build_tlc_14d1 = rschedule('tlc', '14.1_Котельная1')
build_tlc_14d2 = rschedule('tlc', '14.2_Котельная2')
build_tlc_14d4 = rschedule('tlc', '14.4')
build_tlc_15d1 = rschedule('tlc', '15.1_СВК')
build_tlc_15d2 = rschedule('tlc', '15.2_Склад ИМ')
build_tlc_15d3 = rschedule('tlc', '15.3_Склад ПМ')
build_tlc_15d4d1 = rschedule('tlc', '15.4_Склад МК/15.4.1')
build_tlc_15d4d2 = rschedule('tlc', '15.4_Склад МК/15.4.2')
build_tlc_15d5 = rschedule('tlc', '15.5_Склад ТГ')
build_tlc_15d6 = rschedule('tlc', '15.6_Склад АТ')
build_tlc_15d7 = rschedule('tlc', '15.7_Склад ТШП')
#build_tlc_18 = rschedule('tlc', '18')
build_tlc_21 = rschedule('tlc', '21')

# %%
#Проверка
#Multi
checkmt_1 = build_tlc_1.check_multi()
checkmt_2 = build_tlc_2.check_multi()
checkmt_2d1 = build_tlc_2d1.check_multi()
checkmt_3 = build_tlc_3.check_multi()
checkmt_4 = build_tlc_4.check_multi()
checkmt_5d1 = build_tlc_5d1.check_multi()
checkmt_5d2 = build_tlc_5d2.check_multi()
checkmt_5d3 = build_tlc_5d3.check_multi()
checkmt_5d4 = build_tlc_5d4.check_multi()
checkmt_7d2 = build_tlc_7d2.check_multi()
checkmt_7d4 = build_tlc_7d4.check_multi()
checkmt_8d1 = build_tlc_8d1.check_multi()
checkmt_11d5d1 = build_tlc_11d5d1.check_multi()
checkmt_11d5d2 = build_tlc_11d5d2.check_multi()
checkmt_11d5d3 = build_tlc_11d5d3.check_multi()
checkmt_11d5d4 = build_tlc_11d5d4.check_multi()
checkmt_11d6 = build_tlc_11d6.check_multi()
checkmt_14d1 = build_tlc_14d1.check_multi()
checkmt_14d2 = build_tlc_14d2.check_multi()
checkmt_14d4 = build_tlc_14d4.check_multi()
checkmt_15d1 = build_tlc_15d1.check_multi()
checkmt_15d2 = build_tlc_15d2.check_multi()
checkmt_15d3 = build_tlc_15d3.check_multi()
checkmt_15d4d1 = build_tlc_15d4d1.check_multi()
checkmt_15d4d2 = build_tlc_15d4d2.check_multi()
checkmt_15d5 = build_tlc_15d5.check_multi()
checkmt_15d6 = build_tlc_15d6.check_multi()
checkmt_15d7 = build_tlc_15d7.check_multi()
#checkmt_18= build_tlc_18.check_multi()
checkmt_21 = build_tlc_21.check_multi()


tlc_ch_mt = pd.DataFrame([all(checkmt_1),
all(checkmt_2),
all(checkmt_2d1),
all(checkmt_3),
all(checkmt_4),
all(checkmt_5d1),
all(checkmt_5d2),
all(checkmt_5d3),
all(checkmt_5d4),
all(checkmt_7d2),
all(checkmt_7d4),
all(checkmt_8d1),
all(checkmt_11d5d1),
all(checkmt_11d5d2),
all(checkmt_11d5d3),
all(checkmt_11d5d4),
all(checkmt_11d6),
all(checkmt_14d1),
all(checkmt_14d2),
all(checkmt_14d4),
all(checkmt_15d1),
all(checkmt_15d2),
all(checkmt_15d3),
all(checkmt_15d4d1),
all(checkmt_15d4d2),
all(checkmt_15d5),
all(checkmt_15d6),
all(checkmt_15d7),
#all(checkmt_18),
all(checkmt_21)],
['1-',
'2-',
'2.1-',
'3-',
'4-',
'5.1-',
'5.2-',
'5.3-',
'5.4-',
'7.2-',
'7.4-',
'8.1-',
'11.5.1-',
'11.5.2-',
'11.5.3-',
'11.5.4-',
'11.6-',
'14.1-',
'14.2-',
'14.4-',
'15.1-',
'15.2-',
'15.3-',
'15.4.1-',
'15.4.2-',
'15.5-',
'15.6-',
'15.7-',
#'18-',
'21-'])


#Family

checkfm_1 = build_tlc_1.check_family()
checkfm_2 = build_tlc_2.check_family()
checkfm_2d1 = build_tlc_2d1.check_family()
checkfm_3 = build_tlc_3.check_family()
checkfm_4 = build_tlc_4.check_family()
checkfm_5d1 = build_tlc_5d1.check_family()
checkfm_5d2 = build_tlc_5d2.check_family()
checkfm_5d3 = build_tlc_5d3.check_family()
checkfm_5d4 = build_tlc_5d4.check_family()
checkfm_7d2 = build_tlc_7d2.check_family()
checkfm_7d4 = build_tlc_7d4.check_family()
checkfm_8d1 = build_tlc_8d1.check_family()
checkfm_11d5d1 = build_tlc_11d5d1.check_family()
checkfm_11d5d2 = build_tlc_11d5d2.check_family()
checkfm_11d5d3 = build_tlc_11d5d3.check_family()
checkfm_11d5d4 = build_tlc_11d5d4.check_family()
checkfm_11d6 = build_tlc_11d6.check_family()
checkfm_14d1 = build_tlc_14d1.check_family()
checkfm_14d2 = build_tlc_14d2.check_family()
checkfm_14d4 = build_tlc_14d4.check_family()
checkfm_15d1 = build_tlc_15d1.check_family()
checkfm_15d2 = build_tlc_15d2.check_family()
checkfm_15d3 = build_tlc_15d3.check_family()
checkfm_15d4d1 = build_tlc_15d4d1.check_family()
checkfm_15d4d2 = build_tlc_15d4d2.check_family()
checkfm_15d5 = build_tlc_15d5.check_family()
checkfm_15d6 = build_tlc_15d6.check_family()
checkfm_15d7 = build_tlc_15d7.check_family() 
#checkfm_18= build_tlc_18.check_family()
checkfm_21 = build_tlc_21.check_family()

df_ch_1 = pd.DataFrame(checkfm_1, build_tlc_1.files())
df_ch_2 = pd.DataFrame(checkfm_2, build_tlc_2.files())
df_ch_2d1 = pd.DataFrame(checkfm_2d1, build_tlc_2d1.files())
df_ch_3 = pd.DataFrame(checkfm_3, build_tlc_3.files())
df_ch_4 = pd.DataFrame(checkfm_4, build_tlc_4.files())
df_ch_5d1 = pd.DataFrame(checkfm_5d1, build_tlc_5d1.files())
df_ch_5d2 = pd.DataFrame(checkfm_5d2, build_tlc_5d2.files())
df_ch_5d3 = pd.DataFrame(checkfm_5d3, build_tlc_5d3.files())
df_ch_5d4 = pd.DataFrame(checkfm_5d4, build_tlc_5d4.files())
df_ch_7d2 = pd.DataFrame(checkfm_7d2, build_tlc_7d2.files())
df_ch_7d4 = pd.DataFrame(checkfm_7d4, build_tlc_7d4.files())
df_ch_8d1 = pd.DataFrame(checkfm_8d1, build_tlc_8d1.files())
df_ch_11d5d1 = pd.DataFrame(checkfm_11d5d1, build_tlc_11d5d1.files())
df_ch_11d5d2 = pd.DataFrame(checkfm_11d5d2, build_tlc_11d5d2.files())
df_ch_11d5d3 = pd.DataFrame(checkfm_11d5d3, build_tlc_11d5d3.files())
df_ch_11d5d4 = pd.DataFrame(checkfm_11d5d4, build_tlc_11d5d4.files())
df_ch_11d6 = pd.DataFrame(checkfm_11d6, build_tlc_11d6.files())
df_ch_14d1 = pd.DataFrame(checkfm_14d1, build_tlc_14d1.files())
df_ch_14d2 = pd.DataFrame(checkfm_14d2, build_tlc_14d2.files())
df_ch_14d4 = pd.DataFrame(checkfm_14d4, build_tlc_14d4.files())
df_ch_15d1 = pd.DataFrame(checkfm_15d1, build_tlc_15d1.files())
df_ch_15d2 = pd.DataFrame(checkfm_15d2, build_tlc_15d2.files())
df_ch_15d3 = pd.DataFrame(checkfm_15d3, build_tlc_15d3.files())
df_ch_15d4d1 = pd.DataFrame(checkfm_15d4d1, build_tlc_15d4d1.files())
df_ch_15d4d2 = pd.DataFrame(checkfm_15d4d2, build_tlc_15d4d2.files())
df_ch_15d5 = pd.DataFrame(checkfm_15d5, build_tlc_15d5.files())
df_ch_15d6 = pd.DataFrame(checkfm_15d6, build_tlc_15d6.files())
df_ch_15d7 = pd.DataFrame(checkfm_15d7, build_tlc_15d7.files())
#df_ch_18 = pd.DataFrame(checkfm_18= build_tlc_18.check_family())
df_ch_21 = pd.DataFrame(checkfm_21, build_tlc_21.files())

tlc_ch_fm = pd.concat([df_ch_1,
df_ch_2,
df_ch_2d1,
df_ch_3,
df_ch_4,
df_ch_5d1,
df_ch_5d2,
df_ch_5d3,
df_ch_5d4,
df_ch_7d2,
df_ch_7d4,
df_ch_8d1,
df_ch_11d5d1,
df_ch_11d5d2,
df_ch_11d5d3,
df_ch_11d5d4,
df_ch_11d6,
df_ch_14d1,
df_ch_14d2,
df_ch_14d4,
df_ch_15d1,
df_ch_15d2,
df_ch_15d3,
df_ch_15d4d1,
df_ch_15d4d2,
df_ch_15d5,
df_ch_15d6,
df_ch_15d7,
#df_ch_18,
df_ch_21], join = "outer")

# %%
# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(path_proj + r'\0_Schedules\TLC_TD_X_X_MK3_BIM_Check_Families' + '.xlsx') as writer:  
    tlc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    tlc_ch_mt.to_excel(writer, sheet_name='Check_Multi')
with pd.ExcelWriter(path_proj + r'\0_Schedules\Archive\TLC_TD_X_X_MK3_BIM_Check_Families_' + ct + '.xlsx') as writer:  
    tlc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    tlc_ch_mt.to_excel(writer, sheet_name='Check_Multi')

# %%
print('1-', all(checkmt_1), "\n",
'2-', all(checkmt_2), "\n",
'2.1-', all(checkmt_2d1), "\n",
'3-', all(checkmt_3), "\n",
'4-', all(checkmt_4), "\n",
'5.1-', all(checkmt_5d1), "\n",
'5.2-', all(checkmt_5d2), "\n",
'5.3-', all(checkmt_5d3), "\n",
'5.4-', all(checkmt_5d4), "\n",
'7.2-', all(checkmt_7d2), "\n",
'7.4-', all(checkmt_7d4), "\n",
'8.1-', all(checkmt_8d1), "\n",
'11.5.1-', all(checkmt_11d5d1), "\n",
'11.5.2-', all(checkmt_11d5d2), "\n",
'11.5.3-', all(checkmt_11d5d3), "\n",
'11.5.4-', all(checkmt_11d5d4), "\n",
'11.6-', all(checkmt_11d6), "\n",
'14.1-', all(checkmt_14d1), "\n",
'14.2-', all(checkmt_14d2), "\n",
'14.4-', all(checkmt_14d4), "\n",
'15.1-', all(checkmt_15d1), "\n",
'15.2-', all(checkmt_15d2), "\n",
'15.3-', all(checkmt_15d3), "\n",
'15.4.1-', all(checkmt_15d4d1), "\n",
'15.4.2-', all(checkmt_15d4d2), "\n",
'15.5-', all(checkmt_15d5), "\n",
'15.6-', all(checkmt_15d6), "\n",
'15.7-', all(checkmt_15d7), "\n",
'18-', all(checkmt_18), "\n",
'21-', all(checkmt_21), "\n",)

# %%
#Family

df_ch_1 = pd.DataFrame(checkfm_1, build_tlc_1.check_family())
df_ch_2 = pd.DataFrame(checkfm_2, build_tlc_2.check_family())
df_ch_2d1 = pd.DataFrame(checkfm_2d1, build_tlc_2d1.check_family())
df_ch_3 = pd.DataFrame(checkfm_3, build_tlc_3.check_family())
df_ch_4 = pd.DataFrame(checkfm_4, build_tlc_4.check_family())
df_ch_5d1 = pd.DataFrame(checkfm_5d1, build_tlc_5d1.check_family())
df_ch_5d2 = pd.DataFrame(checkfm_5d2, build_tlc_5d2.check_family())
df_ch_5d3 = pd.DataFrame(checkfm_5d3, build_tlc_5d3.check_family())
df_ch_5d4 = pd.DataFrame(checkfm_5d4, build_tlc_5d4.check_family())
df_ch_7d2 = pd.DataFrame(checkfm_7d2, build_tlc_7d2.check_family())
df_ch_7d4 = pd.DataFrame(checkfm_7d4, build_tlc_7d4.check_family())
df_ch_8d1 = pd.DataFrame(checkfm_8d1, build_tlc_8d1.check_family())
df_ch_11d5d1 = pd.DataFrame(checkfm_11d5d1, build_tlc_11d5d1.check_family())
df_ch_11d5d2 = pd.DataFrame(checkfm_11d5d2, build_tlc_11d5d2.check_family())
df_ch_11d5d3 = pd.DataFrame(checkfm_11d5d3, build_tlc_11d5d3.check_family())
df_ch_11d5d4 = pd.DataFrame(checkfm_11d5d4, build_tlc_11d5d4.check_family())
df_ch_11d6 = pd.DataFrame(checkfm_11d6, build_tlc_11d6.check_family())
df_ch_14d1 = pd.DataFrame(checkfm_14d1, build_tlc_14d1.check_family())
df_ch_14d2 = pd.DataFrame(checkfm_14d2, build_tlc_14d2.check_family())
df_ch_14d4 = pd.DataFrame(checkfm_14d4, build_tlc_14d4.check_family())
df_ch_15d1 = pd.DataFrame(checkfm_15d1, build_tlc_15d1.check_family())
df_ch_15d2 = pd.DataFrame(checkfm_15d2, build_tlc_15d2.check_family())
df_ch_15d3 = pd.DataFrame(checkfm_15d3, build_tlc_15d3.check_family())
df_ch_15d4d1 = pd.DataFrame(checkfm_15d4d1, build_tlc_15d4d1.check_family())
df_ch_15d4d2 = pd.DataFrame(checkfm_15d4d2, build_tlc_15d4d2.check_family())
df_ch_15d5 = pd.DataFrame(checkfm_15d5, build_tlc_15d5.check_family())
df_ch_15d6 = pd.DataFrame(checkfm_15d6, build_tlc_15d6.check_family())
df_ch_15d7 = pd.DataFrame(checkfm_15d7, build_tlc_15d7.check_family())
df_ch_18 = pd.DataFrame(checkfm_18= build_tlc_18.check_family())
df_ch_21 = pd.DataFrame(checkfm_21, build_tlc_21.check_family())

tlc_ch_fm = pd.concat([df_ch_1,
df_ch_2,
df_ch_2d1,
df_ch_3,
df_ch_4,
df_ch_5d1,
df_ch_5d2,
df_ch_5d3,
df_ch_5d4,
df_ch_7d2,
df_ch_7d4,
df_ch_8d1,
df_ch_11d5d1,
df_ch_11d5d2,
df_ch_11d5d3,
df_ch_11d5d4,
df_ch_11d6,
df_ch_14d1,
df_ch_14d2,
df_ch_14d4,
df_ch_15d1,
df_ch_15d2,
df_ch_15d3,
df_ch_15d4d1,
df_ch_15d4d2,
df_ch_15d5,
df_ch_15d6,
df_ch_15d7,
df_ch_18,
df_ch_21], join = "outer") 

# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(path_proj + r'\0_Schedules\tlc_TD_X_X_MK3_BIM_Check_Families' + '.xlsx') as writer:  
    tlc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    tlc_ch_mt.to_excel(writer, sheet_name='Check_Multi')
with pd.ExcelWriter(path_proj + r'\0_Schedules\Archive\tlc_TD_X_X_MK3_BIM_Check_Families_' + ct + '.xlsx') as writer:  
    tlc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    tlc_ch_mt.to_excel(writer, sheet_name='Check_Multi')
# Out:
# 1- True
#  2- True
#  2.1- True
#  3- True
#  4- True
#  5.1- True
#  5.2- True
#  5.3- True
#  5.4- True
#  7.2- True
#  7.4- True
#  8.1- True
#  11.5.1- True
#  11.5.2- True
#  11.5.3- True
#  11.5.4- True
#  11.6- True
#  14.1- True
#  14.2- True
#  14.4- True
#  15.1- True
#  15.2- True
#  15.3- True
#  15.4.1- True
#  15.4.2- True
#  15.5- True
#  15.6- True
#  15.7- True
#  18- True
#  21- True

# %%
print('1-', all(checkfm_1), "\n",
'2-', all(checkfm_2), "\n",
'2.1-', all(checkfm_2d1), "\n",
'3-', all(checkfm_3), "\n",
'4-', all(checkfm_4), "\n",
'5.1-', all(checkfm_5d1), "\n",
'5.2-', all(checkfm_5d2), "\n",
'5.3-', all(checkfm_5d3), "\n",
'5.4-', all(checkfm_5d4), "\n",
'7.2-', all(checkfm_7d2), "\n",
'7.4-', all(checkfm_7d4), "\n",
'8.1-', all(checkfm_8d1), "\n",
'11.5.1-', all(checkfm_11d5d1), "\n",
'11.5.2-', all(checkfm_11d5d2), "\n",
'11.5.3-', all(checkfm_11d5d3), "\n",
'11.5.4-', all(checkfm_11d5d4), "\n",
'11.6-', all(checkfm_11d6), "\n",
'14.1-', all(checkfm_14d1), "\n",
'14.2-', all(checkfm_14d2), "\n",
'14.4-', all(checkfm_14d4), "\n",
'15.1-', all(checkfm_15d1), "\n",
'15.2-', all(checkfm_15d2), "\n",
'15.3-', all(checkfm_15d3), "\n",
'15.4.1-', all(checkfm_15d4d1), "\n",
'15.4.2-', all(checkfm_15d4d2), "\n",
'15.5-', all(checkfm_15d5), "\n",
'15.6-', all(checkfm_15d6), "\n",
'15.7-', all(checkfm_15d7), "\n",
'18-', all(checkfm_18), "\n",
'21-', all(checkfm_21), "\n",)

# %%
checkfm_1
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %%
#Create Data frames
df_tlc_1 = build_tlc_1.df()
df_tlc_2d1 = build_tlc_2d1.df()
df_tlc_2 = build_tlc_2.df()
df_tlc_3 = build_tlc_3.df()
df_tlc_4 = build_tlc_4.df()
df_tlc_5d1 = build_tlc_5d1.df()
df_tlc_5d2 = build_tlc_5d2.df()
df_tlc_5d3 = build_tlc_5d3.df()
df_tlc_5d4 = build_tlc_5d4.df()
df_tlc_7d2 = build_tlc_7d2.df()
df_tlc_7d4 = build_tlc_7d4.df()
df_tlc_8d1 = build_tlc_8d1.df()
df_tlc_11d5d1 = build_tlc_11d5d1.df()
df_tlc_11d5d2 = build_tlc_11d5d2.df()
df_tlc_11d5d3 = build_tlc_11d5d3.df()
df_tlc_11d5d4 = build_tlc_11d5d4.df()
df_tlc_11d6 = build_tlc_11d6.df()
df_tlc_14d1 = build_tlc_14d1.df()
df_tlc_14d2 = build_tlc_14d2.df()
df_tlc_14d4 = build_tlc_14d4.df()
df_tlc_15d1 = build_tlc_15d1.df()
df_tlc_15d2 = build_tlc_15d2.df()
df_tlc_15d3 = build_tlc_15d3.df()
df_tlc_15d4d1 = build_tlc_15d4d1.df()
df_tlc_15d4d2 = build_tlc_15d4d2.df()
df_tlc_15d5 = build_tlc_15d5.df()
df_tlc_15d6 = build_tlc_15d6.df()
df_tlc_15d7 = build_tlc_15d7.df()
df_tlc_18 = build_tlc_18.df()
df_tlc_21 = build_tlc_21.df()

# %%
#Compare buildings
df_tlc = pd.concat([df_tlc_1, 
                        df_tlc_2d1,
                        df_tlc_2,                    
                        df_tlc_3,
                        df_tlc_4,
                        df_tlc_5d1,
#                        df_tlc_5d2,
#                        df_tlc_5d3,
                        df_tlc_5d4,
                        df_tlc_7d2,
                        df_tlc_7d4,
                        df_tlc_8d1,
                        df_tlc_11d5d1,
                        df_tlc_11d5d2,
                        df_tlc_11d5d3,
                        df_tlc_11d5d4,
                        df_tlc_11d5,
#                        df_tlc_11d6,
                        df_tlc_14d1,
                        df_tlc_14d2,
                        df_tlc_14d4,
                        df_tlc_15d1,
                        df_tlc_15d2,
                        df_tlc_15d3,
                        df_tlc_15d4d1,
                        df_tlc_15d4d2,
                        df_tlc_15d5,
                        df_tlc_15d6,
                        df_tlc_15d7,
                        df_tlc_18,
                        df_tlc_21                   
                     ], join = "outer")

# %%
# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(path_proj + r'\0_Schedules\TLC_TD_X_X_MK3_BIM_Schedules' + '.xlsx') as writer:  
    df_tlc.to_excel(writer, sheet_name='Summary_Schedule')
df_tlc.to_csv(path_proj + r'\0_Schedules\TLC_TD_X_X_MK3_BIM_Schedules' + '.csv')
   
with pd.ExcelWriter(path_proj + r'\0_Schedules\Archive\TLC_TD_X_X_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    df_tlc.to_excel(writer, sheet_name='Summary_Schedule')

# %%
#Проверка

for i in range(len(build_tlc_1.files())):
    print(('VTBR_Multi-Category MT' in build_tlc_1.category()[i]) and ('VTBR_Multi-Category' in build_tlc_1.category()[i]), build_tlc_1.files()[i])
# Out:
# True TLC_P_II_1_MK3_BIM_AR_Архитектура_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_ES_Электроснабжение_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_KR_Конструктив_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_OV_ОВиК_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_PS_Пожарная сигнализация_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_PT_Пожаротушение_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_SS_Слаботочные системы_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_TX_Технология_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_VK_Водоснабжение и канализация_Schedules.xlsx
# True TLC_P_II_1_MK3_BIM_ОЗДС_Дератизация_Schedules.xlsx
