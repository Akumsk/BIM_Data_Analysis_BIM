# %%
import pandas as pd
import numpy as np
#import pathlib
import datetime
#import xlrd
#import openpyxl
from configurations import config 
import os
from rschedule import rschedule

# %%
path_proj = config['path']['orc']

# %%
# Creating objects
#Создание объектов ОРЦ
build_orc_1d1 = rschedule('ORC', '1.1_МО Склад_3 этап')
build_orc_2d1 = rschedule('ORC', '2.1_КО Склад_3 этап')
build_orc_3d1 = rschedule('ORC', '3.1_КО Склад_2 этап')
build_orc_1d1 = rschedule('ORC', '1.1_МО Склад_3 этап')
build_orc_2d1 = rschedule('ORC', '2.1_КО Склад_3 этап')
build_orc_3d1 = rschedule('ORC', '3.1_КО Склад_2 этап')
build_orc_1d3 = rschedule('ORC', '1.3_КПП 2_3 этап')
build_orc_1d4 = rschedule('ORC', '1.4_КПП 3_3 этап')
build_orc_1d5 = rschedule('ORC', '1.5_КПП 4_3 этап')
build_orc_1d6 = rschedule('ORC', '1.6_КПП 5_4 этап')
build_orc_4d1 = rschedule('ORC', '4.1_Навес_3 этап')
build_orc_7 = rschedule('ORC', '7_Автомойка_3 этап')
build_orc_8 = rschedule('ORC', '8_Адм.блок_1 этап')
build_orc_9 = rschedule('ORC', '9_Магазин с аптекой_3 этап')
build_orc_11 = rschedule('ORC', '11_Гостница с кафе_2 этап')
build_orc_12 = rschedule('ORC', '12 Гостиница №1_3 этап')
build_orc_14 = rschedule('ORC', '14_Столовая_1 этап')
build_orc_16 = rschedule('ORC', '16_Котельная_1 этап')
build_orc_17d1 = rschedule('ORC', '17-1 Адм здание с КПП № 6 и складом хранения особо ценных грузов.  Блок 1_3 этап')
build_orc_17d2 = rschedule('ORC', '17-2 Адм здание с КПП № 6 и складом хранения особо ценных грузов.  Блок 2_5 этап')
build_orc_25 = rschedule('ORC', '25 Пункт временного накопления вторсырья_7 этап')
build_orc_27 = rschedule('ORC', '27 Гараж_7 этап')
build_orc_33 = rschedule('ORC', '33 Автомойка_6 этап')
build_orc_35 = rschedule('ORC', '35 Навес для ПГМ_7 этап')

# %%
#Проверка

#Multi
checkmt_1d1 = build_orc_1d1.check_multi()
checkmt_2d1 = build_orc_2d1.check_multi()
checkmt_3d1 = build_orc_3d1.check_multi()
checkmt_1d3 = build_orc_1d3.check_multi()
checkmt_1d4 = build_orc_1d4.check_multi()
checkmt_1d5 = build_orc_1d5.check_multi()
checkmt_1d6 = build_orc_1d6.check_multi()
checkmt_4d1 = build_orc_4d1.check_multi()
checkmt_7 = build_orc_7.check_multi()
checkmt_8 = build_orc_8.check_multi()
checkmt_9 = build_orc_9.check_multi()
checkmt_11 = build_orc_11.check_multi()
checkmt_12 = build_orc_12.check_multi()
checkmt_14 = build_orc_14.check_multi()
checkmt_16= build_orc_16.check_multi()
checkmt_17d1 = build_orc_17d1.check_multi()
checkmt_17d2 = build_orc_17d2.check_multi()
checkmt_25 = build_orc_25.check_multi()
checkmt_27 = build_orc_27.check_multi()
checkmt_33 = build_orc_33.check_multi()
checkmt_35 = build_orc_35.check_multi()

orc_ch_mt = pd.DataFrame([all(checkmt_1d1),
all(checkmt_2d1),
all(checkmt_3d1),
all(checkmt_1d3),
all(checkmt_1d4),
all(checkmt_1d5),
all(checkmt_1d6),
all(checkmt_4d1),
all(checkmt_7), 
all(checkmt_8),
all(checkmt_9),
all(checkmt_11),
all(checkmt_12),
all(checkmt_14),
all(checkmt_16),
all(checkmt_17d1),
all(checkmt_17d2),
all(checkmt_25),
all(checkmt_27),
all(checkmt_33),
all(checkmt_35)],
['1.1',
'2.1',
'3.1',
'1.3',
'1.4',
'1.5',
'1.6',
'4.1',
'7', 
'8',
'9',
'11',
'12',
'14',
'16',
'17.1',
'17.2',
'25',
'27',
'33',
'35'],)

#Family

checkfm_1d1 = build_orc_1d1.check_family()
checkfm_2d1 = build_orc_2d1.check_family()
checkfm_3d1 = build_orc_3d1.check_family()
checkfm_1d3 = build_orc_1d3.check_family()
checkfm_1d4 = build_orc_1d4.check_family()
checkfm_1d5 = build_orc_1d5.check_family()
checkfm_1d6 = build_orc_1d6.check_family()
checkfm_4d1 = build_orc_4d1.check_family()
checkfm_7 = build_orc_7.check_family()
checkfm_8 = build_orc_8.check_family()
checkfm_9 = build_orc_9.check_family()
checkfm_11 = build_orc_11.check_family()
checkfm_12 = build_orc_12.check_family()
checkfm_14 = build_orc_14.check_family()
checkfm_16= build_orc_16.check_family()
checkfm_17d1 = build_orc_17d1.check_family()
checkfm_17d2 = build_orc_17d2.check_family()
checkfm_25 = build_orc_25.check_family()
checkfm_27 = build_orc_27.check_family()
checkfm_33 = build_orc_33.check_family()
checkfm_35 = build_orc_35.check_family()

df_ch_1d1 = pd.DataFrame(checkfm_1d1, build_orc_1d1.files())
df_ch_2d1 = pd.DataFrame(checkfm_2d1, build_orc_2d1.files())
df_ch_3d1 = pd.DataFrame(checkfm_3d1, build_orc_3d1.files())
df_ch_1d3 = pd.DataFrame(checkfm_1d3, build_orc_1d3.files())
df_ch_1d4 = pd.DataFrame(checkfm_1d4, build_orc_1d4.files())
df_ch_1d5 = pd.DataFrame(checkfm_1d5, build_orc_1d5.files())
df_ch_1d6 = pd.DataFrame(checkfm_1d6, build_orc_1d6.files())
df_ch_4d1 = pd.DataFrame(checkfm_4d1, build_orc_4d1.files())
df_ch_7 = pd.DataFrame(checkfm_7, build_orc_7.files())
df_ch_8 = pd.DataFrame(checkfm_8, build_orc_8.files())
df_ch_9 = pd.DataFrame(checkfm_9, build_orc_9.files())
df_ch_11 = pd.DataFrame(checkfm_11, build_orc_11.files())
df_ch_12 = pd.DataFrame(checkfm_12, build_orc_12.files())
df_ch_14 = pd.DataFrame(checkfm_14, build_orc_14.files())
df_ch_16 = pd.DataFrame(checkfm_16, build_orc_16.files())
df_ch_17d1 = pd.DataFrame(checkfm_17d1, build_orc_17d1.files())
df_ch_17d2 = pd.DataFrame(checkfm_17d2, build_orc_17d2.files())
df_ch_25 = pd.DataFrame(checkfm_25, build_orc_25.files())
df_ch_27 = pd.DataFrame(checkfm_27, build_orc_27.files())
df_ch_33 = pd.DataFrame(checkfm_33, build_orc_33.files())
df_ch_35 = pd.DataFrame(checkfm_35, build_orc_35.files())

orc_ch_fm = pd.concat([df_ch_1d1, 
df_ch_2d1,
df_ch_3d1,
df_ch_1d3,
df_ch_1d4,
df_ch_1d5,
df_ch_1d6,
df_ch_4d1,
df_ch_7,
df_ch_8,
df_ch_9,
df_ch_11,
df_ch_12,
df_ch_14,
df_ch_16,
df_ch_17d1,
df_ch_17d2,
df_ch_27,
df_ch_25,
df_ch_33,
df_ch_35
], join = "outer")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# VTBN_Disk\# BIM\17_Scripts\Phyton\BIM_Analisys\ORC_Analisys.ipynb Cell 4' in <module>
#     <a href='vscode-notebook-cell://192.168.128.12/VTBN_Disk/%23%20BIM/17_Scripts/Phyton/BIM_Analisys/ORC_Analisys.ipynb#ch0000003?line=136'>137</a> now = datetime.datetime.now()
#     <a href='vscode-notebook-cell://192.168.128.12/VTBN_Disk/%23%20BIM/17_Scripts/Phyton/BIM_Analisys/ORC_Analisys.ipynb#ch0000003?line=137'>138</a> ct = now.strftime("%Y_%m_%d")
# --> <a href='vscode-notebook-cell://192.168.128.12/VTBN_Disk/%23%20BIM/17_Scripts/Phyton/BIM_Analisys/ORC_Analisys.ipynb#ch0000003?line=138'>139</a> with pd.ExcelWriter(path_proj + r'\0_Schedules\ORC_TD_X_X_MK3_BIM_Check_Families' + '.xlsx') as writer:
# ...

# %%
# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(path_proj + r'\0_Schedules\ORC_TD_X_X_MK3_BIM_Check_Families' + '.xlsx') as writer:  
    orc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    orc_ch_mt.to_excel(writer, sheet_name='Check_Multi')
with pd.ExcelWriter(path_proj + r'\0_Schedules\Archive\ORC_TD_X_X_MK3_BIM_Check_Families_' + ct + '.xlsx') as writer:  
    orc_ch_fm.to_excel(writer, sheet_name='Check_Families')
    orc_ch_mt.to_excel(writer, sheet_name='Check_Multi')

# %%
#Create Data frames
df_orc_1d1 = build_orc_1d1.df()
df_orc_2d1 = build_orc_2d1.df()
df_orc_3d1 = build_orc_3d1.df()
df_orc_1d3 = build_orc_1d3.df()
df_orc_1d4 = build_orc_1d4.df()
df_orc_1d5 = build_orc_1d5.df()
df_orc_1d6 = build_orc_1d6.df()
df_orc_4d1 = build_orc_4d1.df()
df_orc_7 = build_orc_7.df()
df_orc_8 = build_orc_8.df()
df_orc_9 = build_orc_9.df()
df_orc_11 = build_orc_11.df()
df_orc_12 = build_orc_12.df()
df_orc_14 = build_orc_14.df()
df_orc_16 = build_orc_16.df()
df_orc_17d1 = build_orc_17d1.df()
df_orc_17d2 = build_orc_17d2.df()
df_orc_25 = build_orc_25.df()
df_orc_27 = build_orc_27.df()
df_orc_33 = build_orc_33.df()
df_orc_35 = build_orc_35.df()

# %%
#Compare buildings
df_orc = pd.concat([df_orc_1d1, 
                        df_orc_2d1,
                        df_orc_3d1,
                        df_orc_4d1,
                        df_orc_1d3,                    
                        df_orc_1d4,                    
                        df_orc_1d5,                    
                        df_orc_1d6,                    
                        df_orc_7,
                        df_orc_8,
                        df_orc_9,
                        df_orc_11,
                        df_orc_12,
                        df_orc_14,
                        df_orc_16,
                        df_orc_17d1,
                        df_orc_17d2, 
                        df_orc_25,                    
                        df_orc_27,
                        df_orc_33,                                            
                        df_orc_35                     
                     ], join = "outer")

# %%
# Создание Excel  отчёта
now = datetime.datetime.now()
ct = now.strftime("%Y_%m_%d")
with pd.ExcelWriter(path_proj + r'\0_Schedules\ORC_TD_X_X_MK3_BIM_Schedules' + '.xlsx') as writer:  
    df_orc.to_excel(writer, sheet_name='Summary_Schedule')
with pd.ExcelWriter(path_proj + r'\0_Schedules\Archive\ORC_TD_X_X_MK3_BIM_Schedules_' + ct + '.xlsx') as writer:  
    df_orc.to_excel(writer, sheet_name='Summary_Schedule')

# %%
print('1.1-', all(checkmt_1d1), "\n",
'2.1-', all(checkmt_2d1), "\n",
'3.1-', all(checkmt_3d1), "\n",
'1.3-', all(checkmt_1d3), "\n",
'1.4-', all(checkmt_1d4), "\n",
'1.5-', all(checkmt_1d5), "\n",
'1.6-', all(checkmt_1d6), "\n",
'4.1-', all(checkmt_4d1), "\n",
'7-', all(checkmt_7), "\n",
'8-', all(checkmt_8), "\n",
'9-', all(checkmt_9), "\n",
'11-', all(checkmt_11), "\n",
'12-', all(checkmt_12), "\n",
'14-', all(checkmt_14), "\n",
'16-', all(checkmt_16), "\n",
'17.1-', all(checkmt_17d1), "\n",
'17.2-', all(checkmt_17d2), "\n",
'25-', all(checkmt_25), "\n",
'27-', all(checkmt_27), "\n",
'33-', all(checkmt_33), "\n",
'35-', all(checkmt_35), "\n"
)
# Out:
# 1.1- True
#  2.1- True
#  3.1- True
#  1.3- True
#  1.4- True
#  1.5- True
#  1.6- True
#  4.1- True
#  7- True
#  8- True
#  9- True
#  11- True
#  12- True
#  14- True
#  16- True
#  17.1- True
#  17.2- True
#  25- True
#  27- True
#  33- True
#  35- True

# %%
# Out:
#          0
# 1.1   True
# 2.1   True
# 3.1   True
# 1.3   True
# 1.4   True
# 1.5   True
# 1.6   True
# 4.1   True
# 7     True
# 8     True
# 9     True
# 11    True
# 12    True
# 14    True
# 16    True
# 17.1  True
# 17.2  True
# 25    True
# 27    True
# 33    True
# 35    True

# %%
#Проверка

# %%
print('1.1-', all(checkfm_1d1), "\n", 
'2.1-', all(checkfm_2d1), "\n",
'3.1-', all(checkfm_3d1), "\n",
'1.3-', all(checkfm_1d3), "\n",
'1.4-', all(checkfm_1d4), "\n",
'1.5-', all(checkfm_1d5), "\n",
'1.6-', all(checkfm_1d6), "\n",
'4.1-', all(checkfm_4d1), "\n",
'7-', all(checkfm_7), "\n",
'8-', all(checkfm_8), "\n",
'9-', all(checkfm_9), "\n",
'11-', all(checkfm_11), "\n",
'12-', all(checkfm_12), "\n",
'14-', all(checkfm_14), "\n",
'16-', all(checkfm_16), "\n",
'17.1-', all(checkfm_17d1), "\n",
'17.2-', all(checkfm_17d2), "\n",
'25-', all(checkfm_25), "\n",
'27.1-', all(checkfm_27), "\n",
'33-', all(checkfm_33), "\n",
'35-', all(checkfm_35), "\n")
# Out:
# 1.1- True
#  2.1- True
#  3.1- True
#  1.3- False
#  1.4- True
#  1.5- True
#  1.6- True
#  4.1- True
#  7- True
#  8- True
#  9- True
#  11- False
#  12- True
#  14- True
#  16- True
#  17.1- True
#  17.2- False
#  25- True
#  27.1- True
#  33- True
#  35- True

# %%
checkfm_14
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
build_orc_14.files()
# Out:
# ['ORC_T_I_14-1_STH_BIM_AR_Архитектура(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS1_ЭОМ(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS23_ВК(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS4-1_Вентиляц(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS4-2_Отоплен(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS4-3_Кондиц(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS5_АК(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS5_СС(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_IOS7_ТХ(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_KR_Конструкции(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_TB-1_ПС(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_TB-2_СОУЭ(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_TB-3_ПДВЗ(ЗМТ)_Schedules.xlsx',
#  'ORC_T_I_14-1_STH_BIM_TB-4_ПТ(ЗМТ)_Schedules.xlsx']

# %%
df_ch_17d2
# Out:
#                                                         0
# ORC_T_V_17-2_STH_BIM_AR_АР(ЗТК)_Schedules.xlsx       True
# ORC_T_V_17-2_STH_BIM_IOS1_ЭОМ(ЗТК)_Schedules.xlsx    True
# ORC_T_V_17-2_STH_BIM_IOS23_ВК(ЗТК)_Schedules.xlsx    True
# ORC_T_V_17-2_STH_BIM_IOS4-1_Вентиляц(ЗТК)_Sched...   True
# ORC_T_V_17-2_STH_BIM_IOS4-2_Отоплен(ЗТК)_Schedu...   True
# ORC_T_V_17-2_STH_BIM_IOS4-5_ХС(ЗТК)_Schedules.xlsx   True
# ORC_T_V_17-2_STH_BIM_IOS5_АК(ЗТК)_Schedules.xlsx     True
# ORC_T_V_17-2_STH_BIM_IOS5_СС(ЗТК)_Schedules.xlsx     True
# ORC_T_V_17-2_STH_BIM_IOS7_ТХ(ЗТК)_Schedules.xlsx     True
# ORC_T_V_17-2_STH_BIM_KR_Конструкции(ЗТК)_Schedu...  False
# ORC_T_V_17-2_STH_BIM_TB-1_ПС(ЗТК)_Schedules.xlsx     True
# ORC_T_V_17-2_STH_BIM_TB-2_СОУЭ(ЗТК)_Schedules.xlsx   True
# ORC_T_V_17-2_STH_BIM_TB-4_ПТ(ЗТК)_Schedules.xlsx     True
